# %%
import pandas as pd
import csv
import json

x = """[
      {
         "leaguePoints": 196,
         "isFreshBlood": false,
         "isHotStreak": false,
         "division": "I",
         "isInactive": false,
         "isVeteran": false,
         "losses": 89,
         "playerOrTeamName": "Óui",
         "playerOrTeamId": "20655154",
         "wins": 116
      },
      {
         "leaguePoints": 42,
         "isFreshBlood": false,
         "isHotStreak": true,
         "division": "I",
         "isInactive": false,
         "isVeteran": false,
         "losses": 124,
         "playerOrTeamName": "Henrÿ",
         "playerOrTeamId": "22186978",
         "wins": 138
      },
      {
         "leaguePoints": 85,
         "isFreshBlood": false,
         "isHotStreak": false,
         "division": "I",
         "isInactive": false,
         "isVeteran": false,
         "losses": 68,
         "playerOrTeamName": "fireboyx",
         "playerOrTeamId": "78859792",
         "wins": 75
      },
      {
         "leaguePoints": 57,
         "isFreshBlood": false,
         "isHotStreak": false,
         "division": "I",
         "isInactive": false,
         "isVeteran": false,
         "losses": 112,
         "playerOrTeamName": "xHazzard",
         "playerOrTeamId": "20483477",
         "wins": 120
      }]"""

mTier = open('\Users\NIk Khandwala\Desktop\Notes\datascienceclass.json')
masterTier = json.loads(mTier)

f = csv.writer(open("test.csv", 'wb+'))




f.writerow(['leaguePoints', 'isFreshBlood','isHotStreak','divison','isInactive','isVeteran','losses',
           'playerOrTeamName', 'playerOrTeamId','wins'])

for x in x:
    f.writerow([x["leaguePoints"],
                x["isFreshBlood"],
                x["isHotStreak"],
                x["divison"],
                x["isInactive"],
                x["isVeteran"],
                x["losses"],
                x["playerOrTeamName"],
                x["playerOrTeamID"],
                x["wins"]])
    
#def flattenjson( b, delim ):
#    val = {}
#    for i in b.keys():
#        if isinstance( b[i], dict ):
#            get = flattenjson( b[i], delim )
#            for j in get.keys():
#                val[ i + delim + j ] = get[j]
#        else:
#            val[i] = b[i]
#
#    return val




#pd.read.table('Users\NIk Khandwala\Desktop\Notes\masterTier.json')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-23-ee33ce0bd3ad> in <module>()
#      54
#      55 mTier = open('\Users\NIk Khandwala\Desktop\Notes\datascienceclass.json')
# ---> 56 masterTier = json.loads(mTier)
#      57
#      58 f = csv.writer(open("test.csv", 'wb+'))
#
# C:\Users\NIk Khandwala\Anaconda2\lib\json\__init__.pyc in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     337             parse_int is None and parse_float is None and
#     338             parse_constant is None and object_pairs_hook is None and not kw):
# --> 339         return _default_decoder.decode(s)
#     340     if cls is None:
#     341         cls = JSONDecoder
#
# C:\Users\NIk Khandwala\Anaconda2\lib\json\decoder.pyc in decode(self, s, _w)
#     362
#     363         """
# ...
