# %%
import json
import urllib2
from urllib2 import Request, urlopen
import pandas as pd
import csv
from pandas.io.json import json_normalize
import numpy as np
import matplotlib.pyplot as plt
import unicodedata




request = Request('https://na.api.pvp.net/api/lol/na/v2.2/matchlist/by-summoner/35590582?beginIndex=0&endIndex=10&api_key=RGAPI-6b4e9139-2121-4820-8cd9-371891441c4b')

response = urlopen(request)

data = response.read()

matchList= json.loads(data)

matchList
# Out:
# {u'endIndex': 10,
#  u'matches': [{u'champion': 1,
#    u'lane': u'MID',
#    u'matchId': 2412401663L,
#    u'platformId': u'NA1',
#    u'queue': u'TEAM_BUILDER_RANKED_SOLO',
#    u'region': u'NA',
#    u'role': u'SOLO',
#    u'season': u'PRESEASON2017',
#    u'timestamp': 1485748933846L},
#   {u'champion': 1,
#    u'lane': u'BOTTOM',
#    u'matchId': 2412355501L,
#    u'platformId': u'NA1',
#    u'queue': u'TEAM_BUILDER_RANKED_SOLO',
#    u'region': u'NA',
#    u'role': u'DUO_SUPPORT',
#    u'season': u'PRESEASON2017',
#    u'timestamp': 1485746498334L},
#   {u'champion': 1,
#    u'lane': u'JUNGLE',
#    u'matchId': 2412305632L,
#    u'platformId': u'NA1',
#    u'queue': u'TEAM_BUILDER_RANKED_SOLO',
#    u'region': u'NA',
#    u'role': u'NONE',
#    u'season': u'PRESEASON2017',
#    u'timestamp': 1485742893449L},
#   {u'champion': 1,
#    u'lane': u'MID',
#    u'matchId': 2411862429L,
#    u'platformId': u'NA1',
#    u'queue': u'TEAM_BUILDER_RANKED_SOLO',
#    u'region': u'NA',
#    u'role': u'SOLO',
#    u'season': u'PRESEASON2017',
#    u'timestamp': 1485728057082L},
#   {u'champion': 1,
#    u'lane': u'MID',
#    u'matchId': 2411796285L,
#    u'platformId': u'NA1',
#    u'queue': u'TEAM_BUILDER_RANKED_SOLO',
#    u'region': u'NA',
#    u'role': u'SOLO',
#    u'season': u'PRESEASON2017',
#    u'timestamp': 1485725257898L},
#   {u'champion': 1,
#    u'lane': u'TOP',
#    u'matchId': 2411801397L,
#    u'platformId': u'NA1',
#    u'queue': u'TEAM_BUILDER_RANKED_SOLO',
#    u'region': u'NA',
#    u'role': u'SOLO',
#    u'season': u'PRESEASON2017',
#    u'timestamp': 1485722941459L},
#   {u'champion': 1,
#    u'lane': u'TOP',
#    u'matchId': 2411736741L,
#    u'platformId': u'NA1',
#    u'queue': u'TEAM_BUILDER_RANKED_SOLO',
#    u'region': u'NA',
#    u'role': u'SOLO',
#    u'season': u'PRESEASON2017',
#    u'timestamp': 1485720677539L},
#   {u'champion': 1,
#    u'lane': u'MID',
#    u'matchId': 2411751982L,
#    u'platformId': u'NA1',
#    u'queue': u'TEAM_BUILDER_RANKED_SOLO',
#    u'region': u'NA',
#    u'role': u'SOLO',
#    u'season': u'PRESEASON2017',
#    u'timestamp': 1485718628605L},
#   {u'champion': 1,
#    u'lane': u'MID',
#    u'matchId': 2411687169L,
#    u'platformId': u'NA1',
#    u'queue': u'TEAM_BUILDER_RANKED_SOLO',
#    u'region': u'NA',
#    u'role': u'SOLO',
#    u'season': u'PRESEASON2017',
#    u'timestamp': 1485715777116L},
#   {u'champion': 1,
#    u'lane': u'BOTTOM',
#    u'matchId': 2411683753L,
#    u'platformId': u'NA1',
#    u'queue': u'TEAM_BUILDER_RANKED_SOLO',
#    u'region': u'NA',
#    u'role': u'DUO_CARRY',
#    u'season': u'PRESEASON2017',
#    u'timestamp': 1485713786987L}],
#  u'startIndex': 0,
#  u'totalGames': 8955}

# %%
# !conda list -n root

# %%
df_cols =['champion','lane','matchID','platformID','queue','region','role','season','timestamp']

champion=[]
lane=[]
matchId=[]
platformId=[]
queue=[]
region=[]
role=[]
season=[]
timestamp=[]

for matches in matchList['matches']:    
    champion.append(matches[u'champion'])
    lane.append(matches[u'lane'])
    matchId.append(matches[u'matchId'])
    platformId.append(matches[u'platformId'])
    queue.append(matches[u'queue'])
    region.append(matches[u'region'])
    role.append(matches[u'role'])
    season.append(matches[u'season'])
    timestamp.append(matches[u'timestamp'])
    
df= pd.DataFrame([champion,lane,matchId,platformId,queue,region,role,season,timestamp]).T

# %%
# df

with open('matchList1.csv', 'wb') as createcsv:
    create = csv.writer(createcsv)
    create.writerow(df_cols)
    df.to_csv('matchList1.csv', index =False, encoding="utf-8")

# %% [markdown]
# clean match list/
# get matchID/
# use matchID for match restAPI
# check bool for win or loss and check playerIDs with master tier
# get last 10 matches for each player
# trace those back with staticData and predict winners based on team matchups

# %%
tableMatch = pd.read_csv('matchList1.csv', header= 0, names=df_cols, na_filter=False, skiprows=1 )

tableMatch
# Out:
#    champion    lane     matchID platformID                     queue region  \
# 0         1     MID  2411796285        NA1  TEAM_BUILDER_RANKED_SOLO     NA
# 1         1     TOP  2411801397        NA1  TEAM_BUILDER_RANKED_SOLO     NA
# 2         1     TOP  2411736741        NA1  TEAM_BUILDER_RANKED_SOLO     NA
# 3         1     MID  2411751982        NA1  TEAM_BUILDER_RANKED_SOLO     NA
# 4         1     MID  2411687169        NA1  TEAM_BUILDER_RANKED_SOLO     NA
# 5         1  BOTTOM  2411683753        NA1  TEAM_BUILDER_RANKED_SOLO     NA
# 6         1     MID  2411491458        NA1  TEAM_BUILDER_RANKED_SOLO     NA
# 7        63     TOP  2411466421        NA1  TEAM_BUILDER_RANKED_SOLO     NA
# 8         1     MID  2411461293        NA1  TEAM_BUILDER_RANKED_SOLO     NA
#
#         role         season      timestamp
# 0       SOLO  PRESEASON2017  1485725257898
# 1       SOLO  PRESEASON2017  1485722941459
# 2       SOLO  PRESEASON2017  1485720677539
# 3       SOLO  PRESEASON2017  1485718628605
# 4       SOLO  PRESEASON2017  1485715777116
# 5  DUO_CARRY  PRESEASON2017  1485713786987
# 6       SOLO  PRESEASON2017  1485673746344
# 7       SOLO  PRESEASON2017  1485671549264
# 8       SOLO  PRESEASON2017  1485669235750

# %%
tableMatch.dtypes

# %%
match1 = tableMatch['matchID'][0]
match1 = '2405647360'

# %%
match1 = tableMatch['matchID'][0]
match1 = '2405647360'


#matchRequest = Request('https://na.api.pvp.net/api/lol/na/v2.2/match/' + match1 '?api_key=3b5071b3-ecce-4d46-9c26-fcd911526fc7')
matchRequest =Request('https://na.api.pvp.net/api/lol/na/v2.2/match/' +str(match1) '?api_key=3b5071b3-ecce-4d46-9c26-fcd911526fc7')
responseMatch = urlopen(matchRequest)


matchData = responseMatch.read()

loadMatch = json.loads(matchData)

loadMatch
# Out:
#   File "<ipython-input-3-b071554e9706>", line 6
#     matchRequest =Request('https://na.api.pvp.net/api/lol/na/v2.2/match/' +str(match1) '?api_key=3b5071b3-ecce-4d46-9c26-fcd911526fc7')
#                                                                                                                                      ^
# SyntaxError: invalid syntax

# %% [markdown]
# 100 blue team//200 red team

# %%
matchRequest1 =Request('https://na.api.pvp.net/api/lol/na/v2.2/match/2405647360?api_key=RGAPI-6b4e9139-2121-4820-8cd9-371891441c4b')
responseMatch1 = urlopen(matchRequest1)


matchData1 = responseMatch1.read()

loadMatch1 = json.loads(matchData1)

loadMatch1
# Out:
# {u'mapId': 11,
#  u'matchCreation': 1485064762762L,
#  u'matchDuration': 2031,
#  u'matchId': 2405647360L,
#  u'matchMode': u'CLASSIC',
#  u'matchType': u'MATCHED_GAME',
#  u'matchVersion': u'7.1.172.6393',
#  u'participantIdentities': [{u'participantId': 1,
#    u'player': {u'matchHistoryUri': u'/v1/stats/player_history/NA1/50127061',
#     u'profileIcon': 7,
#     u'summonerId': 35590582,
#     u'summonerName': u'Annie Bot'}},
#   {u'participantId': 2,
#    u'player': {u'matchHistoryUri': u'/v1/stats/player_history/NA/33955468',
#     u'profileIcon': 1302,
#     u'summonerId': 20823651,
#     u'summonerName': u'C9 Smoothie'}},
#   {u'participantId': 3,
#    u'player': {u'matchHistoryUri': u'/v1/stats/player_history/NA1/49600069',
#     u'profileIcon': 1394,
#     u'summonerId': 35035174,
#     u'summonerName': u'NA Mechanics'}},
#   {u'participantId': 4,
#    u'player': {u'matchHistoryUri': u'/v1/stats/player_history/NA1/208042907',
#     u'profileIcon': 673,
#     u'summonerId': 45038172,
#     u'summonerName': u'Sir Celery'}},
#   {u'participantId': 5,
#    u'player': {u'matchHistoryUri': u'/v1/stats/player_history/NA/39810826',
#     u'profileIcon': 775,
#     u'summonerId': 25243945,
#     u'summonerName': u'Prestivent'}},
#   {u'participantId': 6,
#    u'player': {u'matchHistoryUri': u'/v1/stats/player_history/NA1/229107022',
#     u'profileIcon': 1215,
#     u'summonerId': 68240838,
#     u'summonerName': u'EnVy Ninja'}},
#   {u'participantId': 7,
#    u'player': {u'matchHistoryUri': u'/v1/stats/player_history/NA/40716888',
#     u'profileIcon': 774,
#     u'summonerId': 26289480,
#     u'summonerName': u'Flamboozle'}},
#   {u'participantId': 8,
#    u'player': {u'matchHistoryUri': u'/v1/stats/player_history/NA/32850898',
#     u'profileIcon': 984,
#     u'summonerId': 20047271,
#     u'summonerName': u'Descraton'}},
#   {u'participantId': 9,
#    u'player': {u'matchHistoryUri': u'/v1/stats/player_history/NA/40435473',
#     u'profileIcon': 981,
#     u'summonerId': 25951204,
#     u'summonerName': u'Dare 2 Defy'}},
#   {u'participantId': 10,
#    u'player': {u'matchHistoryUri': u'/v1/stats/player_history/NA1/208283501',
#     u'profileIcon': 1451,
#     u'summonerId': 44989337,
#     u'summonerName': u'C9 Gun'}}],
#  u'participants': [{u'championId': 1,
#    u'highestAchievedSeasonTier': u'DIAMOND',
#    u'masteries': [{u'masteryId': 6211, u'rank': 5},
#     {u'masteryId': 6221, u'rank': 1},
#     {u'masteryId': 6232, u'rank': 5},
#     {u'masteryId': 6241, u'rank': 1},
#     {u'masteryId': 6311, u'rank': 5},
#     {u'masteryId': 6322, u'rank': 1},
#     {u'masteryId': 6331, u'rank': 5},
#     {u'masteryId': 6342, u'rank': 1},
#     {u'masteryId': 6352, u'rank': 5},
#     {u'masteryId': 6362, u'rank': 1}],
#    u'participantId': 1,
#    u'runes': [{u'rank': 9, u'runeId': 5273},
#     {u'rank': 9, u'runeId': 5296},
#     {u'rank': 9, u'runeId': 5316},
#     {u'rank': 1, u'runeId': 5356},
#     {u'rank': 2, u'runeId': 5365}],
#    u'spell1Id': 6,
#    u'spell2Id': 4,
#    u'stats': {u'assists': 2,
#     u'champLevel': 15,
#     u'combatPlayerScore': 0,
#     u'deaths': 5,
#     u'doubleKills': 1,
#     u'firstBloodAssist': False,
#     u'firstBloodKill': False,
#     u'firstInhibitorAssist': True,
#     u'firstInhibitorKill': False,
#     u'firstTowerAssist': False,
#     u'firstTowerKill': False,
#     u'goldEarned': 12986,
#     u'goldSpent': 11810,
#     u'inhibitorKills': 0,
#     u'item0': 1052,
#     u'item1': 3191,
#     u'item2': 3158,
#     u'item3': 3027,
#     u'item4': 3285,
#     u'item5': 3135,
#     u'item6': 3364,
#     u'killingSprees': 1,
#     u'kills': 7,
#     u'largestCriticalStrike': 74,
#     u'largestKillingSpree': 5,
#     u'largestMultiKill': 2,
#     u'magicDamageDealt': 112511,
#     u'magicDamageDealtToChampions': 13426,
#     u'magicDamageTaken': 11687,
#     u'minionsKilled': 210,
#     u'neutralMinionsKilled': 16,
#     u'neutralMinionsKilledEnemyJungle': 8,
#     u'neutralMinionsKilledTeamJungle': 8,
#     u'objectivePlayerScore': 0,
#     u'pentaKills': 0,
#     u'physicalDamageDealt': 10318,
#     u'physicalDamageDealtToChampions': 489,
#     u'physicalDamageTaken': 7694,
#     u'quadraKills': 0,
#     u'sightWardsBoughtInGame': 0,
#     u'totalDamageDealt': 123417,
#     u'totalDamageDealtToChampions': 13915,
#     u'totalDamageTaken': 19815,
#     u'totalHeal': 2200,
#     u'totalPlayerScore': 0,
#     u'totalScoreRank': 0,
#     u'totalTimeCrowdControlDealt': 144,
#     u'totalUnitsHealed': 1,
#     u'towerKills': 0,
#     u'tripleKills': 0,
#     u'trueDamageDealt': 587,
#     u'trueDamageDealtToChampions': 0,
#     u'trueDamageTaken': 434,
#     u'unrealKills': 0,
#     u'visionWardsBoughtInGame': 1,
#     u'wardsKilled': 5,
#     u'wardsPlaced': 5,
#     u'winner': False},
#    u'teamId': 100,
#    u'timeline': {u'creepsPerMinDeltas': {u'tenToTwenty': 6.3,
#      u'twentyToThirty': 5.5,
#      u'zeroToTen': 6.300000000000001},
#     u'damageTakenPerMinDeltas': {u'tenToTwenty': 540.0,
#      u'twentyToThirty': 684.2,
#      u'zeroToTen': 234.8},
#     u'goldPerMinDeltas': {u'tenToTwenty': 446.0,
#      u'twentyToThirty': 395.7,
#      u'zeroToTen': 237.39999999999998},
#     u'lane': u'MIDDLE',
#     u'role': u'SOLO',
#     u'xpPerMinDeltas': {u'tenToTwenty': 376.0,
#      u'twentyToThirty': 412.0,
#      u'zeroToTen': 381.79999999999995}}},
#   {u'championId': 21,
#    u'highestAchievedSeasonTier': u'CHALLENGER',
#    u'masteries': [{u'masteryId': 6114, u'rank': 5},
#     {u'masteryId': 6121, u'rank': 1},
#     {u'masteryId': 6134, u'rank': 5},
#     {u'masteryId': 6143, u'rank': 1},
#     {u'masteryId': 6311, u'rank': 5},
#     {u'masteryId': 6322, u'rank': 1},
#     {u'masteryId': 6331, u'rank': 2},
#     {u'masteryId': 6332, u'rank': 3},
#     {u'masteryId': 6341, u'rank': 1},
#     {u'masteryId': 6351, u'rank': 5},
#     {u'masteryId': 6362, u'rank': 1}],
#    u'participantId': 2,
#    u'runes': [{u'rank': 9, u'runeId': 5245},
#     {u'rank': 9, u'runeId': 5297},
#     {u'rank': 9, u'runeId': 5315},
#     {u'rank': 2, u'runeId': 5347},
#     {u'rank': 1, u'runeId': 5357}],
#    u'spell1Id': 4,
#    u'spell2Id': 3,
#    u'stats': {u'assists': 11,
#     u'champLevel': 13,
#     u'combatPlayerScore': 0,
#     u'deaths': 9,
#     u'doubleKills': 0,
#     u'firstBloodAssist': False,
#     u'firstBloodKill': False,
#     u'firstInhibitorAssist': True,
#     u'firstInhibitorKill': False,
#     u'firstTowerAssist': False,
#     u'firstTowerKill': False,
#     u'goldEarned': 10932,
#     u'goldSpent': 10025,
#     u'inhibitorKills': 0,
#     u'item0': 2055,
#     u'item1': 2301,
#     u'item2': 3071,
#     u'item3': 3033,
#     u'item4': 3158,
#     u'item5': 1036,
#     u'item6': 3364,
#     u'killingSprees': 1,
#     u'kills': 3,
#     u'largestCriticalStrike': 169,
#     u'largestKillingSpree': 3,
#     u'largestMultiKill': 1,
#     u'magicDamageDealt': 24191,
#     u'magicDamageDealtToChampions': 9753,
#     u'magicDamageTaken': 11092,
#     u'minionsKilled': 52,
#     u'neutralMinionsKilled': 0,
#     u'neutralMinionsKilledEnemyJungle': 0,
#     u'neutralMinionsKilledTeamJungle': 0,
#     u'objectivePlayerScore': 0,
#     u'pentaKills': 0,
#     u'physicalDamageDealt': 19582,
#     u'physicalDamageDealtToChampions': 5601,
#     u'physicalDamageTaken': 11734,
#     u'quadraKills': 0,
#     u'sightWardsBoughtInGame': 0,
#     u'totalDamageDealt': 43912,
#     u'totalDamageDealtToChampions': 15355,
#     u'totalDamageTaken': 22859,
#     u'totalHeal': 692,
#     u'totalPlayerScore': 0,
#     u'totalScoreRank': 0,
#     u'totalTimeCrowdControlDealt': 286,
#     u'totalUnitsHealed': 1,
#     u'towerKills': 1,
#     u'tripleKills': 0,
#     u'trueDamageDealt': 138,
#     u'trueDamageDealtToChampions': 0,
#     u'trueDamageTaken': 32,
#     u'unrealKills': 0,
#     u'visionWardsBoughtInGame': 7,
#     u'wardsKilled': 15,
#     u'wardsPlaced': 39,
#     u'winner': False},
#    u'teamId': 100,
#    u'timeline': {u'creepsPerMinDeltas': {u'tenToTwenty': 2.1,
#      u'twentyToThirty': 1.7,
#      u'zeroToTen': 1.0},
#     u'csDiffPerMinDeltas': {u'tenToTwenty': 0.9499999999999997,
#      u'twentyToThirty': -0.09999999999999964,
#      u'zeroToTen': 0.34999999999999964},
#     u'damageTakenDiffPerMinDeltas': {u'tenToTwenty': -182.79999999999995,
#      u'twentyToThirty': 275.54999999999995,
#      u'zeroToTen': 11.250000000000028},
#     u'damageTakenPerMinDeltas': {u'tenToTwenty': 512.9,
#      u'twentyToThirty': 918.3000000000001,
#      u'zeroToTen': 328.3},
#     u'goldPerMinDeltas': {u'tenToTwenty': 399.6,
#      u'twentyToThirty': 309.7,
#      u'zeroToTen': 233.89999999999998},
#     u'lane': u'BOTTOM',
#     u'role': u'DUO_SUPPORT',
#     u'xpDiffPerMinDeltas': {u'tenToTwenty': -38.04999999999998,
#      u'twentyToThirty': -225.5,
#      u'zeroToTen': 37.349999999999994},
#     u'xpPerMinDeltas': {u'tenToTwenty': 335.79999999999995,
#      u'twentyToThirty': 303.6,
#      u'zeroToTen': 246.5}}},
#   {u'championId': 51,
#    u'highestAchievedSeasonTier': u'DIAMOND',
#    u'masteries': [{u'masteryId': 6111, u'rank': 5},
#     {u'masteryId': 6122, u'rank': 1},
#     {u'masteryId': 6131, u'rank': 5},
#     {u'masteryId': 6141, u'rank': 1},
#     {u'masteryId': 6151, u'rank': 5},
#     {u'masteryId': 6161, u'rank': 1},
#     {u'masteryId': 6211, u'rank': 5},
#     {u'masteryId': 6223, u'rank': 1},
#     {u'masteryId': 6232, u'rank': 5},
#     {u'masteryId': 6241, u'rank': 1}],
#    u'participantId': 3,
#    u'runes': [{u'rank': 9, u'runeId': 5245},
#     {u'rank': 5, u'runeId': 5277},
#     {u'rank': 4, u'runeId': 5289},
#     {u'rank': 9, u'runeId': 5317},
#     {u'rank': 3, u'runeId': 5337}],
#    u'spell1Id': 7,
#    u'spell2Id': 4,
#    u'stats': {u'assists': 9,
#     u'champLevel': 15,
#     u'combatPlayerScore': 0,
#     u'deaths': 8,
#     u'doubleKills': 0,
#     u'firstBloodAssist': False,
#     u'firstBloodKill': False,
#     u'firstInhibitorAssist': True,
#     u'firstInhibitorKill': False,
#     u'firstTowerAssist': False,
#     u'firstTowerKill': False,
#     u'goldEarned': 12980,
#     u'goldSpent': 12000,
#     u'inhibitorKills': 0,
#     u'item0': 1055,
#     u'item1': 3035,
#     u'item2': 3006,
#     u'item3': 3085,
#     u'item4': 3094,
#     u'item5': 3031,
#     u'item6': 3363,
#     u'killingSprees': 1,
#     u'kills': 5,
#     u'largestCriticalStrike': 1332,
#     u'largestKillingSpree': 3,
#     u'largestMultiKill': 1,
#     u'magicDamageDealt': 2302,
#     u'magicDamageDealtToChampions': 642,
#     u'magicDamageTaken': 9870,
#     u'minionsKilled': 216,
#     u'neutralMinionsKilled': 24,
#     u'neutralMinionsKilledEnemyJungle': 12,
#     u'neutralMinionsKilledTeamJungle': 12,
#     u'objectivePlayerScore': 0,
#     u'pentaKills': 0,
#     u'physicalDamageDealt': 160723,
#     u'physicalDamageDealtToChampions': 14533,
#     u'physicalDamageTaken': 11105,
#     u'quadraKills': 0,
#     u'sightWardsBoughtInGame': 0,
#     u'totalDamageDealt': 164594,
#     u'totalDamageDealtToChampions': 15451,
#     u'totalDamageTaken': 21096,
#     u'totalHeal': 2996,
#     u'totalPlayerScore': 0,
#     u'totalScoreRank': 0,
#     u'totalTimeCrowdControlDealt': 124,
#     u'totalUnitsHealed': 4,
#     u'towerKills': 2,
#     u'tripleKills': 0,
#     u'trueDamageDealt': 1568,
#     u'trueDamageDealtToChampions': 276,
#     u'trueDamageTaken': 120,
#     u'unrealKills': 0,
#     u'visionWardsBoughtInGame': 2,
#     u'wardsKilled': 10,
#     u'wardsPlaced': 12,
#     u'winner': False},
#    u'teamId': 100,
#    u'timeline': {u'creepsPerMinDeltas': {u'tenToTwenty': 6.5,
#      u'twentyToThirty': 5.7,
#      u'zeroToTen': 7.0},
#     u'csDiffPerMinDeltas': {u'tenToTwenty': 0.9499999999999997,
#      u'twentyToThirty': -0.09999999999999964,
#      u'zeroToTen': 0.34999999999999964},
#     u'damageTakenDiffPerMinDeltas': {u'tenToTwenty': -182.79999999999995,
#      u'twentyToThirty': 275.54999999999995,
#      u'zeroToTen': 11.250000000000028},
#     u'damageTakenPerMinDeltas': {u'tenToTwenty': 731.0,
#      u'twentyToThirty': 584.4,
#      u'zeroToTen': 353.9},
#     u'goldPerMinDeltas': {u'tenToTwenty': 411.9,
#      u'twentyToThirty': 408.0,
#      u'zeroToTen': 309.3},
#     u'lane': u'BOTTOM',
#     u'role': u'DUO_CARRY',
#     u'xpDiffPerMinDeltas': {u'tenToTwenty': -38.04999999999998,
#      u'twentyToThirty': -225.5,
#      u'zeroToTen': 37.349999999999994},
#     u'xpPerMinDeltas': {u'tenToTwenty': 422.1,
#      u'twentyToThirty': 476.6,
#      u'zeroToTen': 317.79999999999995}}},
#   {u'championId': 203,
#    u'highestAchievedSeasonTier': u'DIAMOND',
#    u'masteries': [{u'masteryId': 6111, u'rank': 5},
#     {u'masteryId': 6121, u'rank': 1},
#     {u'masteryId': 6131, u'rank': 5},
#     {u'masteryId': 6142, u'rank': 1},
#     {u'masteryId': 6312, u'rank': 5},
#     {u'masteryId': 6322, u'rank': 1},
#     {u'masteryId': 6331, u'rank': 5},
#     {u'masteryId': 6341, u'rank': 1},
#     {u'masteryId': 6351, u'rank': 5},
#     {u'masteryId': 6362, u'rank': 1}],
#    u'participantId': 4,
#    u'runes': [{u'rank': 9, u'runeId': 5245},
#     {u'rank': 9, u'runeId': 5289},
#     {u'rank': 9, u'runeId': 5317},
#     {u'rank': 3, u'runeId': 5337}],
#    u'spell1Id': 4,
#    u'spell2Id': 11,
#    u'stats': {u'assists': 12,
#     u'champLevel': 15,
#     u'combatPlayerScore': 0,
#     u'deaths': 10,
#     u'doubleKills': 0,
#     u'firstBloodAssist': False,
#     u'firstBloodKill': True,
#     u'firstInhibitorAssist': True,
#     u'firstInhibitorKill': False,
#     u'firstTowerAssist': False,
#     u'firstTowerKill': False,
#     u'goldEarned': 12667,
#     u'goldSpent': 11700,
#     u'inhibitorKills': 0,
#     u'item0': 1419,
#     u'item1': 3071,
#     u'item2': 3085,
#     u'item3': 1043,
#     u'item4': 3006,
#     u'item5': 1053,
#     u'item6': 3340,
#     u'killingSprees': 1,
#     u'kills': 5,
#     u'largestCriticalStrike': 320,
#     u'largestKillingSpree': 2,
#     u'largestMultiKill': 1,
#     u'magicDamageDealt': 5459,
#     u'magicDamageDealtToChampions': 1205,
#     u'magicDamageTaken': 15323,
#     u'minionsKilled': 46,
#     u'neutralMinionsKilled': 96,
#     u'neutralMinionsKilledEnemyJungle': 23,
#     u'neutralMinionsKilledTeamJungle': 73,
#     u'objectivePlayerScore': 0,
#     u'pentaKills': 0,
#     u'physicalDamageDealt': 142505,
#     u'physicalDamageDealtToChampions': 15413,
#     u'physicalDamageTaken': 17207,
#     u'quadraKills': 0,
#     u'sightWardsBoughtInGame': 0,
#     u'totalDamageDealt': 154899,
#     u'totalDamageDealtToChampions': 18657,
#     u'totalDamageTaken': 32928,
#     u'totalHeal': 11330,
#     u'totalPlayerScore': 0,
#     u'totalScoreRank': 0,
#     u'totalTimeCrowdControlDealt': 335,
#     u'totalUnitsHealed': 20,
#     u'towerKills': 1,
#     u'tripleKills': 0,
#     u'trueDamageDealt': 6934,
#     u'trueDamageDealtToChampions': 2038,
#     u'trueDamageTaken': 398,
#     u'unrealKills': 0,
#     u'visionWardsBoughtInGame': 3,
#     u'wardsKilled': 5,
#     u'wardsPlaced': 18,
#     u'winner': False},
#    u'teamId': 100,
#    u'timeline': {u'creepsPerMinDeltas': {u'tenToTwenty': 1.4,
#      u'twentyToThirty': 0.6,
#      u'zeroToTen': 0.30000000000000004},
#     u'damageTakenPerMinDeltas': {u'tenToTwenty': 1013.5,
#      u'twentyToThirty': 1139.4,
#      u'zeroToTen': 600.6},
#     u'goldPerMinDeltas': {u'tenToTwenty': 403.5,
#      u'twentyToThirty': 386.4,
#      u'zeroToTen': 292.4},
#     u'lane': u'JUNGLE',
#     u'role': u'NONE',
#     u'xpPerMinDeltas': {u'tenToTwenty': 491.2,
#      u'twentyToThirty': 409.5,
#      u'zeroToTen': 346.7}}},
#   {u'championId': 39,
#    u'highestAchievedSeasonTier': u'MASTER',
#    u'masteries': [{u'masteryId': 6111, u'rank': 5},
#     {u'masteryId': 6121, u'rank': 1},
#     {u'masteryId': 6131, u'rank': 5},
#     {u'masteryId': 6142, u'rank': 1},
#     {u'masteryId': 6151, u'rank': 5},
#     {u'masteryId': 6162, u'rank': 1},
#     {u'masteryId': 6211, u'rank': 5},
#     {u'masteryId': 6223, u'rank': 1},
#     {u'masteryId': 6232, u'rank': 5},
#     {u'masteryId': 6241, u'rank': 1}],
#    u'participantId': 5,
#    u'runes': [{u'rank': 9, u'runeId': 5245},
#     {u'rank': 3, u'runeId': 5289},
#     {u'rank': 6, u'runeId': 5296},
#     {u'rank': 9, u'runeId': 5316},
#     {u'rank': 3, u'runeId': 5337}],
#    u'spell1Id': 4,
#    u'spell2Id': 12,
#    u'stats': {u'assists': 4,
#     u'champLevel': 17,
#     u'combatPlayerScore': 0,
#     u'deaths': 7,
#     u'doubleKills': 1,
#     u'firstBloodAssist': False,
#     u'firstBloodKill': False,
#     u'firstInhibitorAssist': False,
#     u'firstInhibitorKill': True,
#     u'firstTowerAssist': False,
#     u'firstTowerKill': True,
#     u'goldEarned': 14651,
#     u'goldSpent': 14183,
#     u'inhibitorKills': 1,
#     u'item0': 3143,
#     u'item1': 3078,
#     u'item2': 3142,
#     u'item3': 3742,
#     u'item4': 3111,
#     u'item5': 0,
#     u'item6': 3340,
#     u'killingSprees': 3,
#     u'kills': 9,
#     u'largestCriticalStrike': 0,
#     u'largestKillingSpree': 3,
#     u'largestMultiKill': 2,
#     u'magicDamageDealt': 2136,
#     u'magicDamageDealtToChampions': 1877,
#     u'magicDamageTaken': 17548,
#     u'minionsKilled': 245,
#     u'neutralMinionsKilled': 10,
#     u'neutralMinionsKilledEnemyJungle': 7,
#     u'neutralMinionsKilledTeamJungle': 3,
#     u'objectivePlayerScore': 0,
#     u'pentaKills': 0,
#     u'physicalDamageDealt': 146616,
#     u'physicalDamageDealtToChampions': 20047,
#     u'physicalDamageTaken': 20059,
#     u'quadraKills': 0,
#     u'sightWardsBoughtInGame': 0,
#     u'totalDamageDealt': 171704,
#     u'totalDamageDealtToChampions': 27089,
#     u'totalDamageTaken': 38104,
#     u'totalHeal': 8285,
#     u'totalPlayerScore': 0,
#     u'totalScoreRank': 0,
#     u'totalTimeCrowdControlDealt': 530,
#     u'totalUnitsHealed': 1,
#     u'towerKills': 1,
#     u'tripleKills': 0,
#     u'trueDamageDealt': 22952,
#     u'trueDamageDealtToChampions': 5164,
#     u'trueDamageTaken': 496,
#     u'unrealKills': 0,
#     u'visionWardsBoughtInGame': 2,
#     u'wardsKilled': 2,
#     u'wardsPlaced': 14,
#     u'winner': False},
#    u'teamId': 100,
#    u'timeline': {u'creepsPerMinDeltas': {u'tenToTwenty': 8.5,
#      u'twentyToThirty': 6.6,
#      u'zeroToTen': 8.6},
#     u'csDiffPerMinDeltas': {u'tenToTwenty': 0.2999999999999998,
#      u'twentyToThirty': -0.5000000000000004,
#      u'zeroToTen': 1.6999999999999997},
#     u'damageTakenDiffPerMinDeltas': {u'tenToTwenty': 638.8,
#      u'twentyToThirty': 511.09999999999997,
#      u'zeroToTen': 99.8},
#     u'damageTakenPerMinDeltas': {u'tenToTwenty': 1220.4,
#      u'twentyToThirty': 1241.6999999999998,
#      u'zeroToTen': 537.5},
#     u'goldPerMinDeltas': {u'tenToTwenty': 487.70000000000005,
#      u'twentyToThirty': 503.5,
#      u'zeroToTen': 351.5},
#     u'lane': u'TOP',
#     u'role': u'SOLO',
#     u'xpDiffPerMinDeltas': {u'tenToTwenty': 41.89999999999998,
#      u'twentyToThirty': 86.5,
#      u'zeroToTen': 94.30000000000001},
#     u'xpPerMinDeltas': {u'tenToTwenty': 577.7,
#      u'twentyToThirty': 641.4,
#      u'zeroToTen': 512.7}}},
#   {u'championId': 64,
#    u'highestAchievedSeasonTier': u'DIAMOND',
#    u'masteries': [{u'masteryId': 6111, u'rank': 5},
#     {u'masteryId': 6121, u'rank': 1},
#     {u'masteryId': 6134, u'rank': 5},
#     {u'masteryId': 6142, u'rank': 1},
#     {u'masteryId': 6312, u'rank': 5},
#     {u'masteryId': 6323, u'rank': 1},
#     {u'masteryId': 6331, u'rank': 5},
#     {u'masteryId': 6341, u'rank': 1},
#     {u'masteryId': 6351, u'rank': 5},
#     {u'masteryId': 6362, u'rank': 1}],
#    u'participantId': 6,
#    u'runes': [{u'rank': 8, u'runeId': 5245},
#     {u'rank': 1, u'runeId': 5247},
#     {u'rank': 2, u'runeId': 5277},
#     {u'rank': 1, u'runeId': 5287},
#     {u'rank': 6, u'runeId': 5289},
#     {u'rank': 9, u'runeId': 5316},
#     {u'rank': 2, u'runeId': 5337},
#     {u'rank': 1, u'runeId': 5347}],
#    u'spell1Id': 11,
#    u'spell2Id': 4,
#    u'stats': {u'assists': 9,
#     u'champLevel': 17,
#     u'combatPlayerScore': 0,
#     u'deaths': 6,
#     u'doubleKills': 1,
#     u'firstBloodAssist': False,
#     u'firstBloodKill': False,
#     u'firstInhibitorAssist': False,
#     u'firstInhibitorKill': False,
#     u'firstTowerAssist': False,
#     u'firstTowerKill': False,
#     u'goldEarned': 15302,
#     u'goldSpent': 14850,
#     u'inhibitorKills': 0,
#     u'item0': 3026,
#     u'item1': 3071,
#     u'item2': 2045,
#     u'item3': 3047,
#     u'item4': 3742,
#     u'item5': 1412,
#     u'item6': 3364,
#     u'killingSprees': 4,
#     u'kills': 13,
#     u'largestCriticalStrike': 0,
#     u'largestKillingSpree': 3,
#     u'largestMultiKill': 2,
#     u'magicDamageDealt': 25430,
#     u'magicDamageDealtToChampions': 3428,
#     u'magicDamageTaken': 9209,
#     u'minionsKilled': 37,
#     u'neutralMinionsKilled': 112,
#     u'neutralMinionsKilledEnemyJungle': 52,
#     u'neutralMinionsKilledTeamJungle': 60,
#     u'objectivePlayerScore': 0,
#     u'pentaKills': 0,
#     u'physicalDamageDealt': 130194,
#     u'physicalDamageDealtToChampions': 17912,
#     u'physicalDamageTaken': 26543,
#     u'quadraKills': 0,
#     u'sightWardsBoughtInGame': 0,
#     u'totalDamageDealt': 165404,
#     u'totalDamageDealtToChampions': 22124,
#     u'totalDamageTaken': 38154,
#     u'totalHeal': 10724,
#     u'totalPlayerScore': 0,
#     u'totalScoreRank': 0,
#     u'totalTimeCrowdControlDealt': 837,
#     u'totalUnitsHealed': 1,
#     u'towerKills': 1,
#     u'tripleKills': 0,
#     u'trueDamageDealt': 9778,
#     u'trueDamageDealtToChampions': 784,
#     u'trueDamageTaken': 2401,
#     u'unrealKills': 0,
#     u'visionWardsBoughtInGame': 1,
#     u'wardsKilled': 10,
#     u'wardsPlaced': 23,
#     u'winner': True},
#    u'teamId': 200,
#    u'timeline': {u'creepsPerMinDeltas': {u'tenToTwenty': 1.2,
#      u'twentyToThirty': 1.0,
#      u'zeroToTen': 0.7},
#     u'damageTakenPerMinDeltas': {u'tenToTwenty': 957.4000000000001,
#      u'twentyToThirty': 1351.5,
#      u'zeroToTen': 683.2},
#     u'goldPerMinDeltas': {u'tenToTwenty': 513.4,
#      u'twentyToThirty': 377.4,
#      u'zeroToTen': 335.70000000000005},
#     u'lane': u'MIDDLE',
#     u'role': u'DUO_SUPPORT',
#     u'xpPerMinDeltas': {u'tenToTwenty': 621.4,
#      u'twentyToThirty': 546.6,
#      u'zeroToTen': 340.8}}},
#   {u'championId': 202,
#    u'highestAchievedSeasonTier': u'CHALLENGER',
#    u'masteries': [{u'masteryId': 6111, u'rank': 5},
#     {u'masteryId': 6121, u'rank': 1},
#     {u'masteryId': 6131, u'rank': 3},
#     {u'masteryId': 6134, u'rank': 2},
#     {u'masteryId': 6143, u'rank': 1},
#     {u'masteryId': 6151, u'rank': 5},
#     {u'masteryId': 6164, u'rank': 1},
#     {u'masteryId': 6312, u'rank': 5},
#     {u'masteryId': 6322, u'rank': 1},
#     {u'masteryId': 6331, u'rank': 5},
#     {u'masteryId': 6343, u'rank': 1}],
#    u'participantId': 7,
#    u'runes': [{u'rank': 9, u'runeId': 5245},
#     {u'rank': 9, u'runeId': 5289},
#     {u'rank': 9, u'runeId': 5317},
#     {u'rank': 3, u'runeId': 5335}],
#    u'spell1Id': 4,
#    u'spell2Id': 7,
#    u'stats': {u'assists': 15,
#     u'champLevel': 17,
#     u'combatPlayerScore': 0,
#     u'deaths': 7,
#     u'doubleKills': 1,
#     u'firstBloodAssist': False,
#     u'firstBloodKill': False,
#     u'firstInhibitorAssist': False,
#     u'firstInhibitorKill': False,
#     u'firstTowerAssist': False,
#     u'firstTowerKill': False,
#     u'goldEarned': 15947,
#     u'goldSpent': 15125,
#     u'inhibitorKills': 0,
#     u'item0': 3508,
#     u'item1': 3139,
#     u'item2': 3094,
#     u'item3': 3009,
#     u'item4': 0,
#     u'item5': 3031,
#     u'item6': 3363,
#     u'killingSprees': 2,
#     u'kills': 10,
#     u'largestCriticalStrike': 2461,
#     u'largestKillingSpree': 4,
#     u'largestMultiKill': 2,
#     u'magicDamageDealt': 22548,
#     u'magicDamageDealtToChampions': 5727,
#     u'magicDamageTaken': 3797,
#     u'minionsKilled': 213,
#     u'neutralMinionsKilled': 13,
#     u'neutralMinionsKilledEnemyJungle': 5,
#     u'neutralMinionsKilledTeamJungle': 8,
#     u'objectivePlayerScore': 0,
#     u'pentaKills': 0,
#     u'physicalDamageDealt': 179735,
#     u'physicalDamageDealtToChampions': 20509,
#     u'physicalDamageTaken': 14708,
#     u'quadraKills': 0,
#     u'sightWardsBoughtInGame': 0,
#     u'totalDamageDealt': 206655,
#     u'totalDamageDealtToChampions': 26680,
#     u'totalDamageTaken': 19760,
#     u'totalHeal': 4363,
#     u'totalPlayerScore': 0,
#     u'totalScoreRank': 0,
#     u'totalTimeCrowdControlDealt': 479,
#     u'totalUnitsHealed': 4,
#     u'towerKills': 1,
#     u'tripleKills': 0,
#     u'trueDamageDealt': 4371,
#     u'trueDamageDealtToChampions': 444,
#     u'trueDamageTaken': 1255,
#     u'unrealKills': 0,
#     u'visionWardsBoughtInGame': 1,
#     u'wardsKilled': 4,
#     u'wardsPlaced': 13,
#     u'winner': True},
#    u'teamId': 200,
#    u'timeline': {u'creepsPerMinDeltas': {u'tenToTwenty': 6.1,
#      u'twentyToThirty': 7.199999999999999,
#      u'zeroToTen': 6.7},
#     u'csDiffPerMinDeltas': {u'tenToTwenty': -0.9499999999999997,
#      u'twentyToThirty': 0.09999999999999964,
#      u'zeroToTen': -0.34999999999999964},
#     u'damageTakenDiffPerMinDeltas': {u'tenToTwenty': 182.79999999999995,
#      u'twentyToThirty': -275.54999999999995,
#      u'zeroToTen': -11.250000000000028},
#     u'damageTakenPerMinDeltas': {u'tenToTwenty': 773.0,
#      u'twentyToThirty': 491.90000000000003,
#      u'zeroToTen': 344.2},
#     u'goldPerMinDeltas': {u'tenToTwenty': 466.8,
#      u'twentyToThirty': 560.7,
#      u'zeroToTen': 265.4},
#     u'lane': u'BOTTOM',
#     u'role': u'DUO_CARRY',
#     u'xpDiffPerMinDeltas': {u'tenToTwenty': 38.04999999999998,
#      u'twentyToThirty': 225.5,
#      u'zeroToTen': -37.349999999999994},
#     u'xpPerMinDeltas': {u'tenToTwenty': 498.2,
#      u'twentyToThirty': 691.8,
#      u'zeroToTen': 284.5}}},
#   {u'championId': 61,
#    u'highestAchievedSeasonTier': u'MASTER',
#    u'masteries': [{u'masteryId': 6114, u'rank': 5},
#     {u'masteryId': 6122, u'rank': 1},
#     {u'masteryId': 6131, u'rank': 1},
#     {u'masteryId': 6134, u'rank': 4},
#     {u'masteryId': 6141, u'rank': 1},
#     {u'masteryId': 6312, u'rank': 5},
#     {u'masteryId': 6323, u'rank': 1},
#     {u'masteryId': 6331, u'rank': 4},
#     {u'masteryId': 6332, u'rank': 1},
#     {u'masteryId': 6343, u'rank': 1},
#     {u'masteryId': 6351, u'rank': 5},
#     {u'masteryId': 6362, u'rank': 1}],
#    u'participantId': 8,
#    u'runes': [{u'rank': 9, u'runeId': 5273},
#     {u'rank': 3, u'runeId': 5289},
#     {u'rank': 6, u'runeId': 5296},
#     {u'rank': 9, u'runeId': 5316},
#     {u'rank': 3, u'runeId': 5357}],
#    u'spell1Id': 6,
#    u'spell2Id': 4,
#    u'stats': {u'assists': 13,
#     u'champLevel': 18,
#     u'combatPlayerScore': 0,
#     u'deaths': 6,
#     u'doubleKills': 1,
#     u'firstBloodAssist': False,
#     u'firstBloodKill': False,
#     u'firstInhibitorAssist': False,
#     u'firstInhibitorKill': False,
#     u'firstTowerAssist': False,
#     u'firstTowerKill': False,
#     u'goldEarned': 16815,
#     u'goldSpent': 15450,
#     u'inhibitorKills': 1,
#     u'item0': 3089,
#     u'item1': 3001,
#     u'item2': 3165,
#     u'item3': 3020,
#     u'item4': 3151,
#     u'item5': 1026,
#     u'item6': 3363,
#     u'killingSprees': 3,
#     u'kills': 10,
#     u'largestCriticalStrike': 0,
#     u'largestKillingSpree': 5,
#     u'largestMultiKill': 2,
#     u'magicDamageDealt': 185939,
#     u'magicDamageDealtToChampions': 19548,
#     u'magicDamageTaken': 4360,
#     u'minionsKilled': 257,
#     u'neutralMinionsKilled': 14,
#     u'neutralMinionsKilledEnemyJungle': 7,
#     u'neutralMinionsKilledTeamJungle': 7,
#     u'objectivePlayerScore': 0,
#     u'pentaKills': 0,
#     u'physicalDamageDealt': 22883,
#     u'physicalDamageDealtToChampions': 674,
#     u'physicalDamageTaken': 11702,
#     u'quadraKills': 0,
#     u'sightWardsBoughtInGame': 0,
#     u'totalDamageDealt': 212001,
#     u'totalDamageDealtToChampions': 20279,
#     u'totalDamageTaken': 17789,
#     u'totalHeal': 2059,
#     u'totalPlayerScore': 0,
#     u'totalScoreRank': 0,
#     u'totalTimeCrowdControlDealt': 1151,
#     u'totalUnitsHealed': 1,
#     u'towerKills': 2,
#     u'tripleKills': 0,
#     u'trueDamageDealt': 3179,
#     u'trueDamageDealtToChampions': 56,
#     u'trueDamageTaken': 1725,
#     u'unrealKills': 0,
#     u'visionWardsBoughtInGame': 4,
#     u'wardsKilled': 5,
#     u'wardsPlaced': 14,
#     u'winner': True},
#    u'teamId': 200,
#    u'timeline': {u'creepsPerMinDeltas': {u'tenToTwenty': 8.8,
#      u'twentyToThirty': 6.4,
#      u'zeroToTen': 8.0},
#     u'damageTakenPerMinDeltas': {u'tenToTwenty': 697.7,
#      u'twentyToThirty': 791.6,
#      u'zeroToTen': 198.5},
#     u'goldPerMinDeltas': {u'tenToTwenty': 606.5999999999999,
#      u'twentyToThirty': 441.59999999999997,
#      u'zeroToTen': 291.1},
#     u'lane': u'MIDDLE',
#     u'role': u'DUO_CARRY',
#     u'xpPerMinDeltas': {u'tenToTwenty': 675.3,
#      u'twentyToThirty': 534.9,
#      u'zeroToTen': 440.29999999999995}}},
#   {u'championId': 57,
#    u'highestAchievedSeasonTier': u'MASTER',
#    u'masteries': [{u'masteryId': 6114, u'rank': 5},
#     {u'masteryId': 6122, u'rank': 1},
#     {u'masteryId': 6134, u'rank': 5},
#     {u'masteryId': 6143, u'rank': 1},
#     {u'masteryId': 6211, u'rank': 5},
#     {u'masteryId': 6223, u'rank': 1},
#     {u'masteryId': 6231, u'rank': 5},
#     {u'masteryId': 6241, u'rank': 1},
#     {u'masteryId': 6251, u'rank': 5},
#     {u'masteryId': 6262, u'rank': 1}],
#    u'participantId': 9,
#    u'runes': [{u'rank': 9, u'runeId': 5273},
#     {u'rank': 3, u'runeId': 5289},
#     {u'rank': 6, u'runeId': 5297},
#     {u'rank': 9, u'runeId': 5315},
#     {u'rank': 2, u'runeId': 5347},
#     {u'rank': 1, u'runeId': 5357}],
#    u'spell1Id': 4,
#    u'spell2Id': 12,
#    u'stats': {u'assists': 6,
#     u'champLevel': 17,
#     u'combatPlayerScore': 0,
#     u'deaths': 3,
#     u'doubleKills': 0,
#     u'firstBloodAssist': False,
#     u'firstBloodKill': False,
#     u'firstInhibitorAssist': False,
#     u'firstInhibitorKill': False,
#     u'firstTowerAssist': False,
#     u'firstTowerKill': False,
#     u'goldEarned': 14189,
#     u'goldSpent': 13575,
#     u'inhibitorKills': 0,
#     u'item0': 1056,
#     u'item1': 3742,
#     u'item2': 3026,
#     u'item3': 3068,
#     u'item4': 3047,
#     u'item5': 3065,
#     u'item6': 3340,
#     u'killingSprees': 1,
#     u'kills': 4,
#     u'largestCriticalStrike': 0,
#     u'largestKillingSpree': 2,
#     u'largestMultiKill': 1,
#     u'magicDamageDealt': 134648,
#     u'magicDamageDealtToChampions': 12951,
#     u'magicDamageTaken': 4054,
#     u'minionsKilled': 235,
#     u'neutralMinionsKilled': 1,
#     u'neutralMinionsKilledEnemyJungle': 1,
#     u'neutralMinionsKilledTeamJungle': 0,
#     u'objectivePlayerScore': 0,
#     u'pentaKills': 0,
#     u'physicalDamageDealt': 25141,
#     u'physicalDamageDealtToChampions': 3057,
#     u'physicalDamageTaken': 14513,
#     u'quadraKills': 0,
#     u'sightWardsBoughtInGame': 0,
#     u'totalDamageDealt': 161190,
#     u'totalDamageDealtToChampions': 16204,
#     u'totalDamageTaken': 21075,
#     u'totalHeal': 5972,
#     u'totalPlayerScore': 0,
#     u'totalScoreRank': 0,
#     u'totalTimeCrowdControlDealt': 740,
#     u'totalUnitsHealed': 1,
#     u'towerKills': 2,
#     u'tripleKills': 0,
#     u'trueDamageDealt': 1399,
#     u'trueDamageDealtToChampions': 196,
#     u'trueDamageTaken': 2508,
#     u'unrealKills': 0,
#     u'visionWardsBoughtInGame': 1,
#     u'wardsKilled': 1,
#     u'wardsPlaced': 15,
#     u'winner': True},
#    u'teamId': 200,
#    u'timeline': {u'creepsPerMinDeltas': {u'tenToTwenty': 8.2,
#      u'twentyToThirty': 7.1,
#      u'zeroToTen': 6.9},
#     u'csDiffPerMinDeltas': {u'tenToTwenty': -0.2999999999999998,
#      u'twentyToThirty': 0.5000000000000004,
#      u'zeroToTen': -1.6999999999999997},
#     u'damageTakenDiffPerMinDeltas': {u'tenToTwenty': -638.8,
#      u'twentyToThirty': -511.09999999999997,
#      u'zeroToTen': -99.8},
#     u'damageTakenPerMinDeltas': {u'tenToTwenty': 581.6,
#      u'twentyToThirty': 730.5999999999999,
#      u'zeroToTen': 437.7},
#     u'goldPerMinDeltas': {u'tenToTwenty': 425.0,
#      u'twentyToThirty': 482.79999999999995,
#      u'zeroToTen': 233.0},
#     u'lane': u'TOP',
#     u'role': u'SOLO',
#     u'xpDiffPerMinDeltas': {u'tenToTwenty': -41.89999999999998,
#      u'twentyToThirty': -86.5,
#      u'zeroToTen': -94.30000000000001},
#     u'xpPerMinDeltas': {u'tenToTwenty': 535.8,
#      u'twentyToThirty': 554.9,
#      u'zeroToTen': 418.4}}},
#   {u'championId': 143,
#    u'highestAchievedSeasonTier': u'DIAMOND',
#    u'masteries': [{u'masteryId': 6211, u'rank': 5},
#     {u'masteryId': 6221, u'rank': 1},
#     {u'masteryId': 6232, u'rank': 5},
#     {u'masteryId': 6241, u'rank': 1},
#     {u'masteryId': 6311, u'rank': 5},
#     {u'masteryId': 6322, u'rank': 1},
#     {u'masteryId': 6332, u'rank': 5},
#     {u'masteryId': 6342, u'rank': 1},
#     {u'masteryId': 6351, u'rank': 5},
#     {u'masteryId': 6362, u'rank': 1}],
#    u'participantId': 10,
#    u'runes': [{u'rank': 9, u'runeId': 5273},
#     {u'rank': 6, u'runeId': 5296},
#     {u'rank': 3, u'runeId': 5298},
#     {u'rank': 9, u'runeId': 5317},
#     {u'rank': 3, u'runeId': 5357}],
#    u'spell1Id': 4,
#    u'spell2Id': 3,
#    u'stats': {u'assists': 15,
#     u'champLevel': 15,
#     u'combatPlayerScore': 0,
#     u'deaths': 7,
#     u'doubleKills': 0,
#     u'firstBloodAssist': False,
#     u'firstBloodKill': False,
#     u'firstInhibitorAssist': False,
#     u'firstInhibitorKill': False,
#     u'firstTowerAssist': False,
#     u'firstTowerKill': False,
#     u'goldEarned': 11704,
#     u'goldSpent': 10025,
#     u'inhibitorKills': 0,
#     u'item0': 3020,
#     u'item1': 3151,
#     u'item2': 2301,
#     u'item3': 2055,
#     u'item4': 3116,
#     u'item5': 0,
#     u'item6': 3364,
#     u'killingSprees': 1,
#     u'kills': 2,
#     u'largestCriticalStrike': 0,
#     u'largestKillingSpree': 2,
#     u'largestMultiKill': 1,
#     u'magicDamageDealt': 34435,
#     u'magicDamageDealtToChampions': 21882,
#     u'magicDamageTaken': 7440,
#     u'minionsKilled': 21,
#     u'neutralMinionsKilled': 1,
#     u'neutralMinionsKilledEnemyJungle': 0,
#     u'neutralMinionsKilledTeamJungle': 1,
#     u'objectivePlayerScore': 0,
#     u'pentaKills': 0,
#     u'physicalDamageDealt': 3689,
#     u'physicalDamageDealtToChampions': 1360,
#     u'physicalDamageTaken': 11535,
#     u'quadraKills': 0,
#     u'sightWardsBoughtInGame': 0,
#     u'totalDamageDealt': 39116,
#     u'totalDamageDealtToChampions': 23242,
#     u'totalDamageTaken': 19564,
#     u'totalHeal': 2656,
#     u'totalPlayerScore': 0,
#     u'totalScoreRank': 0,
#     u'totalTimeCrowdControlDealt': 366,
#     u'totalUnitsHealed': 5,
#     u'towerKills': 0,
#     u'tripleKills': 0,
#     u'trueDamageDealt': 991,
#     u'trueDamageDealtToChampions': 0,
#     u'trueDamageTaken': 588,
#     u'unrealKills': 0,
#     u'visionWardsBoughtInGame': 7,
#     u'wardsKilled': 10,
#     u'wardsPlaced': 34,
#     u'winner': True},
#    u'teamId': 200,
#    u'timeline': {u'creepsPerMinDeltas': {u'tenToTwenty': 0.6000000000000001,
#      u'twentyToThirty': 0.4,
#      u'zeroToTen': 0.6000000000000001},
#     u'csDiffPerMinDeltas': {u'tenToTwenty': -0.9499999999999997,
#      u'twentyToThirty': 0.09999999999999964,
#      u'zeroToTen': -0.34999999999999964},
#     u'damageTakenDiffPerMinDeltas': {u'tenToTwenty': 182.79999999999995,
#      u'twentyToThirty': -275.54999999999995,
#      u'zeroToTen': -11.250000000000028},
#     u'damageTakenPerMinDeltas': {u'tenToTwenty': 836.5,
#      u'twentyToThirty': 459.70000000000005,
#      u'zeroToTen': 315.5},
#     u'goldPerMinDeltas': {u'tenToTwenty': 308.4,
#      u'twentyToThirty': 370.0,
#      u'zeroToTen': 163.6},
#     u'lane': u'BOTTOM',
#     u'role': u'DUO_SUPPORT',
#     u'xpDiffPerMinDeltas': {u'tenToTwenty': 38.04999999999998,
#      u'twentyToThirty': 225.5,
#      u'zeroToTen': -37.349999999999994},
#     u'xpPerMinDeltas': {u'tenToTwenty': 335.8,
#      u'twentyToThirty': 539.4,
#      u'zeroToTen': 205.1}}}],
#  u'platformId': u'NA1',
#  u'queueType': u'TEAM_BUILDER_RANKED_SOLO',
#  u'region': u'NA',
#  u'season': u'PRESEASON2017',
#  u'teams': [{u'bans': [{u'championId': 7, u'pickTurn': 1},
#     {u'championId': 164, u'pickTurn': 3},
#     {u'championId': 427, u'pickTurn': 5}],
#    u'baronKills': 0,
#    u'dominionVictoryScore': 0,
#    u'dragonKills': 1,
#    u'firstBaron': False,
#    u'firstBlood': True,
#    u'firstDragon': True,
#    u'firstInhibitor': True,
#    u'firstRiftHerald': False,
#    u'firstTower': True,
#    u'inhibitorKills': 1,
#    u'riftHeraldKills': 0,
#    u'teamId': 100,
#    u'towerKills': 5,
#    u'vilemawKills': 0,
#    u'winner': False},
#   {u'bans': [{u'championId': 107, u'pickTurn': 2},
#     {u'championId': 121, u'pickTurn': 4},
#     {u'championId': 13, u'pickTurn': 6}],
#    u'baronKills': 2,
#    u'dominionVictoryScore': 0,
#    u'dragonKills': 3,
#    u'firstBaron': True,
#    u'firstBlood': False,
#    u'firstDragon': False,
#    u'firstInhibitor': False,
#    u'firstRiftHerald': False,
#    u'firstTower': False,
#    u'inhibitorKills': 1,
#    u'riftHeraldKills': 0,
#    u'teamId': 200,
#    u'towerKills': 10,
#    u'vilemawKills': 0,
#    u'winner': True}]}

# %%
loadMatch1.keys()

for key in loadMatch1.keys():
    print key

# %%
print loadMatch1['participantIdentities']

# %%
print loadMatch1['teams']

#{'matchid'},
team_col_header = ['firstDragon','bans','firstInhibitor','baronKills','firstRiftHerald','winner','firstBaron','riftheraldKills',
                  'firstBlood','teamId','firstTower','vilemawKills','inhibitorKills','towerKills','dominionVictoryScore',
                  'dragonKills']

#matchid=['2405647360']
firstDragon=[]
bans=[]
firstInhibitor=[]
baronKills=[]
firstRiftHerald=[]
winner=[]
firstBaron=[]
riftHeraldKills=[]
firstBlood=[]
teamId=[]
firstTower=[]
vilemawKills=[]
inhibitorKills=[]
towerKills=[]
dominionVictoryScore=[]
dragonKills=[]

for teams in loadMatch1['teams']:
    firstDragon.append(teams[u'firstDragon'])
    bans.append(teams[u'bans'])
    firstInhibitor.append(teams[u'firstInhibitor'])
    baronKills.append(teams[u'baronKills'])
    firstRiftHerald.append(teams[u'firstRiftHerald'])
    winner.append(teams[u'winner'])
    firstBaron.append(teams[u'firstBaron'])
    riftHeraldKills.append(teams[u'riftHeraldKills'])
    firstBlood.append(teams[u'firstBlood'])
    teamId.append(teams[u'teamId'])
    firstTower.append(teams[u'firstTower'])
    vilemawKills.append(teams[u'vilemawKills'])
    inhibitorKills.append(teams[u'inhibitorKills'])
    towerKills.append(teams[u'towerKills'])
    dominionVictoryScore.append(teams[u'dominionVictoryScore'])
    dragonKills.append(teams[u'dragonKills'])
    
dfMatch = pd.DataFrame([firstDragon,bans,firstInhibitor,baronKills,firstRiftHerald,winner,firstBaron,riftHeraldKills,
                  firstBlood,teamId,firstTower,vilemawKills,inhibitorKills,towerKills,dominionVictoryScore,
                  dragonKills]).T
# Out:
# [{u'firstDragon': True, u'bans': [{u'pickTurn': 1, u'championId': 7}, {u'pickTurn': 3, u'championId': 164}, {u'pickTurn': 5, u'championId': 427}], u'firstInhibitor': True, u'baronKills': 0, u'firstRiftHerald': False, u'winner': False, u'firstBaron': False, u'riftHeraldKills': 0, u'firstBlood': True, u'teamId': 100, u'firstTower': True, u'vilemawKills': 0, u'inhibitorKills': 1, u'towerKills': 5, u'dominionVictoryScore': 0, u'dragonKills': 1}, {u'firstDragon': False, u'bans': [{u'pickTurn': 2, u'championId': 107}, {u'pickTurn': 4, u'championId': 121}, {u'pickTurn': 6, u'championId': 13}], u'firstInhibitor': False, u'baronKills': 2, u'firstRiftHerald': False, u'winner': True, u'firstBaron': True, u'riftHeraldKills': 0, u'firstBlood': False, u'teamId': 200, u'firstTower': False, u'vilemawKills': 0, u'inhibitorKills': 1, u'towerKills': 10, u'dominionVictoryScore': 0, u'dragonKills': 3}]

# %%
print team_col_header
dfMatch

# %%
dfMatch.dtypes

# %%
with open('matchData1.csv', 'wb') as createcsv:
    create = csv.writer(createcsv)
    create.writerow(team_col_header)
    dfMatch.to_csv('matchData1.csv', index=False, encoding='utf-8')

# %%
matchData = pd.read_csv('matchData1.csv', header=0, names=team_col_header,na_filter=False)
matchData
# Out:
#   firstDragon                                               bans  \
# 0        True                                                  0
# 1       False  [{u'pickTurn': 2, u'championId': 107}, {u'pick...
#
#   firstInhibitor  baronKills firstRiftHerald winner firstBaron  \
# 0              1           5               0      1
# 1          False           2           False   True       True
#
#   riftheraldKills firstBlood teamId firstTower vilemawKills inhibitorKills  \
# 0
# 1               0      False    200      False            0              1
#
#   towerKills dominionVictoryScore dragonKills
# 0
# 1         10                    0           3

# %%
yo = pd.read_csv("match1.csv")

# %%
dfMatch.columns = ['firstDragon','bans','firstInhibitor','baronKills','firstRiftHerald','winner','firstBaron','riftheraldKills',
                  'firstBlood','teamId','firstTower','vilemawKills','inhibitorKills','towerKills','dominionVictoryScore',
                  'dragonKills']

dfMatch.T
# Out:
#                                                                       0  \
# firstDragon                                                        True
# bans                  [{u'pickTurn': 1, u'championId': 7}, {u'pickTu...
# firstInhibitor                                                     True
# baronKills                                                            0
# firstRiftHerald                                                   False
# winner                                                            False
# firstBaron                                                        False
# riftheraldKills                                                       0
# firstBlood                                                         True
# teamId                                                              100
# firstTower                                                         True
# vilemawKills                                                          0
# inhibitorKills                                                        1
# towerKills                                                            5
# dominionVictoryScore                                                  0
# dragonKills                                                           1
#
#                                                                       1
# firstDragon                                                       False
# bans                  [{u'pickTurn': 2, u'championId': 107}, {u'pick...
# firstInhibitor                                                    False
# baronKills                                                            2
# firstRiftHerald                                                   False
# winner                                                             True
# firstBaron                                                         True
# riftheraldKills                                                       0
# firstBlood                                                        False
# teamId                                                              200
# firstTower                                                        False
# vilemawKills                                                          0
# inhibitorKills                                                        1
# towerKills                                                           10
# dominionVictoryScore                                                  0
# dragonKills                                                           3
