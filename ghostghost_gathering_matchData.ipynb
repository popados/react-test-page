# %% [markdown]
# HELP!!!!!!!!! How do I put this data into a single sheet(I want each csv/sheet/whatever to be per player not per match) efficiently: 1 player; 11 matches; 2 teams per match; 14 features per team per match.
#
# [1:57]
# I could just take the team the player was on on and forget the other team
#
# [1:58]
# That should make it 1 player; 11 matches; 14 features and use the team id as a node for my model
#
# [1:59]
# I need to figure out how to add a new row for matchID? That should allow me to track the breaks in information so the same 14 features are separate each of the 11 times per match (edited)
#
# [2:04]
# I THINK THAT SHOULD DO IT! I needed to type to think it out haha. Make my csv have rows per matchID and then each column is the feature per match. However when making my model I want to use 5 players which means I need to use 5 separate csv files?

# %%
import json
import csv
import urllib2
import pandas as pd
from urllib2 import Request, urlopen
import numpy as np

matchList1 = pd.read_csv('matchList.csv')#ghostghost PlayerID:621
matchList1
# Out:
#     champion    lane     matchID platformID                     queue  region  \
# 0        154  JUNGLE  2414044482        NA1  TEAM_BUILDER_RANKED_SOLO     NaN
# 1          4     MID  2414052519        NA1  TEAM_BUILDER_RANKED_SOLO     NaN
# 2        154  JUNGLE  2413197247        NA1  TEAM_BUILDER_RANKED_SOLO     NaN
# 3        202  BOTTOM  2413213657        NA1  TEAM_BUILDER_RANKED_SOLO     NaN
# 4         51  BOTTOM  2413211846        NA1  TEAM_BUILDER_RANKED_SOLO     NaN
# 5          4     MID  2410883736        NA1  TEAM_BUILDER_RANKED_SOLO     NaN
# 6          4     MID  2410881353        NA1  TEAM_BUILDER_RANKED_SOLO     NaN
# 7          4     MID  2410749501        NA1  TEAM_BUILDER_RANKED_SOLO     NaN
# 8          4     MID  2410767351        NA1  TEAM_BUILDER_RANKED_SOLO     NaN
# 9          4     MID  2410774976        NA1  TEAM_BUILDER_RANKED_SOLO     NaN
# 10         4     MID  2407787433        NA1  TEAM_BUILDER_RANKED_SOLO     NaN
#
#          role         season      timestamp
# 0        NONE  PRESEASON2017  1485969645147
# 1        SOLO  PRESEASON2017  1485967390722
# 2        NONE  PRESEASON2017  1485884788791
# 3   DUO_CARRY  PRESEASON2017  1485881924665
# 4   DUO_CARRY  PRESEASON2017  1485879296159
# 5        SOLO  PRESEASON2017  1485624082554
# 6        SOLO  PRESEASON2017  1485622251093
# 7        SOLO  PRESEASON2017  1485620381751
# 8        SOLO  PRESEASON2017  1485618663676
# 9        SOLO  PRESEASON2017  1485616033220
# 10       SOLO  PRESEASON2017  1485305776502

# %%
matchID=[]

for n in list(np.unique(matchList1.matchID.values)):
    matchID.append(str(n))
    print str(n)
# Out:
# 2407787433
# 2410749501
# 2410767351
# 2410774976
# 2410881353
# 2410883736
# 2413197247
# 2413211846
# 2413213657
# 2414044482
# 2414052519

# %%
matchID[0]
# Out:
# '2407787433'

# %%
matchRequest =Request('https://na.api.pvp.net/api/lol/na/v2.2/match/'+matchID[0]+'?api_key=RGAPI-6b4e9139-2121-4820-8cd9-371891441c4b')
responseMatch = urlopen(matchRequest)
loadMatch = responseMatch.read()
matchData = json.loads(loadMatch)
matchData
# Out:
# {u'mapId': 11,
#  u'matchCreation': 1485305776502L,
#  u'matchDuration': 2056,
#  u'matchId': 2407787433L,
#  u'matchMode': u'CLASSIC',
#  u'matchType': u'MATCHED_GAME',
#  u'matchVersion': u'7.1.172.6393',
#  u'participantIdentities': [{u'participantId': 1,
#    u'player': {u'matchHistoryUri': u'/v1/stats/player_history/NA1/200626893',
#     u'profileIcon': 1441,
#     u'summonerId': 37558151,
#     u'summonerName': u'lnvalid Name'}},
#   {u'participantId': 2,
#    u'player': {u'matchHistoryUri': u'/v1/stats/player_history/NA1/200499050',
#     u'profileIcon': 1381,
#     u'summonerId': 37532228,
#     u'summonerName': u'rhubarbs'}},
#   {u'participantId': 3,
#    u'player': {u'matchHistoryUri': u'/v1/stats/player_history/NA1/48093906',
#     u'profileIcon': 936,
#     u'summonerId': 33359979,
#     u'summonerName': u'21 10'}},
#   {u'participantId': 4,
#    u'player': {u'matchHistoryUri': u'/v1/stats/player_history/NA1/201596793',
#     u'profileIcon': 1460,
#     u'summonerId': 38869932,
#     u'summonerName': u'really big meme'}},
#   {u'participantId': 5,
#    u'player': {u'matchHistoryUri': u'/v1/stats/player_history/NA1/209287319',
#     u'profileIcon': 603,
#     u'summonerId': 46239231,
#     u'summonerName': u'Hyorimaru'}},
#   {u'participantId': 6,
#    u'player': {u'matchHistoryUri': u'/v1/stats/player_history/NA/32971449',
#     u'profileIcon': 1467,
#     u'summonerId': 20132258,
#     u'summonerName': u'Doublelift'}},
#   {u'participantId': 7,
#    u'player': {u'matchHistoryUri': u'/v1/stats/player_history/NA/5766',
#     u'profileIcon': 20,
#     u'summonerId': 621,
#     u'summonerName': u'Ghost Ghost'}},
#   {u'participantId': 8,
#    u'player': {u'matchHistoryUri': u'/v1/stats/player_history/NA/34367796',
#     u'profileIcon': 1377,
#     u'summonerId': 21108632,
#     u'summonerName': u'GKyrios'}},
#   {u'participantId': 9,
#    u'player': {u'matchHistoryUri': u'/v1/stats/player_history/NA/40745212',
#     u'profileIcon': 1110,
#     u'summonerId': 26165051,
#     u'summonerName': u'Saucy Sells'}},
#   {u'participantId': 10,
#    u'player': {u'matchHistoryUri': u'/v1/stats/player_history/NA1/201041252',
#     u'profileIcon': 1160,
#     u'summonerId': 38529975,
#     u'summonerName': u'Eiyo'}}],
#  u'participants': [{u'championId': 22,
#    u'highestAchievedSeasonTier': u'DIAMOND',
#    u'masteries': [{u'masteryId': 6111, u'rank': 5},
#     {u'masteryId': 6122, u'rank': 1},
#     {u'masteryId': 6131, u'rank': 1},
#     {u'masteryId': 6134, u'rank': 4},
#     {u'masteryId': 6143, u'rank': 1},
#     {u'masteryId': 6151, u'rank': 5},
#     {u'masteryId': 6161, u'rank': 1},
#     {u'masteryId': 6211, u'rank': 5},
#     {u'masteryId': 6223, u'rank': 1},
#     {u'masteryId': 6231, u'rank': 5},
#     {u'masteryId': 6241, u'rank': 1}],
#    u'participantId': 1,
#    u'runes': [{u'rank': 9, u'runeId': 5245},
#     {u'rank': 9, u'runeId': 5290},
#     {u'rank': 9, u'runeId': 5317},
#     {u'rank': 1, u'runeId': 5335},
#     {u'rank': 2, u'runeId': 5337}],
#    u'spell1Id': 4,
#    u'spell2Id': 7,
#    u'stats': {u'assists': 13,
#     u'champLevel': 17,
#     u'combatPlayerScore': 0,
#     u'deaths': 5,
#     u'doubleKills': 0,
#     u'firstBloodAssist': False,
#     u'firstBloodKill': True,
#     u'firstInhibitorAssist': True,
#     u'firstInhibitorKill': False,
#     u'firstTowerAssist': False,
#     u'firstTowerKill': False,
#     u'goldEarned': 15360,
#     u'goldSpent': 14725,
#     u'inhibitorKills': 0,
#     u'item0': 3031,
#     u'item1': 3140,
#     u'item2': 3508,
#     u'item3': 3085,
#     u'item4': 3006,
#     u'item5': 3035,
#     u'item6': 3363,
#     u'killingSprees': 0,
#     u'kills': 2,
#     u'largestCriticalStrike': 799,
#     u'largestKillingSpree': 0,
#     u'largestMultiKill': 1,
#     u'magicDamageDealt': 3029,
#     u'magicDamageDealtToChampions': 2823,
#     u'magicDamageTaken': 7615,
#     u'minionsKilled': 247,
#     u'neutralMinionsKilled': 30,
#     u'neutralMinionsKilledEnemyJungle': 17,
#     u'neutralMinionsKilledTeamJungle': 13,
#     u'objectivePlayerScore': 0,
#     u'pentaKills': 0,
#     u'physicalDamageDealt': 193318,
#     u'physicalDamageDealtToChampions': 16803,
#     u'physicalDamageTaken': 12132,
#     u'quadraKills': 0,
#     u'sightWardsBoughtInGame': 0,
#     u'totalDamageDealt': 199011,
#     u'totalDamageDealtToChampions': 20192,
#     u'totalDamageTaken': 20123,
#     u'totalHeal': 3733,
#     u'totalPlayerScore': 0,
#     u'totalScoreRank': 0,
#     u'totalTimeCrowdControlDealt': 3767,
#     u'totalUnitsHealed': 4,
#     u'towerKills': 0,
#     u'tripleKills': 0,
#     u'trueDamageDealt': 2663,
#     u'trueDamageDealtToChampions': 565,
#     u'trueDamageTaken': 376,
#     u'unrealKills': 0,
#     u'visionWardsBoughtInGame': 3,
#     u'wardsKilled': 5,
#     u'wardsPlaced': 12,
#     u'winner': True},
#    u'teamId': 100,
#    u'timeline': {u'creepsPerMinDeltas': {u'tenToTwenty': 8.1,
#      u'twentyToThirty': 7.0,
#      u'zeroToTen': 7.4},
#     u'csDiffPerMinDeltas': {u'tenToTwenty': -0.9500000000000002,
#      u'twentyToThirty': -0.8999999999999999,
#      u'zeroToTen': -0.24999999999999956},
#     u'damageTakenDiffPerMinDeltas': {u'tenToTwenty': 79.19999999999993,
#      u'twentyToThirty': 171.45,
#      u'zeroToTen': -22.200000000000017},
#     u'damageTakenPerMinDeltas': {u'tenToTwenty': 361.09999999999997,
#      u'twentyToThirty': 731.4000000000001,
#      u'zeroToTen': 263.0},
#     u'goldPerMinDeltas': {u'tenToTwenty': 417.1,
#      u'twentyToThirty': 499.0,
#      u'zeroToTen': 290.9},
#     u'lane': u'BOTTOM',
#     u'role': u'DUO_CARRY',
#     u'xpDiffPerMinDeltas': {u'tenToTwenty': -38.00000000000003,
#      u'twentyToThirty': 92.29999999999995,
#      u'zeroToTen': -46.5},
#     u'xpPerMinDeltas': {u'tenToTwenty': 484.2,
#      u'twentyToThirty': 655.2,
#      u'zeroToTen': 304.3}}},
#   {u'championId': 245,
#    u'highestAchievedSeasonTier': u'MASTER',
#    u'masteries': [{u'masteryId': 6114, u'rank': 5},
#     {u'masteryId': 6121, u'rank': 1},
#     {u'masteryId': 6134, u'rank': 5},
#     {u'masteryId': 6142, u'rank': 1},
#     {u'masteryId': 6312, u'rank': 5},
#     {u'masteryId': 6323, u'rank': 1},
#     {u'masteryId': 6331, u'rank': 4},
#     {u'masteryId': 6332, u'rank': 1},
#     {u'masteryId': 6343, u'rank': 1},
#     {u'masteryId': 6351, u'rank': 5},
#     {u'masteryId': 6362, u'rank': 1}],
#    u'participantId': 2,
#    u'runes': [{u'rank': 3, u'runeId': 5247},
#     {u'rank': 6, u'runeId': 5273},
#     {u'rank': 9, u'runeId': 5289},
#     {u'rank': 9, u'runeId': 5316},
#     {u'rank': 3, u'runeId': 5357}],
#    u'spell1Id': 12,
#    u'spell2Id': 4,
#    u'stats': {u'assists': 9,
#     u'champLevel': 17,
#     u'combatPlayerScore': 0,
#     u'deaths': 5,
#     u'doubleKills': 1,
#     u'firstBloodAssist': False,
#     u'firstBloodKill': False,
#     u'firstInhibitorAssist': True,
#     u'firstInhibitorKill': False,
#     u'firstTowerAssist': False,
#     u'firstTowerKill': True,
#     u'goldEarned': 16780,
#     u'goldSpent': 15000,
#     u'inhibitorKills': 0,
#     u'item0': 3157,
#     u'item1': 3152,
#     u'item2': 3100,
#     u'item3': 3111,
#     u'item4': 3089,
#     u'item5': 1026,
#     u'item6': 3363,
#     u'killingSprees': 3,
#     u'kills': 11,
#     u'largestCriticalStrike': 0,
#     u'largestKillingSpree': 5,
#     u'largestMultiKill': 3,
#     u'magicDamageDealt': 161397,
#     u'magicDamageDealtToChampions': 16092,
#     u'magicDamageTaken': 10900,
#     u'minionsKilled': 225,
#     u'neutralMinionsKilled': 5,
#     u'neutralMinionsKilledEnemyJungle': 3,
#     u'neutralMinionsKilledTeamJungle': 2,
#     u'objectivePlayerScore': 0,
#     u'pentaKills': 0,
#     u'physicalDamageDealt': 27223,
#     u'physicalDamageDealtToChampions': 2546,
#     u'physicalDamageTaken': 18106,
#     u'quadraKills': 0,
#     u'sightWardsBoughtInGame': 0,
#     u'totalDamageDealt': 188765,
#     u'totalDamageDealtToChampions': 18639,
#     u'totalDamageTaken': 29568,
#     u'totalHeal': 9264,
#     u'totalPlayerScore': 0,
#     u'totalScoreRank': 0,
#     u'totalTimeCrowdControlDealt': 250,
#     u'totalUnitsHealed': 1,
#     u'towerKills': 5,
#     u'tripleKills': 1,
#     u'trueDamageDealt': 144,
#     u'trueDamageDealtToChampions': 0,
#     u'trueDamageTaken': 562,
#     u'unrealKills': 0,
#     u'visionWardsBoughtInGame': 0,
#     u'wardsKilled': 3,
#     u'wardsPlaced': 10,
#     u'winner': True},
#    u'teamId': 100,
#    u'timeline': {u'creepsPerMinDeltas': {u'tenToTwenty': 10.7,
#      u'twentyToThirty': 5.1,
#      u'zeroToTen': 6.4},
#     u'damageTakenPerMinDeltas': {u'tenToTwenty': 751.3,
#      u'twentyToThirty': 1187.7,
#      u'zeroToTen': 378.70000000000005},
#     u'goldPerMinDeltas': {u'tenToTwenty': 604.0,
#      u'twentyToThirty': 475.0,
#      u'zeroToTen': 294.4},
#     u'lane': u'JUNGLE',
#     u'role': u'NONE',
#     u'xpPerMinDeltas': {u'tenToTwenty': 637.3,
#      u'twentyToThirty': 480.3,
#      u'zeroToTen': 379.4}}},
#   {u'championId': 21,
#    u'highestAchievedSeasonTier': u'MASTER',
#    u'masteries': [{u'masteryId': 6114, u'rank': 5},
#     {u'masteryId': 6121, u'rank': 1},
#     {u'masteryId': 6134, u'rank': 5},
#     {u'masteryId': 6143, u'rank': 1},
#     {u'masteryId': 6311, u'rank': 5},
#     {u'masteryId': 6322, u'rank': 1},
#     {u'masteryId': 6331, u'rank': 2},
#     {u'masteryId': 6332, u'rank': 3},
#     {u'masteryId': 6342, u'rank': 1},
#     {u'masteryId': 6351, u'rank': 5},
#     {u'masteryId': 6362, u'rank': 1}],
#    u'participantId': 3,
#    u'runes': [{u'rank': 9, u'runeId': 5245},
#     {u'rank': 9, u'runeId': 5297},
#     {u'rank': 5, u'runeId': 5315},
#     {u'rank': 4, u'runeId': 5317},
#     {u'rank': 1, u'runeId': 5347},
#     {u'rank': 2, u'runeId': 5357}],
#    u'spell1Id': 4,
#    u'spell2Id': 3,
#    u'stats': {u'assists': 19,
#     u'champLevel': 15,
#     u'combatPlayerScore': 0,
#     u'deaths': 8,
#     u'doubleKills': 0,
#     u'firstBloodAssist': False,
#     u'firstBloodKill': False,
#     u'firstInhibitorAssist': True,
#     u'firstInhibitorKill': False,
#     u'firstTowerAssist': False,
#     u'firstTowerKill': False,
#     u'goldEarned': 12666,
#     u'goldSpent': 11425,
#     u'inhibitorKills': 0,
#     u'item0': 3123,
#     u'item1': 2031,
#     u'item2': 2301,
#     u'item3': 3151,
#     u'item4': 3009,
#     u'item5': 3071,
#     u'item6': 3364,
#     u'killingSprees': 1,
#     u'kills': 3,
#     u'largestCriticalStrike': 0,
#     u'largestKillingSpree': 3,
#     u'largestMultiKill': 1,
#     u'magicDamageDealt': 31793,
#     u'magicDamageDealtToChampions': 12772,
#     u'magicDamageTaken': 11806,
#     u'minionsKilled': 17,
#     u'neutralMinionsKilled': 0,
#     u'neutralMinionsKilledEnemyJungle': 0,
#     u'neutralMinionsKilledTeamJungle': 0,
#     u'objectivePlayerScore': 0,
#     u'pentaKills': 0,
#     u'physicalDamageDealt': 22341,
#     u'physicalDamageDealtToChampions': 9624,
#     u'physicalDamageTaken': 12526,
#     u'quadraKills': 0,
#     u'sightWardsBoughtInGame': 0,
#     u'totalDamageDealt': 54434,
#     u'totalDamageDealtToChampions': 22597,
#     u'totalDamageTaken': 24405,
#     u'totalHeal': 4340,
#     u'totalPlayerScore': 0,
#     u'totalScoreRank': 0,
#     u'totalTimeCrowdControlDealt': 235,
#     u'totalUnitsHealed': 1,
#     u'towerKills': 0,
#     u'tripleKills': 0,
#     u'trueDamageDealt': 300,
#     u'trueDamageDealtToChampions': 200,
#     u'trueDamageTaken': 72,
#     u'unrealKills': 0,
#     u'visionWardsBoughtInGame': 7,
#     u'wardsKilled': 8,
#     u'wardsPlaced': 38,
#     u'winner': True},
#    u'teamId': 100,
#    u'timeline': {u'creepsPerMinDeltas': {u'tenToTwenty': 0.3,
#      u'twentyToThirty': 0.7,
#      u'zeroToTen': 0.3},
#     u'csDiffPerMinDeltas': {u'tenToTwenty': -0.9500000000000002,
#      u'twentyToThirty': -0.8999999999999999,
#      u'zeroToTen': -0.24999999999999956},
#     u'damageTakenDiffPerMinDeltas': {u'tenToTwenty': 79.19999999999993,
#      u'twentyToThirty': 171.45,
#      u'zeroToTen': -22.200000000000017},
#     u'damageTakenPerMinDeltas': {u'tenToTwenty': 611.9,
#      u'twentyToThirty': 916.0,
#      u'zeroToTen': 304.20000000000005},
#     u'goldPerMinDeltas': {u'tenToTwenty': 315.79999999999995,
#      u'twentyToThirty': 479.6,
#      u'zeroToTen': 195.3},
#     u'lane': u'BOTTOM',
#     u'role': u'DUO_SUPPORT',
#     u'xpDiffPerMinDeltas': {u'tenToTwenty': -38.00000000000003,
#      u'twentyToThirty': 92.29999999999995,
#      u'zeroToTen': -46.5},
#     u'xpPerMinDeltas': {u'tenToTwenty': 264.5,
#      u'twentyToThirty': 536.2,
#      u'zeroToTen': 257.5}}},
#   {u'championId': 121,
#    u'highestAchievedSeasonTier': u'DIAMOND',
#    u'masteries': [{u'masteryId': 6114, u'rank': 5},
#     {u'masteryId': 6121, u'rank': 1},
#     {u'masteryId': 6134, u'rank': 5},
#     {u'masteryId': 6141, u'rank': 1},
#     {u'masteryId': 6312, u'rank': 5},
#     {u'masteryId': 6323, u'rank': 1},
#     {u'masteryId': 6331, u'rank': 5},
#     {u'masteryId': 6341, u'rank': 1},
#     {u'masteryId': 6351, u'rank': 5},
#     {u'masteryId': 6362, u'rank': 1}],
#    u'participantId': 4,
#    u'runes': [{u'rank': 9, u'runeId': 5245},
#     {u'rank': 9, u'runeId': 5295},
#     {u'rank': 9, u'runeId': 5317},
#     {u'rank': 2, u'runeId': 5335},
#     {u'rank': 1, u'runeId': 5355}],
#    u'spell1Id': 11,
#    u'spell2Id': 4,
#    u'stats': {u'assists': 16,
#     u'champLevel': 18,
#     u'combatPlayerScore': 0,
#     u'deaths': 6,
#     u'doubleKills': 2,
#     u'firstBloodAssist': False,
#     u'firstBloodKill': False,
#     u'firstInhibitorAssist': False,
#     u'firstInhibitorKill': False,
#     u'firstTowerAssist': True,
#     u'firstTowerKill': False,
#     u'goldEarned': 17042,
#     u'goldSpent': 16845,
#     u'inhibitorKills': 1,
#     u'item0': 3036,
#     u'item1': 3142,
#     u'item2': 3082,
#     u'item3': 1412,
#     u'item4': 3156,
#     u'item5': 3111,
#     u'item6': 3364,
#     u'killingSprees': 3,
#     u'kills': 13,
#     u'largestCriticalStrike': 0,
#     u'largestKillingSpree': 6,
#     u'largestMultiKill': 3,
#     u'magicDamageDealt': 6639,
#     u'magicDamageDealtToChampions': 3826,
#     u'magicDamageTaken': 9090,
#     u'minionsKilled': 54,
#     u'neutralMinionsKilled': 103,
#     u'neutralMinionsKilledEnemyJungle': 61,
#     u'neutralMinionsKilledTeamJungle': 42,
#     u'objectivePlayerScore': 0,
#     u'pentaKills': 0,
#     u'physicalDamageDealt': 176488,
#     u'physicalDamageDealtToChampions': 20288,
#     u'physicalDamageTaken': 20718,
#     u'quadraKills': 0,
#     u'sightWardsBoughtInGame': 0,
#     u'totalDamageDealt': 189955,
#     u'totalDamageDealtToChampions': 24676,
#     u'totalDamageTaken': 30676,
#     u'totalHeal': 13596,
#     u'totalPlayerScore': 0,
#     u'totalScoreRank': 0,
#     u'totalTimeCrowdControlDealt': 460,
#     u'totalUnitsHealed': 1,
#     u'towerKills': 2,
#     u'tripleKills': 1,
#     u'trueDamageDealt': 6827,
#     u'trueDamageDealtToChampions': 562,
#     u'trueDamageTaken': 868,
#     u'unrealKills': 0,
#     u'visionWardsBoughtInGame': 1,
#     u'wardsKilled': 7,
#     u'wardsPlaced': 6,
#     u'winner': True},
#    u'teamId': 100,
#    u'timeline': {u'creepsPerMinDeltas': {u'tenToTwenty': 1.2000000000000002,
#      u'twentyToThirty': 2.5,
#      u'zeroToTen': 0.0},
#     u'damageTakenPerMinDeltas': {u'tenToTwenty': 783.7,
#      u'twentyToThirty': 1034.8,
#      u'zeroToTen': 685.4},
#     u'goldPerMinDeltas': {u'tenToTwenty': 596.0,
#      u'twentyToThirty': 423.79999999999995,
#      u'zeroToTen': 271.7},
#     u'lane': u'JUNGLE',
#     u'role': u'NONE',
#     u'xpPerMinDeltas': {u'tenToTwenty': 616.4,
#      u'twentyToThirty': 617.0,
#      u'zeroToTen': 307.7}}},
#   {u'championId': 92,
#    u'highestAchievedSeasonTier': u'MASTER',
#    u'masteries': [{u'masteryId': 6111, u'rank': 5},
#     {u'masteryId': 6121, u'rank': 1},
#     {u'masteryId': 6134, u'rank': 5},
#     {u'masteryId': 6142, u'rank': 1},
#     {u'masteryId': 6151, u'rank': 5},
#     {u'masteryId': 6162, u'rank': 1},
#     {u'masteryId': 6312, u'rank': 5},
#     {u'masteryId': 6323, u'rank': 1},
#     {u'masteryId': 6331, u'rank': 5},
#     {u'masteryId': 6343, u'rank': 1}],
#    u'participantId': 5,
#    u'runes': [{u'rank': 9, u'runeId': 5253},
#     {u'rank': 9, u'runeId': 5289},
#     {u'rank': 9, u'runeId': 5317},
#     {u'rank': 3, u'runeId': 5343}],
#    u'spell1Id': 4,
#    u'spell2Id': 12,
#    u'stats': {u'assists': 5,
#     u'champLevel': 18,
#     u'combatPlayerScore': 0,
#     u'deaths': 5,
#     u'doubleKills': 1,
#     u'firstBloodAssist': False,
#     u'firstBloodKill': False,
#     u'firstInhibitorAssist': False,
#     u'firstInhibitorKill': True,
#     u'firstTowerAssist': False,
#     u'firstTowerKill': False,
#     u'goldEarned': 15233,
#     u'goldSpent': 14200,
#     u'inhibitorKills': 1,
#     u'item0': 3814,
#     u'item1': 3142,
#     u'item2': 3071,
#     u'item3': 3111,
#     u'item4': 3156,
#     u'item5': 1036,
#     u'item6': 3340,
#     u'killingSprees': 2,
#     u'kills': 9,
#     u'largestCriticalStrike': 0,
#     u'largestKillingSpree': 4,
#     u'largestMultiKill': 2,
#     u'magicDamageDealt': 0,
#     u'magicDamageDealtToChampions': 0,
#     u'magicDamageTaken': 6909,
#     u'minionsKilled': 192,
#     u'neutralMinionsKilled': 53,
#     u'neutralMinionsKilledEnemyJungle': 23,
#     u'neutralMinionsKilledTeamJungle': 30,
#     u'objectivePlayerScore': 0,
#     u'pentaKills': 0,
#     u'physicalDamageDealt': 171609,
#     u'physicalDamageDealtToChampions': 16384,
#     u'physicalDamageTaken': 12810,
#     u'quadraKills': 0,
#     u'sightWardsBoughtInGame': 0,
#     u'totalDamageDealt': 172123,
#     u'totalDamageDealtToChampions': 16384,
#     u'totalDamageTaken': 20300,
#     u'totalHeal': 3238,
#     u'totalPlayerScore': 0,
#     u'totalScoreRank': 0,
#     u'totalTimeCrowdControlDealt': 191,
#     u'totalUnitsHealed': 1,
#     u'towerKills': 1,
#     u'tripleKills': 0,
#     u'trueDamageDealt': 514,
#     u'trueDamageDealtToChampions': 0,
#     u'trueDamageTaken': 580,
#     u'unrealKills': 0,
#     u'visionWardsBoughtInGame': 0,
#     u'wardsKilled': 2,
#     u'wardsPlaced': 12,
#     u'winner': True},
#    u'teamId': 100,
#    u'timeline': {u'creepsPerMinDeltas': {u'tenToTwenty': 8.0,
#      u'twentyToThirty': 5.199999999999999,
#      u'zeroToTen': 5.9},
#     u'csDiffPerMinDeltas': {u'tenToTwenty': -0.5999999999999992,
#      u'twentyToThirty': -1.7000000000000006,
#      u'zeroToTen': 0.8999999999999999},
#     u'damageTakenDiffPerMinDeltas': {u'tenToTwenty': -338.7,
#      u'twentyToThirty': 111.70000000000002,
#      u'zeroToTen': -125.59999999999997},
#     u'damageTakenPerMinDeltas': {u'tenToTwenty': 271.8,
#      u'twentyToThirty': 826.7,
#      u'zeroToTen': 464.3},
#     u'goldPerMinDeltas': {u'tenToTwenty': 425.29999999999995,
#      u'twentyToThirty': 545.5,
#      u'zeroToTen': 324.70000000000005},
#     u'lane': u'TOP',
#     u'role': u'SOLO',
#     u'xpDiffPerMinDeltas': {u'tenToTwenty': 39.099999999999994,
#      u'twentyToThirty': 219.70000000000005,
#      u'zeroToTen': 89.0},
#     u'xpPerMinDeltas': {u'tenToTwenty': 511.5,
#      u'twentyToThirty': 701.6,
#      u'zeroToTen': 479.1}}},
#   {u'championId': 51,
#    u'highestAchievedSeasonTier': u'MASTER',
#    u'masteries': [{u'masteryId': 6111, u'rank': 5},
#     {u'masteryId': 6121, u'rank': 1},
#     {u'masteryId': 6131, u'rank': 5},
#     {u'masteryId': 6141, u'rank': 1},
#     {u'masteryId': 6151, u'rank': 5},
#     {u'masteryId': 6161, u'rank': 1},
#     {u'masteryId': 6211, u'rank': 5},
#     {u'masteryId': 6223, u'rank': 1},
#     {u'masteryId': 6232, u'rank': 5},
#     {u'masteryId': 6241, u'rank': 1}],
#    u'participantId': 6,
#    u'runes': [{u'rank': 9, u'runeId': 5245},
#     {u'rank': 9, u'runeId': 5289},
#     {u'rank': 9, u'runeId': 5317},
#     {u'rank': 3, u'runeId': 5337}],
#    u'spell1Id': 4,
#    u'spell2Id': 7,
#    u'stats': {u'assists': 9,
#     u'champLevel': 17,
#     u'combatPlayerScore': 0,
#     u'deaths': 5,
#     u'doubleKills': 0,
#     u'firstBloodAssist': False,
#     u'firstBloodKill': False,
#     u'firstInhibitorAssist': False,
#     u'firstInhibitorKill': False,
#     u'firstTowerAssist': False,
#     u'firstTowerKill': False,
#     u'goldEarned': 15969,
#     u'goldSpent': 15600,
#     u'inhibitorKills': 0,
#     u'item0': 3139,
#     u'item1': 3085,
#     u'item2': 3031,
#     u'item3': 3094,
#     u'item4': 3006,
#     u'item5': 3035,
#     u'item6': 3363,
#     u'killingSprees': 2,
#     u'kills': 10,
#     u'largestCriticalStrike': 1829,
#     u'largestKillingSpree': 4,
#     u'largestMultiKill': 1,
#     u'magicDamageDealt': 2651,
#     u'magicDamageDealtToChampions': 968,
#     u'magicDamageTaken': 6671,
#     u'minionsKilled': 282,
#     u'neutralMinionsKilled': 11,
#     u'neutralMinionsKilledEnemyJungle': 0,
#     u'neutralMinionsKilledTeamJungle': 11,
#     u'objectivePlayerScore': 0,
#     u'pentaKills': 0,
#     u'physicalDamageDealt': 207884,
#     u'physicalDamageDealtToChampions': 22701,
#     u'physicalDamageTaken': 14924,
#     u'quadraKills': 0,
#     u'sightWardsBoughtInGame': 0,
#     u'totalDamageDealt': 213177,
#     u'totalDamageDealtToChampions': 24726,
#     u'totalDamageTaken': 21782,
#     u'totalHeal': 1396,
#     u'totalPlayerScore': 0,
#     u'totalScoreRank': 0,
#     u'totalTimeCrowdControlDealt': 275,
#     u'totalUnitsHealed': 2,
#     u'towerKills': 1,
#     u'tripleKills': 0,
#     u'trueDamageDealt': 2642,
#     u'trueDamageDealtToChampions': 1056,
#     u'trueDamageTaken': 187,
#     u'unrealKills': 0,
#     u'visionWardsBoughtInGame': 2,
#     u'wardsKilled': 8,
#     u'wardsPlaced': 12,
#     u'winner': False},
#    u'teamId': 200,
#    u'timeline': {u'creepsPerMinDeltas': {u'tenToTwenty': 9.3,
#      u'twentyToThirty': 8.399999999999999,
#      u'zeroToTen': 8.1},
#     u'csDiffPerMinDeltas': {u'tenToTwenty': 0.9500000000000002,
#      u'twentyToThirty': 0.8999999999999999,
#      u'zeroToTen': 0.24999999999999956},
#     u'damageTakenDiffPerMinDeltas': {u'tenToTwenty': -79.19999999999993,
#      u'twentyToThirty': -171.45,
#      u'zeroToTen': 22.200000000000017},
#     u'damageTakenPerMinDeltas': {u'tenToTwenty': 526.8,
#      u'twentyToThirty': 656.7,
#      u'zeroToTen': 341.70000000000005},
#     u'goldPerMinDeltas': {u'tenToTwenty': 453.6,
#      u'twentyToThirty': 512.4000000000001,
#      u'zeroToTen': 323.3},
#     u'lane': u'BOTTOM',
#     u'role': u'DUO_CARRY',
#     u'xpDiffPerMinDeltas': {u'tenToTwenty': 38.00000000000003,
#      u'twentyToThirty': -92.29999999999995,
#      u'zeroToTen': 46.5},
#     u'xpPerMinDeltas': {u'tenToTwenty': 458.4,
#      u'twentyToThirty': 539.5999999999999,
#      u'zeroToTen': 351.9}}},
#   {u'championId': 4,
#    u'highestAchievedSeasonTier': u'UNRANKED',
#    u'masteries': [{u'masteryId': 6114, u'rank': 5},
#     {u'masteryId': 6122, u'rank': 1},
#     {u'masteryId': 6131, u'rank': 2},
#     {u'masteryId': 6134, u'rank': 3},
#     {u'masteryId': 6141, u'rank': 1},
#     {u'masteryId': 6312, u'rank': 5},
#     {u'masteryId': 6323, u'rank': 1},
#     {u'masteryId': 6331, u'rank': 5},
#     {u'masteryId': 6341, u'rank': 1},
#     {u'masteryId': 6351, u'rank': 5},
#     {u'masteryId': 6362, u'rank': 1}],
#    u'participantId': 7,
#    u'runes': [{u'rank': 9, u'runeId': 5273},
#     {u'rank': 9, u'runeId': 5289},
#     {u'rank': 9, u'runeId': 5316},
#     {u'rank': 3, u'runeId': 5357}],
#    u'spell1Id': 4,
#    u'spell2Id': 6,
#    u'stats': {u'assists': 8,
#     u'champLevel': 15,
#     u'combatPlayerScore': 0,
#     u'deaths': 7,
#     u'doubleKills': 0,
#     u'firstBloodAssist': False,
#     u'firstBloodKill': False,
#     u'firstInhibitorAssist': False,
#     u'firstInhibitorKill': False,
#     u'firstTowerAssist': False,
#     u'firstTowerKill': False,
#     u'goldEarned': 12138,
#     u'goldSpent': 11125,
#     u'inhibitorKills': 0,
#     u'item0': 1056,
#     u'item1': 3157,
#     u'item2': 3027,
#     u'item3': 3158,
#     u'item4': 3100,
#     u'item5': 1026,
#     u'item6': 3340,
#     u'killingSprees': 1,
#     u'kills': 4,
#     u'largestCriticalStrike': 0,
#     u'largestKillingSpree': 2,
#     u'largestMultiKill': 1,
#     u'magicDamageDealt': 117532,
#     u'magicDamageDealtToChampions': 10630,
#     u'magicDamageTaken': 6388,
#     u'minionsKilled': 181,
#     u'neutralMinionsKilled': 12,
#     u'neutralMinionsKilledEnemyJungle': 0,
#     u'neutralMinionsKilledTeamJungle': 12,
#     u'objectivePlayerScore': 0,
#     u'pentaKills': 0,
#     u'physicalDamageDealt': 11702,
#     u'physicalDamageDealtToChampions': 783,
#     u'physicalDamageTaken': 14500,
#     u'quadraKills': 0,
#     u'sightWardsBoughtInGame': 0,
#     u'totalDamageDealt': 129448,
#     u'totalDamageDealtToChampions': 11468,
#     u'totalDamageTaken': 21240,
#     u'totalHeal': 2343,
#     u'totalPlayerScore': 0,
#     u'totalScoreRank': 0,
#     u'totalTimeCrowdControlDealt': 296,
#     u'totalUnitsHealed': 1,
#     u'towerKills': 1,
#     u'tripleKills': 0,
#     u'trueDamageDealt': 214,
#     u'trueDamageDealtToChampions': 54,
#     u'trueDamageTaken': 352,
#     u'unrealKills': 0,
#     u'visionWardsBoughtInGame': 1,
#     u'wardsKilled': 2,
#     u'wardsPlaced': 11,
#     u'winner': False},
#    u'teamId': 200,
#    u'timeline': {u'creepsPerMinDeltas': {u'tenToTwenty': 7.9,
#      u'twentyToThirty': 3.0,
#      u'zeroToTen': 5.3},
#     u'damageTakenPerMinDeltas': {u'tenToTwenty': 601.0,
#      u'twentyToThirty': 694.0,
#      u'zeroToTen': 177.8},
#     u'goldPerMinDeltas': {u'tenToTwenty': 406.0,
#      u'twentyToThirty': 311.3,
#      u'zeroToTen': 279.0},
#     u'lane': u'MIDDLE',
#     u'role': u'SOLO',
#     u'xpPerMinDeltas': {u'tenToTwenty': 438.3,
#      u'twentyToThirty': 371.9,
#      u'zeroToTen': 419.5}}},
#   {u'championId': 68,
#    u'highestAchievedSeasonTier': u'DIAMOND',
#    u'masteries': [{u'masteryId': 6114, u'rank': 5},
#     {u'masteryId': 6121, u'rank': 1},
#     {u'masteryId': 6131, u'rank': 2},
#     {u'masteryId': 6134, u'rank': 3},
#     {u'masteryId': 6142, u'rank': 1},
#     {u'masteryId': 6311, u'rank': 5},
#     {u'masteryId': 6321, u'rank': 1},
#     {u'masteryId': 6331, u'rank': 5},
#     {u'masteryId': 6343, u'rank': 1},
#     {u'masteryId': 6351, u'rank': 5},
#     {u'masteryId': 6362, u'rank': 1}],
#    u'participantId': 8,
#    u'runes': [{u'rank': 9, u'runeId': 5247},
#     {u'rank': 9, u'runeId': 5298},
#     {u'rank': 9, u'runeId': 5317},
#     {u'rank': 3, u'runeId': 5337}],
#    u'spell1Id': 4,
#    u'spell2Id': 11,
#    u'stats': {u'assists': 7,
#     u'champLevel': 16,
#     u'combatPlayerScore': 0,
#     u'deaths': 12,
#     u'doubleKills': 0,
#     u'firstBloodAssist': False,
#     u'firstBloodKill': False,
#     u'firstInhibitorAssist': False,
#     u'firstInhibitorKill': False,
#     u'firstTowerAssist': False,
#     u'firstTowerKill': False,
#     u'goldEarned': 12189,
#     u'goldSpent': 10835,
#     u'inhibitorKills': 0,
#     u'item0': 1402,
#     u'item1': 2055,
#     u'item2': 3157,
#     u'item3': 3020,
#     u'item4': 1052,
#     u'item5': 3151,
#     u'item6': 3364,
#     u'killingSprees': 2,
#     u'kills': 6,
#     u'largestCriticalStrike': 0,
#     u'largestKillingSpree': 2,
#     u'largestMultiKill': 1,
#     u'magicDamageDealt': 120581,
#     u'magicDamageDealtToChampions': 15760,
#     u'magicDamageTaken': 10692,
#     u'minionsKilled': 54,
#     u'neutralMinionsKilled': 88,
#     u'neutralMinionsKilledEnemyJungle': 26,
#     u'neutralMinionsKilledTeamJungle': 62,
#     u'objectivePlayerScore': 0,
#     u'pentaKills': 0,
#     u'physicalDamageDealt': 21448,
#     u'physicalDamageDealtToChampions': 439,
#     u'physicalDamageTaken': 21331,
#     u'quadraKills': 0,
#     u'sightWardsBoughtInGame': 0,
#     u'totalDamageDealt': 147392,
#     u'totalDamageDealtToChampions': 17351,
#     u'totalDamageTaken': 32102,
#     u'totalHeal': 5289,
#     u'totalPlayerScore': 0,
#     u'totalScoreRank': 0,
#     u'totalTimeCrowdControlDealt': 669,
#     u'totalUnitsHealed': 1,
#     u'towerKills': 0,
#     u'tripleKills': 0,
#     u'trueDamageDealt': 5364,
#     u'trueDamageDealtToChampions': 1152,
#     u'trueDamageTaken': 79,
#     u'unrealKills': 0,
#     u'visionWardsBoughtInGame': 8,
#     u'wardsKilled': 0,
#     u'wardsPlaced': 10,
#     u'winner': False},
#    u'teamId': 200,
#    u'timeline': {u'creepsPerMinDeltas': {u'tenToTwenty': 1.1,
#      u'twentyToThirty': 2.2,
#      u'zeroToTen': 0.4},
#     u'damageTakenPerMinDeltas': {u'tenToTwenty': 909.9,
#      u'twentyToThirty': 1026.8,
#      u'zeroToTen': 613.4000000000001},
#     u'goldPerMinDeltas': {u'tenToTwenty': 325.1,
#      u'twentyToThirty': 311.3,
#      u'zeroToTen': 258.5},
#     u'lane': u'JUNGLE',
#     u'role': u'NONE',
#     u'xpPerMinDeltas': {u'tenToTwenty': 461.4,
#      u'twentyToThirty': 409.8,
#      u'zeroToTen': 309.0}}},
#   {u'championId': 14,
#    u'highestAchievedSeasonTier': u'DIAMOND',
#    u'masteries': [{u'masteryId': 6114, u'rank': 5},
#     {u'masteryId': 6122, u'rank': 1},
#     {u'masteryId': 6134, u'rank': 5},
#     {u'masteryId': 6143, u'rank': 1},
#     {u'masteryId': 6212, u'rank': 5},
#     {u'masteryId': 6223, u'rank': 1},
#     {u'masteryId': 6231, u'rank': 5},
#     {u'masteryId': 6241, u'rank': 1},
#     {u'masteryId': 6251, u'rank': 5},
#     {u'masteryId': 6262, u'rank': 1}],
#    u'participantId': 9,
#    u'runes': [{u'rank': 8, u'runeId': 5245},
#     {u'rank': 1, u'runeId': 5251},
#     {u'rank': 9, u'runeId': 5289},
#     {u'rank': 9, u'runeId': 5317},
#     {u'rank': 3, u'runeId': 5335}],
#    u'spell1Id': 12,
#    u'spell2Id': 4,
#    u'stats': {u'assists': 8,
#     u'champLevel': 16,
#     u'combatPlayerScore': 0,
#     u'deaths': 8,
#     u'doubleKills': 0,
#     u'firstBloodAssist': False,
#     u'firstBloodKill': False,
#     u'firstInhibitorAssist': False,
#     u'firstInhibitorKill': False,
#     u'firstTowerAssist': False,
#     u'firstTowerKill': False,
#     u'goldEarned': 12446,
#     u'goldSpent': 10875,
#     u'inhibitorKills': 0,
#     u'item0': 3047,
#     u'item1': 2033,
#     u'item2': 3068,
#     u'item3': 3065,
#     u'item4': 3110,
#     u'item5': 1031,
#     u'item6': 3340,
#     u'killingSprees': 2,
#     u'kills': 5,
#     u'largestCriticalStrike': 333,
#     u'largestKillingSpree': 3,
#     u'largestMultiKill': 1,
#     u'magicDamageDealt': 72965,
#     u'magicDamageDealtToChampions': 6772,
#     u'magicDamageTaken': 6453,
#     u'minionsKilled': 230,
#     u'neutralMinionsKilled': 5,
#     u'neutralMinionsKilledEnemyJungle': 2,
#     u'neutralMinionsKilledTeamJungle': 3,
#     u'objectivePlayerScore': 0,
#     u'pentaKills': 0,
#     u'physicalDamageDealt': 89380,
#     u'physicalDamageDealtToChampions': 9736,
#     u'physicalDamageTaken': 21439,
#     u'quadraKills': 0,
#     u'sightWardsBoughtInGame': 0,
#     u'totalDamageDealt': 163605,
#     u'totalDamageDealtToChampions': 16705,
#     u'totalDamageTaken': 28553,
#     u'totalHeal': 15707,
#     u'totalPlayerScore': 0,
#     u'totalScoreRank': 0,
#     u'totalTimeCrowdControlDealt': 1875,
#     u'totalUnitsHealed': 1,
#     u'towerKills': 0,
#     u'tripleKills': 0,
#     u'trueDamageDealt': 1260,
#     u'trueDamageDealtToChampions': 196,
#     u'trueDamageTaken': 659,
#     u'unrealKills': 0,
#     u'visionWardsBoughtInGame': 1,
#     u'wardsKilled': 1,
#     u'wardsPlaced': 15,
#     u'winner': False},
#    u'teamId': 200,
#    u'timeline': {u'creepsPerMinDeltas': {u'tenToTwenty': 8.6,
#      u'twentyToThirty': 6.9,
#      u'zeroToTen': 5.0},
#     u'csDiffPerMinDeltas': {u'tenToTwenty': 0.5999999999999992,
#      u'twentyToThirty': 1.7000000000000006,
#      u'zeroToTen': -0.8999999999999999},
#     u'damageTakenDiffPerMinDeltas': {u'tenToTwenty': 338.7,
#      u'twentyToThirty': -111.70000000000002,
#      u'zeroToTen': 125.59999999999997},
#     u'damageTakenPerMinDeltas': {u'tenToTwenty': 610.5,
#      u'twentyToThirty': 715.0,
#      u'zeroToTen': 589.9},
#     u'goldPerMinDeltas': {u'tenToTwenty': 323.2,
#      u'twentyToThirty': 439.9,
#      u'zeroToTen': 281.6},
#     u'lane': u'TOP',
#     u'role': u'SOLO',
#     u'xpDiffPerMinDeltas': {u'tenToTwenty': -39.099999999999994,
#      u'twentyToThirty': -219.70000000000005,
#      u'zeroToTen': -89.0},
#     u'xpPerMinDeltas': {u'tenToTwenty': 472.4,
#      u'twentyToThirty': 481.9,
#      u'zeroToTen': 390.1}}},
#   {u'championId': 90,
#    u'highestAchievedSeasonTier': u'DIAMOND',
#    u'masteries': [{u'masteryId': 6114, u'rank': 5},
#     {u'masteryId': 6123, u'rank': 1},
#     {u'masteryId': 6134, u'rank': 5},
#     {u'masteryId': 6143, u'rank': 1},
#     {u'masteryId': 6311, u'rank': 5},
#     {u'masteryId': 6322, u'rank': 1},
#     {u'masteryId': 6332, u'rank': 5},
#     {u'masteryId': 6342, u'rank': 1},
#     {u'masteryId': 6352, u'rank': 5},
#     {u'masteryId': 6362, u'rank': 1}],
#    u'participantId': 10,
#    u'runes': [{u'rank': 9, u'runeId': 5297},
#     {u'rank': 5, u'runeId': 5315},
#     {u'rank': 4, u'runeId': 5316},
#     {u'rank': 3, u'runeId': 5347},
#     {u'rank': 9, u'runeId': 5402}],
#    u'spell1Id': 3,
#    u'spell2Id': 4,
#    u'stats': {u'assists': 9,
#     u'champLevel': 15,
#     u'combatPlayerScore': 0,
#     u'deaths': 6,
#     u'doubleKills': 1,
#     u'firstBloodAssist': False,
#     u'firstBloodKill': False,
#     u'firstInhibitorAssist': False,
#     u'firstInhibitorKill': False,
#     u'firstTowerAssist': False,
#     u'firstTowerKill': False,
#     u'goldEarned': 10699,
#     u'goldSpent': 10585,
#     u'inhibitorKills': 0,
#     u'item0': 3116,
#     u'item1': 3158,
#     u'item2': 3151,
#     u'item3': 3108,
#     u'item4': 1052,
#     u'item5': 2301,
#     u'item6': 3364,
#     u'killingSprees': 1,
#     u'kills': 4,
#     u'largestCriticalStrike': 0,
#     u'largestKillingSpree': 3,
#     u'largestMultiKill': 2,
#     u'magicDamageDealt': 23647,
#     u'magicDamageDealtToChampions': 9674,
#     u'magicDamageTaken': 7311,
#     u'minionsKilled': 31,
#     u'neutralMinionsKilled': 5,
#     u'neutralMinionsKilledEnemyJungle': 3,
#     u'neutralMinionsKilledTeamJungle': 2,
#     u'objectivePlayerScore': 0,
#     u'pentaKills': 0,
#     u'physicalDamageDealt': 13327,
#     u'physicalDamageDealtToChampions': 2825,
#     u'physicalDamageTaken': 10956,
#     u'quadraKills': 0,
#     u'sightWardsBoughtInGame': 0,
#     u'totalDamageDealt': 36975,
#     u'totalDamageDealtToChampions': 12500,
#     u'totalDamageTaken': 18318,
#     u'totalHeal': 806,
#     u'totalPlayerScore': 0,
#     u'totalScoreRank': 0,
#     u'totalTimeCrowdControlDealt': 573,
#     u'totalUnitsHealed': 1,
#     u'towerKills': 0,
#     u'tripleKills': 0,
#     u'trueDamageDealt': 0,
#     u'trueDamageDealtToChampions': 0,
#     u'trueDamageTaken': 50,
#     u'unrealKills': 0,
#     u'visionWardsBoughtInGame': 2,
#     u'wardsKilled': 9,
#     u'wardsPlaced': 44,
#     u'winner': False},
#    u'teamId': 200,
#    u'timeline': {u'creepsPerMinDeltas': {u'tenToTwenty': 1.0,
#      u'twentyToThirty': 1.1,
#      u'zeroToTen': 0.1},
#     u'csDiffPerMinDeltas': {u'tenToTwenty': 0.9500000000000002,
#      u'twentyToThirty': 0.8999999999999999,
#      u'zeroToTen': 0.24999999999999956},
#     u'damageTakenDiffPerMinDeltas': {u'tenToTwenty': -79.19999999999993,
#      u'twentyToThirty': -171.45,
#      u'zeroToTen': 22.200000000000017},
#     u'damageTakenPerMinDeltas': {u'tenToTwenty': 287.8,
#      u'twentyToThirty': 647.8,
#      u'zeroToTen': 269.9},
#     u'goldPerMinDeltas': {u'tenToTwenty': 322.1,
#      u'twentyToThirty': 316.4,
#      u'zeroToTen': 230.9},
#     u'lane': u'BOTTOM',
#     u'role': u'DUO_SUPPORT',
#     u'xpDiffPerMinDeltas': {u'tenToTwenty': 38.00000000000003,
#      u'twentyToThirty': -92.29999999999995,
#      u'zeroToTen': 46.5},
#     u'xpPerMinDeltas': {u'tenToTwenty': 366.3,
#      u'twentyToThirty': 467.20000000000005,
#      u'zeroToTen': 302.9}}}],
#  u'platformId': u'NA1',
#  u'queueType': u'TEAM_BUILDER_RANKED_SOLO',
#  u'region': u'NA',
#  u'season': u'PRESEASON2017',
#  u'teams': [{u'bans': [{u'championId': 7, u'pickTurn': 1},
#     {u'championId': 126, u'pickTurn': 3},
#     {u'championId': 107, u'pickTurn': 5}],
#    u'baronKills': 2,
#    u'dominionVictoryScore': 0,
#    u'dragonKills': 4,
#    u'firstBaron': True,
#    u'firstBlood': True,
#    u'firstDragon': True,
#    u'firstInhibitor': True,
#    u'firstRiftHerald': False,
#    u'firstTower': True,
#    u'inhibitorKills': 3,
#    u'riftHeraldKills': 0,
#    u'teamId': 100,
#    u'towerKills': 11,
#    u'vilemawKills': 0,
#    u'winner': True},
#   {u'bans': [{u'championId': 120, u'pickTurn': 2},
#     {u'championId': 164, u'pickTurn': 4},
#     {u'championId': 134, u'pickTurn': 6}],
#    u'baronKills': 0,
#    u'dominionVictoryScore': 0,
#    u'dragonKills': 0,
#    u'firstBaron': False,
#    u'firstBlood': False,
#    u'firstDragon': False,
#    u'firstInhibitor': False,
#    u'firstRiftHerald': False,
#    u'firstTower': False,
#    u'inhibitorKills': 0,
#    u'riftHeraldKills': 0,
#    u'teamId': 200,
#    u'towerKills': 3,
#    u'vilemawKills': 0,
#    u'winner': False}]}

# %%
#last match in the list
print matchData['teams'] #he was on team 200

#{'matchid'},
team_col_header = ['firstDragon','bans','firstInhibitor','baronKills','firstRiftHerald','winner','firstBaron','riftheraldKills',
                  'firstBlood','teamId','firstTower','vilemawKills','inhibitorKills','towerKills','dominionVictoryScore',
                  'dragonKills']

#matchid=['2407787433']
matchID=['2407787433']
firstDragon=[]
bans=[]
firstInhibitor=[]
baronKills=[]
firstRiftHerald=[]
winner=[]
firstBaron=[]
riftHeraldKills=[]
firstBlood=[]
teamId=[]
firstTower=[]
vilemawKills=[]
inhibitorKills=[]
towerKills=[]
dominionVictoryScore=[]
dragonKills=[]

matchID.append('2407787433')

for teams in matchData['teams']:
    firstDragon.append(teams[u'firstDragon'])
    bans.append(teams[u'bans'])
    firstInhibitor.append(teams[u'firstInhibitor'])
    baronKills.append(teams[u'baronKills'])
    firstRiftHerald.append(teams[u'firstRiftHerald'])
    winner.append(teams[u'winner'])
    firstBaron.append(teams[u'firstBaron'])
    riftHeraldKills.append(teams[u'riftHeraldKills'])
    firstBlood.append(teams[u'firstBlood'])
    teamId.append(teams[u'teamId'])
    firstTower.append(teams[u'firstTower'])
    vilemawKills.append(teams[u'vilemawKills'])
    inhibitorKills.append(teams[u'inhibitorKills'])
    towerKills.append(teams[u'towerKills'])
    dominionVictoryScore.append(teams[u'dominionVictoryScore'])
    dragonKills.append(teams[u'dragonKills'])
    
dfMatch = pd.DataFrame([matchID,firstDragon,bans,firstInhibitor,baronKills,firstRiftHerald,winner,firstBaron,riftHeraldKills,
                  firstBlood,teamId,firstTower,vilemawKills,inhibitorKills,towerKills,dominionVictoryScore,
                  dragonKills]).T

dfMatch.columns=['matchID','firstDragon','bans','firstInhibitor','baronKills','firstRiftHerald','winner','firstBaron','riftheraldKills',
                  'firstBlood','teamId','firstTower','vilemawKills','inhibitorKills','towerKills','dominionVictoryScore',
                  'dragonKills']

dfghostTeam=dfMatch.drop([0]) #drops the row
# Out:
# [{u'firstDragon': True, u'bans': [{u'pickTurn': 1, u'championId': 7}, {u'pickTurn': 3, u'championId': 126}, {u'pickTurn': 5, u'championId': 107}], u'firstInhibitor': True, u'baronKills': 2, u'firstRiftHerald': False, u'winner': True, u'firstBaron': True, u'riftHeraldKills': 0, u'firstBlood': True, u'teamId': 100, u'firstTower': True, u'vilemawKills': 0, u'inhibitorKills': 3, u'towerKills': 11, u'dominionVictoryScore': 0, u'dragonKills': 4}, {u'firstDragon': False, u'bans': [{u'pickTurn': 2, u'championId': 120}, {u'pickTurn': 4, u'championId': 164}, {u'pickTurn': 6, u'championId': 134}], u'firstInhibitor': False, u'baronKills': 0, u'firstRiftHerald': False, u'winner': False, u'firstBaron': False, u'riftHeraldKills': 0, u'firstBlood': False, u'teamId': 200, u'firstTower': False, u'vilemawKills': 0, u'inhibitorKills': 0, u'towerKills': 3, u'dominionVictoryScore': 0, u'dragonKills': 0}]

# %%
matchRequest =Request('https://na.api.pvp.net/api/lol/na/v2.2/match/'+matchID[1]+'?api_key=RGAPI-6b4e9139-2121-4820-8cd9-371891441c4b')
responseMatch = urlopen(matchRequest)
loadMatch = responseMatch.read()
matchData1 = json.loads(loadMatch)
matchData1
#matchID[1]
# Out:
# {u'mapId': 11,
#  u'matchCreation': 1485620381751L,
#  u'matchDuration': 1309,
#  u'matchId': 2410749501L,
#  u'matchMode': u'CLASSIC',
#  u'matchType': u'MATCHED_GAME',
#  u'matchVersion': u'7.2.174.829',
#  u'participantIdentities': [{u'participantId': 1,
#    u'player': {u'matchHistoryUri': u'/v1/stats/player_history/NA1/43953050',
#     u'profileIcon': 579,
#     u'summonerId': 29557073,
#     u'summonerName': u'098kR19mO12'}},
#   {u'participantId': 2,
#    u'player': {u'matchHistoryUri': u'/v1/stats/player_history/NA1/207848138',
#     u'profileIcon': 745,
#     u'summonerId': 45021344,
#     u'summonerName': u'SirFlyHighTheOP'}},
#   {u'participantId': 3,
#    u'player': {u'matchHistoryUri': u'/v1/stats/player_history/NA1/209851729',
#     u'profileIcon': 627,
#     u'summonerId': 47022584,
#     u'summonerName': u'fog1999'}},
#   {u'participantId': 4,
#    u'player': {u'matchHistoryUri': u'/v1/stats/player_history/NA/39266190',
#     u'profileIcon': 7,
#     u'summonerId': 24811667,
#     u'summonerName': u'Schw\xeffty'}},
#   {u'participantId': 5,
#    u'player': {u'matchHistoryUri': u'/v1/stats/player_history/NA/34805125',
#     u'profileIcon': 1435,
#     u'summonerId': 21421991,
#     u'summonerName': u'Sablemyst'}},
#   {u'participantId': 6,
#    u'player': {u'matchHistoryUri': u'/v1/stats/player_history/NA/37567508',
#     u'profileIcon': 545,
#     u'summonerId': 23472635,
#     u'summonerName': u'Life'}},
#   {u'participantId': 7,
#    u'player': {u'matchHistoryUri': u'/v1/stats/player_history/NA1/217852494',
#     u'profileIcon': 667,
#     u'summonerId': 56013836,
#     u'summonerName': u'Yo Saki'}},
#   {u'participantId': 8,
#    u'player': {u'matchHistoryUri': u'/v1/stats/player_history/NA1/44216588',
#     u'profileIcon': 1113,
#     u'summonerId': 30042959,
#     u'summonerName': u'JV4'}},
#   {u'participantId': 9,
#    u'player': {u'matchHistoryUri': u'/v1/stats/player_history/NA/5766',
#     u'profileIcon': 20,
#     u'summonerId': 621,
#     u'summonerName': u'Ghost Ghost'}},
#   {u'participantId': 10,
#    u'player': {u'matchHistoryUri': u'/v1/stats/player_history/NA/32968025',
#     u'profileIcon': 575,
#     u'summonerId': 20129804,
#     u'summonerName': u'rqspaceinvad'}}],
#  u'participants': [{u'championId': 13,
#    u'highestAchievedSeasonTier': u'CHALLENGER',
#    u'masteries': [{u'masteryId': 6211, u'rank': 5},
#     {u'masteryId': 6221, u'rank': 1},
#     {u'masteryId': 6231, u'rank': 5},
#     {u'masteryId': 6241, u'rank': 1},
#     {u'masteryId': 6312, u'rank': 5},
#     {u'masteryId': 6321, u'rank': 1},
#     {u'masteryId': 6331, u'rank': 3},
#     {u'masteryId': 6332, u'rank': 2},
#     {u'masteryId': 6343, u'rank': 1},
#     {u'masteryId': 6351, u'rank': 5},
#     {u'masteryId': 6361, u'rank': 1}],
#    u'participantId': 1,
#    u'runes': [{u'rank': 9, u'runeId': 5273},
#     {u'rank': 3, u'runeId': 5289},
#     {u'rank': 6, u'runeId': 5296},
#     {u'rank': 9, u'runeId': 5316},
#     {u'rank': 3, u'runeId': 5357}],
#    u'spell1Id': 4,
#    u'spell2Id': 1,
#    u'stats': {u'assists': 1,
#     u'champLevel': 12,
#     u'combatPlayerScore': 0,
#     u'deaths': 5,
#     u'doubleKills': 0,
#     u'firstBloodAssist': False,
#     u'firstBloodKill': False,
#     u'firstInhibitorAssist': False,
#     u'firstInhibitorKill': False,
#     u'firstTowerAssist': False,
#     u'firstTowerKill': False,
#     u'goldEarned': 7076,
#     u'goldSpent': 6525,
#     u'inhibitorKills': 0,
#     u'item0': 2031,
#     u'item1': 3108,
#     u'item2': 3158,
#     u'item3': 3070,
#     u'item4': 3802,
#     u'item5': 3027,
#     u'item6': 3363,
#     u'killingSprees': 0,
#     u'kills': 1,
#     u'largestCriticalStrike': 522,
#     u'largestKillingSpree': 0,
#     u'largestMultiKill': 1,
#     u'magicDamageDealt': 76935,
#     u'magicDamageDealtToChampions': 8560,
#     u'magicDamageTaken': 5613,
#     u'minionsKilled': 164,
#     u'neutralMinionsKilled': 4,
#     u'neutralMinionsKilledEnemyJungle': 0,
#     u'neutralMinionsKilledTeamJungle': 4,
#     u'objectivePlayerScore': 0,
#     u'pentaKills': 0,
#     u'physicalDamageDealt': 9192,
#     u'physicalDamageDealtToChampions': 448,
#     u'physicalDamageTaken': 5045,
#     u'quadraKills': 0,
#     u'sightWardsBoughtInGame': 0,
#     u'totalDamageDealt': 86512,
#     u'totalDamageDealtToChampions': 9008,
#     u'totalDamageTaken': 11197,
#     u'totalHeal': 789,
#     u'totalPlayerScore': 0,
#     u'totalScoreRank': 0,
#     u'totalTimeCrowdControlDealt': 52,
#     u'totalUnitsHealed': 1,
#     u'towerKills': 0,
#     u'tripleKills': 0,
#     u'trueDamageDealt': 384,
#     u'trueDamageDealtToChampions': 0,
#     u'trueDamageTaken': 538,
#     u'unrealKills': 0,
#     u'visionWardsBoughtInGame': 3,
#     u'wardsKilled': 1,
#     u'wardsPlaced': 9,
#     u'winner': False},
#    u'teamId': 100,
#    u'timeline': {u'creepsPerMinDeltas': {u'tenToTwenty': 8.3,
#      u'zeroToTen': 7.3},
#     u'csDiffPerMinDeltas': {u'tenToTwenty': -0.9999999999999996,
#      u'zeroToTen': 0.3999999999999999},
#     u'damageTakenDiffPerMinDeltas': {u'tenToTwenty': -139.79999999999995,
#      u'zeroToTen': -76.49999999999997},
#     u'damageTakenPerMinDeltas': {u'tenToTwenty': 524.9,
#      u'zeroToTen': 301.20000000000005},
#     u'goldPerMinDeltas': {u'tenToTwenty': 364.3, u'zeroToTen': 254.7},
#     u'lane': u'MIDDLE',
#     u'role': u'SOLO',
#     u'xpDiffPerMinDeltas': {u'tenToTwenty': -151.09999999999997,
#      u'zeroToTen': -83.4},
#     u'xpPerMinDeltas': {u'tenToTwenty': 462.5, u'zeroToTen': 421.4}}},
#   {u'championId': 107,
#    u'highestAchievedSeasonTier': u'MASTER',
#    u'masteries': [{u'masteryId': 6111, u'rank': 5},
#     {u'masteryId': 6121, u'rank': 1},
#     {u'masteryId': 6134, u'rank': 5},
#     {u'masteryId': 6141, u'rank': 1},
#     {u'masteryId': 6312, u'rank': 5},
#     {u'masteryId': 6321, u'rank': 1},
#     {u'masteryId': 6331, u'rank': 5},
#     {u'masteryId': 6341, u'rank': 1},
#     {u'masteryId': 6351, u'rank': 5},
#     {u'masteryId': 6362, u'rank': 1}],
#    u'participantId': 2,
#    u'runes': [{u'rank': 8, u'runeId': 5245},
#     {u'rank': 1, u'runeId': 5251},
#     {u'rank': 9, u'runeId': 5289},
#     {u'rank': 9, u'runeId': 5316},
#     {u'rank': 3, u'runeId': 5335}],
#    u'spell1Id': 4,
#    u'spell2Id': 11,
#    u'stats': {u'assists': 1,
#     u'champLevel': 11,
#     u'combatPlayerScore': 0,
#     u'deaths': 7,
#     u'doubleKills': 0,
#     u'firstBloodAssist': False,
#     u'firstBloodKill': False,
#     u'firstInhibitorAssist': False,
#     u'firstInhibitorKill': False,
#     u'firstTowerAssist': False,
#     u'firstTowerKill': False,
#     u'goldEarned': 7557,
#     u'goldSpent': 7175,
#     u'inhibitorKills': 0,
#     u'item0': 3071,
#     u'item1': 1412,
#     u'item2': 1028,
#     u'item3': 0,
#     u'item4': 3158,
#     u'item5': 0,
#     u'item6': 3364,
#     u'killingSprees': 2,
#     u'kills': 6,
#     u'largestCriticalStrike': 343,
#     u'largestKillingSpree': 2,
#     u'largestMultiKill': 1,
#     u'magicDamageDealt': 7777,
#     u'magicDamageDealtToChampions': 1483,
#     u'magicDamageTaken': 5770,
#     u'minionsKilled': 21,
#     u'neutralMinionsKilled': 70,
#     u'neutralMinionsKilledEnemyJungle': 27,
#     u'neutralMinionsKilledTeamJungle': 43,
#     u'objectivePlayerScore': 0,
#     u'pentaKills': 0,
#     u'physicalDamageDealt': 69633,
#     u'physicalDamageDealtToChampions': 9104,
#     u'physicalDamageTaken': 16180,
#     u'quadraKills': 0,
#     u'sightWardsBoughtInGame': 0,
#     u'totalDamageDealt': 83141,
#     u'totalDamageDealtToChampions': 11317,
#     u'totalDamageTaken': 22346,
#     u'totalHeal': 6069,
#     u'totalPlayerScore': 0,
#     u'totalScoreRank': 0,
#     u'totalTimeCrowdControlDealt': 382,
#     u'totalUnitsHealed': 1,
#     u'towerKills': 0,
#     u'tripleKills': 0,
#     u'trueDamageDealt': 5731,
#     u'trueDamageDealtToChampions': 730,
#     u'trueDamageTaken': 396,
#     u'unrealKills': 0,
#     u'visionWardsBoughtInGame': 0,
#     u'wardsKilled': 2,
#     u'wardsPlaced': 3,
#     u'winner': False},
#    u'teamId': 100,
#    u'timeline': {u'creepsPerMinDeltas': {u'tenToTwenty': 1.3,
#      u'zeroToTen': 0.4},
#     u'csDiffPerMinDeltas': {u'tenToTwenty': 0.0, u'zeroToTen': 0.0},
#     u'damageTakenDiffPerMinDeltas': {u'tenToTwenty': 82.99999999999989,
#      u'zeroToTen': 24.899999999999977},
#     u'damageTakenPerMinDeltas': {u'tenToTwenty': 1142.1999999999998,
#      u'zeroToTen': 717.2},
#     u'goldPerMinDeltas': {u'tenToTwenty': 408.0, u'zeroToTen': 268.0},
#     u'lane': u'JUNGLE',
#     u'role': u'NONE',
#     u'xpDiffPerMinDeltas': {u'tenToTwenty': 10.799999999999983,
#      u'zeroToTen': -135.7},
#     u'xpPerMinDeltas': {u'tenToTwenty': 541.0999999999999,
#      u'zeroToTen': 283.5}}},
#   {u'championId': 53,
#    u'highestAchievedSeasonTier': u'DIAMOND',
#    u'masteries': [{u'masteryId': 6212, u'rank': 5},
#     {u'masteryId': 6221, u'rank': 1},
#     {u'masteryId': 6232, u'rank': 5},
#     {u'masteryId': 6241, u'rank': 1},
#     {u'masteryId': 6251, u'rank': 5},
#     {u'masteryId': 6262, u'rank': 1},
#     {u'masteryId': 6311, u'rank': 5},
#     {u'masteryId': 6322, u'rank': 1},
#     {u'masteryId': 6331, u'rank': 5},
#     {u'masteryId': 6342, u'rank': 1}],
#    u'participantId': 3,
#    u'runes': [{u'rank': 9, u'runeId': 5260},
#     {u'rank': 9, u'runeId': 5287},
#     {u'rank': 9, u'runeId': 5316},
#     {u'rank': 3, u'runeId': 5365}],
#    u'spell1Id': 3,
#    u'spell2Id': 4,
#    u'stats': {u'assists': 2,
#     u'champLevel': 9,
#     u'combatPlayerScore': 0,
#     u'deaths': 6,
#     u'doubleKills': 0,
#     u'firstBloodAssist': False,
#     u'firstBloodKill': False,
#     u'firstInhibitorAssist': False,
#     u'firstInhibitorKill': False,
#     u'firstTowerAssist': False,
#     u'firstTowerKill': False,
#     u'goldEarned': 4760,
#     u'goldSpent': 4725,
#     u'inhibitorKills': 0,
#     u'item0': 2049,
#     u'item1': 3401,
#     u'item2': 3117,
#     u'item3': 1028,
#     u'item4': 0,
#     u'item5': 0,
#     u'item6': 3341,
#     u'killingSprees': 0,
#     u'kills': 0,
#     u'largestCriticalStrike': 0,
#     u'largestKillingSpree': 0,
#     u'largestMultiKill': 0,
#     u'magicDamageDealt': 7641,
#     u'magicDamageDealtToChampions': 2491,
#     u'magicDamageTaken': 7203,
#     u'minionsKilled': 20,
#     u'neutralMinionsKilled': 0,
#     u'neutralMinionsKilledEnemyJungle': 0,
#     u'neutralMinionsKilledTeamJungle': 0,
#     u'objectivePlayerScore': 0,
#     u'pentaKills': 0,
#     u'physicalDamageDealt': 4652,
#     u'physicalDamageDealtToChampions': 2067,
#     u'physicalDamageTaken': 10741,
#     u'quadraKills': 0,
#     u'sightWardsBoughtInGame': 0,
#     u'totalDamageDealt': 13909,
#     u'totalDamageDealtToChampions': 4559,
#     u'totalDamageTaken': 18292,
#     u'totalHeal': 788,
#     u'totalPlayerScore': 0,
#     u'totalScoreRank': 0,
#     u'totalTimeCrowdControlDealt': 82,
#     u'totalUnitsHealed': 5,
#     u'towerKills': 0,
#     u'tripleKills': 0,
#     u'trueDamageDealt': 1614,
#     u'trueDamageDealtToChampions': 0,
#     u'trueDamageTaken': 348,
#     u'unrealKills': 0,
#     u'visionWardsBoughtInGame': 1,
#     u'wardsKilled': 3,
#     u'wardsPlaced': 18,
#     u'winner': False},
#    u'teamId': 100,
#    u'timeline': {u'creepsPerMinDeltas': {u'tenToTwenty': 1.3,
#      u'zeroToTen': 0.7},
#     u'csDiffPerMinDeltas': {u'tenToTwenty': -1.6500000000000001,
#      u'zeroToTen': -1.0499999999999998},
#     u'damageTakenDiffPerMinDeltas': {u'tenToTwenty': 344.8999999999999,
#      u'zeroToTen': 146.55},
#     u'damageTakenPerMinDeltas': {u'tenToTwenty': 1031.1,
#      u'zeroToTen': 498.59999999999997},
#     u'goldPerMinDeltas': {u'tenToTwenty': 229.9, u'zeroToTen': 163.2},
#     u'lane': u'BOTTOM',
#     u'role': u'DUO_SUPPORT',
#     u'xpDiffPerMinDeltas': {u'tenToTwenty': -202.5,
#      u'zeroToTen': -55.750000000000014},
#     u'xpPerMinDeltas': {u'tenToTwenty': 264.20000000000005,
#      u'zeroToTen': 236.8}}},
#   {u'championId': 119,
#    u'highestAchievedSeasonTier': u'UNRANKED',
#    u'masteries': [{u'masteryId': 6111, u'rank': 5},
#     {u'masteryId': 6122, u'rank': 1},
#     {u'masteryId': 6131, u'rank': 3},
#     {u'masteryId': 6134, u'rank': 2},
#     {u'masteryId': 6142, u'rank': 1},
#     {u'masteryId': 6151, u'rank': 5},
#     {u'masteryId': 6161, u'rank': 1},
#     {u'masteryId': 6211, u'rank': 5},
#     {u'masteryId': 6223, u'rank': 1},
#     {u'masteryId': 6231, u'rank': 5},
#     {u'masteryId': 6241, u'rank': 1}],
#    u'participantId': 4,
#    u'runes': [{u'rank': 9, u'runeId': 5245},
#     {u'rank': 5, u'runeId': 5275},
#     {u'rank': 4, u'runeId': 5289},
#     {u'rank': 9, u'runeId': 5317},
#     {u'rank': 2, u'runeId': 5337},
#     {u'rank': 1, u'runeId': 5412}],
#    u'spell1Id': 4,
#    u'spell2Id': 7,
#    u'stats': {u'assists': 0,
#     u'champLevel': 10,
#     u'combatPlayerScore': 0,
#     u'deaths': 5,
#     u'doubleKills': 0,
#     u'firstBloodAssist': False,
#     u'firstBloodKill': True,
#     u'firstInhibitorAssist': False,
#     u'firstInhibitorKill': False,
#     u'firstTowerAssist': False,
#     u'firstTowerKill': False,
#     u'goldEarned': 6527,
#     u'goldSpent': 5975,
#     u'inhibitorKills': 0,
#     u'item0': 3142,
#     u'item1': 1055,
#     u'item2': 1038,
#     u'item3': 1001,
#     u'item4': 0,
#     u'item5': 1037,
#     u'item6': 3340,
#     u'killingSprees': 0,
#     u'kills': 1,
#     u'largestCriticalStrike': 0,
#     u'largestKillingSpree': 0,
#     u'largestMultiKill': 1,
#     u'magicDamageDealt': 0,
#     u'magicDamageDealtToChampions': 0,
#     u'magicDamageTaken': 4727,
#     u'minionsKilled': 139,
#     u'neutralMinionsKilled': 0,
#     u'neutralMinionsKilledEnemyJungle': 0,
#     u'neutralMinionsKilledTeamJungle': 0,
#     u'objectivePlayerScore': 0,
#     u'pentaKills': 0,
#     u'physicalDamageDealt': 59350,
#     u'physicalDamageDealtToChampions': 7359,
#     u'physicalDamageTaken': 6893,
#     u'quadraKills': 0,
#     u'sightWardsBoughtInGame': 0,
#     u'totalDamageDealt': 59350,
#     u'totalDamageDealtToChampions': 7359,
#     u'totalDamageTaken': 12187,
#     u'totalHeal': 1399,
#     u'totalPlayerScore': 0,
#     u'totalScoreRank': 0,
#     u'totalTimeCrowdControlDealt': 50,
#     u'totalUnitsHealed': 3,
#     u'towerKills': 0,
#     u'tripleKills': 0,
#     u'trueDamageDealt': 0,
#     u'trueDamageDealtToChampions': 0,
#     u'trueDamageTaken': 567,
#     u'unrealKills': 0,
#     u'visionWardsBoughtInGame': 0,
#     u'wardsKilled': 0,
#     u'wardsPlaced': 4,
#     u'winner': False},
#    u'teamId': 100,
#    u'timeline': {u'creepsPerMinDeltas': {u'tenToTwenty': 7.3999999999999995,
#      u'zeroToTen': 6.3},
#     u'csDiffPerMinDeltas': {u'tenToTwenty': -1.6500000000000001,
#      u'zeroToTen': -1.0499999999999998},
#     u'damageTakenDiffPerMinDeltas': {u'tenToTwenty': 344.8999999999999,
#      u'zeroToTen': 146.55},
#     u'damageTakenPerMinDeltas': {u'tenToTwenty': 584.6, u'zeroToTen': 312.9},
#     u'goldPerMinDeltas': {u'tenToTwenty': 300.9,
#      u'zeroToTen': 275.29999999999995},
#     u'lane': u'BOTTOM',
#     u'role': u'DUO_CARRY',
#     u'xpDiffPerMinDeltas': {u'tenToTwenty': -202.5,
#      u'zeroToTen': -55.750000000000014},
#     u'xpPerMinDeltas': {u'tenToTwenty': 378.2, u'zeroToTen': 277.7}}},
#   {u'championId': 57,
#    u'highestAchievedSeasonTier': u'DIAMOND',
#    u'masteries': [{u'masteryId': 6212, u'rank': 5},
#     {u'masteryId': 6223, u'rank': 1},
#     {u'masteryId': 6231, u'rank': 5},
#     {u'masteryId': 6241, u'rank': 1},
#     {u'masteryId': 6252, u'rank': 5},
#     {u'masteryId': 6261, u'rank': 1},
#     {u'masteryId': 6312, u'rank': 5},
#     {u'masteryId': 6322, u'rank': 1},
#     {u'masteryId': 6332, u'rank': 5},
#     {u'masteryId': 6343, u'rank': 1}],
#    u'participantId': 5,
#    u'runes': [{u'rank': 9, u'runeId': 5290},
#     {u'rank': 9, u'runeId': 5318},
#     {u'rank': 3, u'runeId': 5337},
#     {u'rank': 9, u'runeId': 5402}],
#    u'spell1Id': 12,
#    u'spell2Id': 4,
#    u'stats': {u'assists': 3,
#     u'champLevel': 11,
#     u'combatPlayerScore': 0,
#     u'deaths': 7,
#     u'doubleKills': 0,
#     u'firstBloodAssist': False,
#     u'firstBloodKill': False,
#     u'firstInhibitorAssist': False,
#     u'firstInhibitorKill': False,
#     u'firstTowerAssist': False,
#     u'firstTowerKill': False,
#     u'goldEarned': 6114,
#     u'goldSpent': 5825,
#     u'inhibitorKills': 0,
#     u'item0': 3047,
#     u'item1': 1056,
#     u'item2': 3211,
#     u'item3': 3068,
#     u'item4': 0,
#     u'item5': 0,
#     u'item6': 3363,
#     u'killingSprees': 0,
#     u'kills': 0,
#     u'largestCriticalStrike': 0,
#     u'largestKillingSpree': 0,
#     u'largestMultiKill': 0,
#     u'magicDamageDealt': 39077,
#     u'magicDamageDealtToChampions': 5026,
#     u'magicDamageTaken': 7409,
#     u'minionsKilled': 118,
#     u'neutralMinionsKilled': 1,
#     u'neutralMinionsKilledEnemyJungle': 0,
#     u'neutralMinionsKilledTeamJungle': 1,
#     u'objectivePlayerScore': 0,
#     u'pentaKills': 0,
#     u'physicalDamageDealt': 11345,
#     u'physicalDamageDealtToChampions': 2004,
#     u'physicalDamageTaken': 9418,
#     u'quadraKills': 0,
#     u'sightWardsBoughtInGame': 0,
#     u'totalDamageDealt': 50423,
#     u'totalDamageDealtToChampions': 7030,
#     u'totalDamageTaken': 17540,
#     u'totalHeal': 3856,
#     u'totalPlayerScore': 0,
#     u'totalScoreRank': 0,
#     u'totalTimeCrowdControlDealt': 325,
#     u'totalUnitsHealed': 1,
#     u'towerKills': 0,
#     u'tripleKills': 0,
#     u'trueDamageDealt': 0,
#     u'trueDamageDealtToChampions': 0,
#     u'trueDamageTaken': 712,
#     u'unrealKills': 0,
#     u'visionWardsBoughtInGame': 1,
#     u'wardsKilled': 1,
#     u'wardsPlaced': 4,
#     u'winner': False},
#    u'teamId': 100,
#    u'timeline': {u'creepsPerMinDeltas': {u'tenToTwenty': 4.0,
#      u'zeroToTen': 7.2},
#     u'csDiffPerMinDeltas': {u'tenToTwenty': -2.3, u'zeroToTen': 0.0},
#     u'damageTakenDiffPerMinDeltas': {u'tenToTwenty': 314.29999999999995,
#      u'zeroToTen': 46.300000000000026},
#     u'damageTakenPerMinDeltas': {u'tenToTwenty': 1111.4, u'zeroToTen': 418.5},
#     u'goldPerMinDeltas': {u'tenToTwenty': 284.4, u'zeroToTen': 238.8},
#     u'lane': u'TOP',
#     u'role': u'SOLO',
#     u'xpDiffPerMinDeltas': {u'tenToTwenty': -208.79999999999998,
#      u'zeroToTen': -22.799999999999983},
#     u'xpPerMinDeltas': {u'tenToTwenty': 354.20000000000005,
#      u'zeroToTen': 399.20000000000005}}},
#   {u'championId': 15,
#    u'highestAchievedSeasonTier': u'UNRANKED',
#    u'masteries': [{u'masteryId': 6111, u'rank': 5},
#     {u'masteryId': 6122, u'rank': 1},
#     {u'masteryId': 6131, u'rank': 5},
#     {u'masteryId': 6142, u'rank': 1},
#     {u'masteryId': 6151, u'rank': 5},
#     {u'masteryId': 6161, u'rank': 1},
#     {u'masteryId': 6312, u'rank': 5},
#     {u'masteryId': 6322, u'rank': 1},
#     {u'masteryId': 6331, u'rank': 5},
#     {u'masteryId': 6343, u'rank': 1}],
#    u'participantId': 6,
#    u'runes': [{u'rank': 7, u'runeId': 5245},
#     {u'rank': 2, u'runeId': 5247},
#     {u'rank': 9, u'runeId': 5289},
#     {u'rank': 9, u'runeId': 5317},
#     {u'rank': 2, u'runeId': 5337},
#     {u'rank': 1, u'runeId': 5347}],
#    u'spell1Id': 4,
#    u'spell2Id': 7,
#    u'stats': {u'assists': 4,
#     u'champLevel': 13,
#     u'combatPlayerScore': 0,
#     u'deaths': 2,
#     u'doubleKills': 1,
#     u'firstBloodAssist': False,
#     u'firstBloodKill': False,
#     u'firstInhibitorAssist': False,
#     u'firstInhibitorKill': False,
#     u'firstTowerAssist': False,
#     u'firstTowerKill': True,
#     u'goldEarned': 10927,
#     u'goldSpent': 7975,
#     u'inhibitorKills': 0,
#     u'item0': 2031,
#     u'item1': 3046,
#     u'item2': 3006,
#     u'item3': 0,
#     u'item4': 1055,
#     u'item5': 3508,
#     u'item6': 3340,
#     u'killingSprees': 1,
#     u'kills': 6,
#     u'largestCriticalStrike': 358,
#     u'largestKillingSpree': 5,
#     u'largestMultiKill': 2,
#     u'magicDamageDealt': 0,
#     u'magicDamageDealtToChampions': 0,
#     u'magicDamageTaken': 2067,
#     u'minionsKilled': 208,
#     u'neutralMinionsKilled': 4,
#     u'neutralMinionsKilledEnemyJungle': 3,
#     u'neutralMinionsKilledTeamJungle': 1,
#     u'objectivePlayerScore': 0,
#     u'pentaKills': 0,
#     u'physicalDamageDealt': 116773,
#     u'physicalDamageDealtToChampions': 13149,
#     u'physicalDamageTaken': 7186,
#     u'quadraKills': 0,
#     u'sightWardsBoughtInGame': 0,
#     u'totalDamageDealt': 117189,
#     u'totalDamageDealtToChampions': 13149,
#     u'totalDamageTaken': 9518,
#     u'totalHeal': 1826,
#     u'totalPlayerScore': 0,
#     u'totalScoreRank': 0,
#     u'totalTimeCrowdControlDealt': 1,
#     u'totalUnitsHealed': 2,
#     u'towerKills': 3,
#     u'tripleKills': 0,
#     u'trueDamageDealt': 415,
#     u'trueDamageDealtToChampions': 0,
#     u'trueDamageTaken': 264,
#     u'unrealKills': 0,
#     u'visionWardsBoughtInGame': 1,
#     u'wardsKilled': 4,
#     u'wardsPlaced': 6,
#     u'winner': True},
#    u'teamId': 200,
#    u'timeline': {u'creepsPerMinDeltas': {u'tenToTwenty': 10.7,
#      u'zeroToTen': 7.6},
#     u'csDiffPerMinDeltas': {u'tenToTwenty': 1.6500000000000001,
#      u'zeroToTen': 1.0499999999999998},
#     u'damageTakenDiffPerMinDeltas': {u'tenToTwenty': -344.8999999999999,
#      u'zeroToTen': -146.55},
#     u'damageTakenPerMinDeltas': {u'tenToTwenty': 413.3,
#      u'zeroToTen': 326.79999999999995},
#     u'goldPerMinDeltas': {u'tenToTwenty': 581.0, u'zeroToTen': 268.3},
#     u'lane': u'BOTTOM',
#     u'role': u'DUO_CARRY',
#     u'xpDiffPerMinDeltas': {u'tenToTwenty': 202.5,
#      u'zeroToTen': 55.750000000000014},
#     u'xpPerMinDeltas': {u'tenToTwenty': 632.9, u'zeroToTen': 314.0}}},
#   {u'championId': 121,
#    u'highestAchievedSeasonTier': u'DIAMOND',
#    u'masteries': [{u'masteryId': 6114, u'rank': 5},
#     {u'masteryId': 6121, u'rank': 1},
#     {u'masteryId': 6134, u'rank': 5},
#     {u'masteryId': 6141, u'rank': 1},
#     {u'masteryId': 6312, u'rank': 5},
#     {u'masteryId': 6321, u'rank': 1},
#     {u'masteryId': 6331, u'rank': 5},
#     {u'masteryId': 6343, u'rank': 1},
#     {u'masteryId': 6351, u'rank': 5},
#     {u'masteryId': 6362, u'rank': 1}],
#    u'participantId': 7,
#    u'runes': [{u'rank': 9, u'runeId': 5245},
#     {u'rank': 1, u'runeId': 5275},
#     {u'rank': 8, u'runeId': 5290},
#     {u'rank': 9, u'runeId': 5317},
#     {u'rank': 3, u'runeId': 5335}],
#    u'spell1Id': 4,
#    u'spell2Id': 11,
#    u'stats': {u'assists': 7,
#     u'champLevel': 13,
#     u'combatPlayerScore': 0,
#     u'deaths': 4,
#     u'doubleKills': 2,
#     u'firstBloodAssist': False,
#     u'firstBloodKill': False,
#     u'firstInhibitorAssist': True,
#     u'firstInhibitorKill': False,
#     u'firstTowerAssist': False,
#     u'firstTowerKill': False,
#     u'goldEarned': 10510,
#     u'goldSpent': 8500,
#     u'inhibitorKills': 0,
#     u'item0': 1400,
#     u'item1': 3077,
#     u'item2': 0,
#     u'item3': 3009,
#     u'item4': 3071,
#     u'item5': 1036,
#     u'item6': 3340,
#     u'killingSprees': 3,
#     u'kills': 10,
#     u'largestCriticalStrike': 0,
#     u'largestKillingSpree': 3,
#     u'largestMultiKill': 2,
#     u'magicDamageDealt': 3971,
#     u'magicDamageDealtToChampions': 2357,
#     u'magicDamageTaken': 3622,
#     u'minionsKilled': 28,
#     u'neutralMinionsKilled': 86,
#     u'neutralMinionsKilledEnemyJungle': 37,
#     u'neutralMinionsKilledTeamJungle': 49,
#     u'objectivePlayerScore': 0,
#     u'pentaKills': 0,
#     u'physicalDamageDealt': 114972,
#     u'physicalDamageDealtToChampions': 13887,
#     u'physicalDamageTaken': 15989,
#     u'quadraKills': 0,
#     u'sightWardsBoughtInGame': 0,
#     u'totalDamageDealt': 125441,
#     u'totalDamageDealtToChampions': 17214,
#     u'totalDamageTaken': 19905,
#     u'totalHeal': 8502,
#     u'totalPlayerScore': 0,
#     u'totalScoreRank': 0,
#     u'totalTimeCrowdControlDealt': 207,
#     u'totalUnitsHealed': 1,
#     u'towerKills': 1,
#     u'tripleKills': 0,
#     u'trueDamageDealt': 6497,
#     u'trueDamageDealtToChampions': 970,
#     u'trueDamageTaken': 294,
#     u'unrealKills': 0,
#     u'visionWardsBoughtInGame': 1,
#     u'wardsKilled': 1,
#     u'wardsPlaced': 9,
#     u'winner': True},
#    u'teamId': 200,
#    u'timeline': {u'creepsPerMinDeltas': {u'tenToTwenty': 1.3,
#      u'zeroToTen': 0.4},
#     u'csDiffPerMinDeltas': {u'tenToTwenty': 0.0, u'zeroToTen': 0.0},
#     u'damageTakenDiffPerMinDeltas': {u'tenToTwenty': -82.99999999999989,
#      u'zeroToTen': -24.899999999999977},
#     u'damageTakenPerMinDeltas': {u'tenToTwenty': 1059.2, u'zeroToTen': 692.3},
#     u'goldPerMinDeltas': {u'tenToTwenty': 458.9, u'zeroToTen': 351.2},
#     u'lane': u'JUNGLE',
#     u'role': u'NONE',
#     u'xpDiffPerMinDeltas': {u'tenToTwenty': -10.799999999999983,
#      u'zeroToTen': 135.7},
#     u'xpPerMinDeltas': {u'tenToTwenty': 530.3, u'zeroToTen': 419.2}}},
#   {u'championId': 412,
#    u'highestAchievedSeasonTier': u'DIAMOND',
#    u'masteries': [{u'masteryId': 6211, u'rank': 5},
#     {u'masteryId': 6223, u'rank': 1},
#     {u'masteryId': 6232, u'rank': 5},
#     {u'masteryId': 6241, u'rank': 1},
#     {u'masteryId': 6252, u'rank': 5},
#     {u'masteryId': 6262, u'rank': 1},
#     {u'masteryId': 6311, u'rank': 5},
#     {u'masteryId': 6322, u'rank': 1},
#     {u'masteryId': 6332, u'rank': 5},
#     {u'masteryId': 6342, u'rank': 1}],
#    u'participantId': 8,
#    u'runes': [{u'rank': 9, u'runeId': 5257},
#     {u'rank': 9, u'runeId': 5289},
#     {u'rank': 9, u'runeId': 5317},
#     {u'rank': 3, u'runeId': 5347}],
#    u'spell1Id': 4,
#    u'spell2Id': 3,
#    u'stats': {u'assists': 14,
#     u'champLevel': 11,
#     u'combatPlayerScore': 0,
#     u'deaths': 1,
#     u'doubleKills': 0,
#     u'firstBloodAssist': False,
#     u'firstBloodKill': False,
#     u'firstInhibitorAssist': False,
#     u'firstInhibitorKill': True,
#     u'firstTowerAssist': False,
#     u'firstTowerKill': False,
#     u'goldEarned': 7425,
#     u'goldSpent': 6225,
#     u'inhibitorKills': 1,
#     u'item0': 3107,
#     u'item1': 3117,
#     u'item2': 2045,
#     u'item3': 1033,
#     u'item4': 1033,
#     u'item5': 3302,
#     u'item6': 3364,
#     u'killingSprees': 1,
#     u'kills': 3,
#     u'largestCriticalStrike': 0,
#     u'largestKillingSpree': 2,
#     u'largestMultiKill': 1,
#     u'magicDamageDealt': 16119,
#     u'magicDamageDealtToChampions': 5098,
#     u'magicDamageTaken': 2488,
#     u'minionsKilled': 31,
#     u'neutralMinionsKilled': 0,
#     u'neutralMinionsKilledEnemyJungle': 0,
#     u'neutralMinionsKilledTeamJungle': 0,
#     u'objectivePlayerScore': 0,
#     u'pentaKills': 0,
#     u'physicalDamageDealt': 5531,
#     u'physicalDamageDealtToChampions': 1392,
#     u'physicalDamageTaken': 6393,
#     u'quadraKills': 0,
#     u'sightWardsBoughtInGame': 0,
#     u'totalDamageDealt': 22716,
#     u'totalDamageDealtToChampions': 7276,
#     u'totalDamageTaken': 8929,
#     u'totalHeal': 2713,
#     u'totalPlayerScore': 0,
#     u'totalScoreRank': 0,
#     u'totalTimeCrowdControlDealt': 203,
#     u'totalUnitsHealed': 4,
#     u'towerKills': 0,
#     u'tripleKills': 0,
#     u'trueDamageDealt': 1066,
#     u'trueDamageDealtToChampions': 785,
#     u'trueDamageTaken': 48,
#     u'unrealKills': 0,
#     u'visionWardsBoughtInGame': 3,
#     u'wardsKilled': 3,
#     u'wardsPlaced': 14,
#     u'winner': True},
#    u'teamId': 200,
#    u'timeline': {u'creepsPerMinDeltas': {u'tenToTwenty': 1.2999999999999998,
#      u'zeroToTen': 1.5},
#     u'csDiffPerMinDeltas': {u'tenToTwenty': 1.6500000000000001,
#      u'zeroToTen': 1.0499999999999998},
#     u'damageTakenDiffPerMinDeltas': {u'tenToTwenty': -344.8999999999999,
#      u'zeroToTen': -146.55},
#     u'damageTakenPerMinDeltas': {u'tenToTwenty': 512.6, u'zeroToTen': 191.6},
#     u'goldPerMinDeltas': {u'tenToTwenty': 371.3,
#      u'zeroToTen': 205.10000000000002},
#     u'lane': u'BOTTOM',
#     u'role': u'DUO_SUPPORT',
#     u'xpDiffPerMinDeltas': {u'tenToTwenty': 202.5,
#      u'zeroToTen': 55.750000000000014},
#     u'xpPerMinDeltas': {u'tenToTwenty': 414.5, u'zeroToTen': 312.0}}},
#   {u'championId': 4,
#    u'highestAchievedSeasonTier': u'UNRANKED',
#    u'masteries': [{u'masteryId': 6114, u'rank': 5},
#     {u'masteryId': 6122, u'rank': 1},
#     {u'masteryId': 6131, u'rank': 2},
#     {u'masteryId': 6134, u'rank': 3},
#     {u'masteryId': 6141, u'rank': 1},
#     {u'masteryId': 6312, u'rank': 5},
#     {u'masteryId': 6323, u'rank': 1},
#     {u'masteryId': 6331, u'rank': 5},
#     {u'masteryId': 6341, u'rank': 1},
#     {u'masteryId': 6351, u'rank': 5},
#     {u'masteryId': 6362, u'rank': 1}],
#    u'participantId': 9,
#    u'runes': [{u'rank': 9, u'runeId': 5273},
#     {u'rank': 9, u'runeId': 5296},
#     {u'rank': 9, u'runeId': 5316},
#     {u'rank': 3, u'runeId': 5365}],
#    u'spell1Id': 4,
#    u'spell2Id': 14,
#    u'stats': {u'assists': 7,
#     u'champLevel': 14,
#     u'combatPlayerScore': 0,
#     u'deaths': 0,
#     u'doubleKills': 1,
#     u'firstBloodAssist': False,
#     u'firstBloodKill': False,
#     u'firstInhibitorAssist': True,
#     u'firstInhibitorKill': False,
#     u'firstTowerAssist': False,
#     u'firstTowerKill': False,
#     u'goldEarned': 11876,
#     u'goldSpent': 7850,
#     u'inhibitorKills': 0,
#     u'item0': 1056,
#     u'item1': 3027,
#     u'item2': 0,
#     u'item3': 1082,
#     u'item4': 3100,
#     u'item5': 3158,
#     u'item6': 3363,
#     u'killingSprees': 1,
#     u'kills': 9,
#     u'largestCriticalStrike': 0,
#     u'largestKillingSpree': 9,
#     u'largestMultiKill': 2,
#     u'magicDamageDealt': 105276,
#     u'magicDamageDealtToChampions': 14372,
#     u'magicDamageTaken': 5257,
#     u'minionsKilled': 173,
#     u'neutralMinionsKilled': 4,
#     u'neutralMinionsKilledEnemyJungle': 1,
#     u'neutralMinionsKilledTeamJungle': 3,
#     u'objectivePlayerScore': 0,
#     u'pentaKills': 0,
#     u'physicalDamageDealt': 16467,
#     u'physicalDamageDealtToChampions': 2142,
#     u'physicalDamageTaken': 7464,
#     u'quadraKills': 0,
#     u'sightWardsBoughtInGame': 0,
#     u'totalDamageDealt': 123822,
#     u'totalDamageDealtToChampions': 17321,
#     u'totalDamageTaken': 12721,
#     u'totalHeal': 3596,
#     u'totalPlayerScore': 0,
#     u'totalScoreRank': 0,
#     u'totalTimeCrowdControlDealt': 331,
#     u'totalUnitsHealed': 1,
#     u'towerKills': 2,
#     u'tripleKills': 0,
#     u'trueDamageDealt': 2078,
#     u'trueDamageDealtToChampions': 806,
#     u'trueDamageTaken': 0,
#     u'unrealKills': 0,
#     u'visionWardsBoughtInGame': 2,
#     u'wardsKilled': 2,
#     u'wardsPlaced': 9,
#     u'winner': True},
#    u'teamId': 200,
#    u'timeline': {u'creepsPerMinDeltas': {u'tenToTwenty': 9.3,
#      u'zeroToTen': 6.9},
#     u'csDiffPerMinDeltas': {u'tenToTwenty': 0.9999999999999996,
#      u'zeroToTen': -0.3999999999999999},
#     u'damageTakenDiffPerMinDeltas': {u'tenToTwenty': 139.79999999999995,
#      u'zeroToTen': 76.49999999999997},
#     u'damageTakenPerMinDeltas': {u'tenToTwenty': 664.7, u'zeroToTen': 377.7},
#     u'goldPerMinDeltas': {u'tenToTwenty': 588.8, u'zeroToTen': 376.2},
#     u'lane': u'MIDDLE',
#     u'role': u'SOLO',
#     u'xpDiffPerMinDeltas': {u'tenToTwenty': 151.09999999999997,
#      u'zeroToTen': 83.4},
#     u'xpPerMinDeltas': {u'tenToTwenty': 613.5999999999999,
#      u'zeroToTen': 504.79999999999995}}},
#   {u'championId': 111,
#    u'highestAchievedSeasonTier': u'DIAMOND',
#    u'masteries': [{u'masteryId': 6114, u'rank': 5},
#     {u'masteryId': 6122, u'rank': 1},
#     {u'masteryId': 6134, u'rank': 5},
#     {u'masteryId': 6143, u'rank': 1},
#     {u'masteryId': 6211, u'rank': 5},
#     {u'masteryId': 6223, u'rank': 1},
#     {u'masteryId': 6231, u'rank': 5},
#     {u'masteryId': 6241, u'rank': 1},
#     {u'masteryId': 6251, u'rank': 5},
#     {u'masteryId': 6262, u'rank': 1}],
#    u'participantId': 10,
#    u'runes': [{u'rank': 9, u'runeId': 5247},
#     {u'rank': 9, u'runeId': 5290},
#     {u'rank': 9, u'runeId': 5316},
#     {u'rank': 3, u'runeId': 5347}],
#    u'spell1Id': 4,
#    u'spell2Id': 12,
#    u'stats': {u'assists': 11,
#     u'champLevel': 13,
#     u'combatPlayerScore': 0,
#     u'deaths': 1,
#     u'doubleKills': 0,
#     u'firstBloodAssist': False,
#     u'firstBloodKill': False,
#     u'firstInhibitorAssist': True,
#     u'firstInhibitorKill': False,
#     u'firstTowerAssist': False,
#     u'firstTowerKill': False,
#     u'goldEarned': 8420,
#     u'goldSpent': 6450,
#     u'inhibitorKills': 0,
#     u'item0': 3751,
#     u'item1': 2033,
#     u'item2': 3065,
#     u'item3': 3047,
#     u'item4': 1031,
#     u'item5': 0,
#     u'item6': 3340,
#     u'killingSprees': 1,
#     u'kills': 2,
#     u'largestCriticalStrike': 0,
#     u'largestKillingSpree': 2,
#     u'largestMultiKill': 1,
#     u'magicDamageDealt': 51628,
#     u'magicDamageDealtToChampions': 7509,
#     u'magicDamageTaken': 5077,
#     u'minionsKilled': 143,
#     u'neutralMinionsKilled': 6,
#     u'neutralMinionsKilledEnemyJungle': 0,
#     u'neutralMinionsKilledTeamJungle': 6,
#     u'objectivePlayerScore': 0,
#     u'pentaKills': 0,
#     u'physicalDamageDealt': 18678,
#     u'physicalDamageDealtToChampions': 3745,
#     u'physicalDamageTaken': 8947,
#     u'quadraKills': 0,
#     u'sightWardsBoughtInGame': 0,
#     u'totalDamageDealt': 70327,
#     u'totalDamageDealtToChampions': 11255,
#     u'totalDamageTaken': 14148,
#     u'totalHeal': 1468,
#     u'totalPlayerScore': 0,
#     u'totalScoreRank': 0,
#     u'totalTimeCrowdControlDealt': 439,
#     u'totalUnitsHealed': 1,
#     u'towerKills': 0,
#     u'tripleKills': 0,
#     u'trueDamageDealt': 20,
#     u'trueDamageDealtToChampions': 0,
#     u'trueDamageTaken': 124,
#     u'unrealKills': 0,
#     u'visionWardsBoughtInGame': 2,
#     u'wardsKilled': 0,
#     u'wardsPlaced': 8,
#     u'winner': True},
#    u'teamId': 200,
#    u'timeline': {u'creepsPerMinDeltas': {u'tenToTwenty': 6.3,
#      u'zeroToTen': 7.2},
#     u'csDiffPerMinDeltas': {u'tenToTwenty': 2.3, u'zeroToTen': 0.0},
#     u'damageTakenDiffPerMinDeltas': {u'tenToTwenty': -314.29999999999995,
#      u'zeroToTen': -46.300000000000026},
#     u'damageTakenPerMinDeltas': {u'tenToTwenty': 797.1, u'zeroToTen': 372.2},
#     u'goldPerMinDeltas': {u'tenToTwenty': 432.9, u'zeroToTen': 243.6},
#     u'lane': u'TOP',
#     u'role': u'SOLO',
#     u'xpDiffPerMinDeltas': {u'tenToTwenty': 208.79999999999998,
#      u'zeroToTen': 22.799999999999983},
#     u'xpPerMinDeltas': {u'tenToTwenty': 563.0, u'zeroToTen': 422.0}}}],
#  u'platformId': u'NA1',
#  u'queueType': u'TEAM_BUILDER_RANKED_SOLO',
#  u'region': u'NA',
#  u'season': u'PRESEASON2017',
#  u'teams': [{u'bans': [{u'championId': 164, u'pickTurn': 1},
#     {u'championId': 7, u'pickTurn': 3},
#     {u'championId': 90, u'pickTurn': 5}],
#    u'baronKills': 0,
#    u'dominionVictoryScore': 0,
#    u'dragonKills': 0,
#    u'firstBaron': False,
#    u'firstBlood': True,
#    u'firstDragon': False,
#    u'firstInhibitor': False,
#    u'firstRiftHerald': False,
#    u'firstTower': False,
#    u'inhibitorKills': 0,
#    u'riftHeraldKills': 0,
#    u'teamId': 100,
#    u'towerKills': 0,
#    u'vilemawKills': 0,
#    u'winner': False},
#   {u'bans': [{u'championId': 120, u'pickTurn': 2},
#     {u'championId': 55, u'pickTurn': 4},
#     {u'championId': 19, u'pickTurn': 6}],
#    u'baronKills': 0,
#    u'dominionVictoryScore': 0,
#    u'dragonKills': 2,
#    u'firstBaron': False,
#    u'firstBlood': False,
#    u'firstDragon': True,
#    u'firstInhibitor': True,
#    u'firstRiftHerald': False,
#    u'firstTower': True,
#    u'inhibitorKills': 1,
#    u'riftHeraldKills': 0,
#    u'teamId': 200,
#    u'towerKills': 7,
#    u'vilemawKills': 0,
#    u'winner': True}]}

# %%
matchID[2]
# Out:
# '2410767351'

# %%
print matchData1['teams'] #he was on team 200

#{'matchid'},
team_col_header = ['firstDragon','bans','firstInhibitor','baronKills','firstRiftHerald','winner','firstBaron','riftheraldKills',
                  'firstBlood','teamId','firstTower','vilemawKills','inhibitorKills','towerKills','dominionVictoryScore',
                  'dragonKills']

#matchid=['2410767351']
matchID=['2410767351']
firstDragon=[]
bans=[]
firstInhibitor=[]
baronKills=[]
firstRiftHerald=[]
winner=[]
firstBaron=[]
riftHeraldKills=[]
firstBlood=[]
teamId=[]
firstTower=[]
vilemawKills=[]
inhibitorKills=[]
towerKills=[]
dominionVictoryScore=[]
dragonKills=[]

matchID.append('2410767351')

for teams in matchData1['teams']:
    firstDragon.append(teams[u'firstDragon'])
    bans.append(teams[u'bans'])
    firstInhibitor.append(teams[u'firstInhibitor'])
    baronKills.append(teams[u'baronKills'])
    firstRiftHerald.append(teams[u'firstRiftHerald'])
    winner.append(teams[u'winner'])
    firstBaron.append(teams[u'firstBaron'])
    riftHeraldKills.append(teams[u'riftHeraldKills'])
    firstBlood.append(teams[u'firstBlood'])
    teamId.append(teams[u'teamId'])
    firstTower.append(teams[u'firstTower'])
    vilemawKills.append(teams[u'vilemawKills'])
    inhibitorKills.append(teams[u'inhibitorKills'])
    towerKills.append(teams[u'towerKills'])
    dominionVictoryScore.append(teams[u'dominionVictoryScore'])
    dragonKills.append(teams[u'dragonKills'])
    
dfMatch1 = pd.DataFrame([matchID,firstDragon,bans,firstInhibitor,baronKills,firstRiftHerald,winner,firstBaron,riftHeraldKills,
                  firstBlood,teamId,firstTower,vilemawKills,inhibitorKills,towerKills,dominionVictoryScore,
                  dragonKills]).T

dfMatch1.columns=['matchID','firstDragon','bans','firstInhibitor','baronKills','firstRiftHerald','winner','firstBaron','riftheraldKills',
                  'firstBlood','teamId','firstTower','vilemawKills','inhibitorKills','towerKills','dominionVictoryScore',
                  'dragonKills']

dfghostTeam1= dfMatch1.drop([0])
# Out:
# [{u'firstDragon': False, u'bans': [{u'pickTurn': 1, u'championId': 164}, {u'pickTurn': 3, u'championId': 7}, {u'pickTurn': 5, u'championId': 90}], u'firstInhibitor': False, u'baronKills': 0, u'firstRiftHerald': False, u'winner': False, u'firstBaron': False, u'riftHeraldKills': 0, u'firstBlood': True, u'teamId': 100, u'firstTower': False, u'vilemawKills': 0, u'inhibitorKills': 0, u'towerKills': 0, u'dominionVictoryScore': 0, u'dragonKills': 0}, {u'firstDragon': True, u'bans': [{u'pickTurn': 2, u'championId': 120}, {u'pickTurn': 4, u'championId': 55}, {u'pickTurn': 6, u'championId': 19}], u'firstInhibitor': True, u'baronKills': 0, u'firstRiftHerald': False, u'winner': True, u'firstBaron': False, u'riftHeraldKills': 0, u'firstBlood': False, u'teamId': 200, u'firstTower': True, u'vilemawKills': 0, u'inhibitorKills': 1, u'towerKills': 7, u'dominionVictoryScore': 0, u'dragonKills': 2}]

# %%
matchID[3]
# Out:
# '2410774976'

# %%
matchRequest =Request('https://na.api.pvp.net/api/lol/na/v2.2/match/'+matchID[3]+'?api_key=RGAPI-6b4e9139-2121-4820-8cd9-371891441c4b')
responseMatch = urlopen(matchRequest)
loadMatch = responseMatch.read()
matchData3 = json.loads(loadMatch)
matchData3
#matchID[1]

print matchData1['teams'] #he was on team 100

#{'matchid'},
team_col_header = ['firstDragon','bans','firstInhibitor','baronKills','firstRiftHerald','winner','firstBaron','riftheraldKills',
                  'firstBlood','teamId','firstTower','vilemawKills','inhibitorKills','towerKills','dominionVictoryScore',
                  'dragonKills']

#matchid=['2410774976']
match=[]
firstDragon=[]
bans=[]
firstInhibitor=[]
baronKills=[]
firstRiftHerald=[]
winner=[]
firstBaron=[]
riftHeraldKills=[]
firstBlood=[]
teamId=[]
firstTower=[]
vilemawKills=[]
inhibitorKills=[]
towerKills=[]
dominionVictoryScore=[]
dragonKills=[]

for teams in matchData3['teams']:
    firstDragon.append(teams[u'firstDragon'])
    bans.append(teams[u'bans'])
    firstInhibitor.append(teams[u'firstInhibitor'])
    baronKills.append(teams[u'baronKills'])
    firstRiftHerald.append(teams[u'firstRiftHerald'])
    winner.append(teams[u'winner'])
    firstBaron.append(teams[u'firstBaron'])
    riftHeraldKills.append(teams[u'riftHeraldKills'])
    firstBlood.append(teams[u'firstBlood'])
    teamId.append(teams[u'teamId'])
    firstTower.append(teams[u'firstTower'])
    vilemawKills.append(teams[u'vilemawKills'])
    inhibitorKills.append(teams[u'inhibitorKills'])
    towerKills.append(teams[u'towerKills'])
    dominionVictoryScore.append(teams[u'dominionVictoryScore'])
    dragonKills.append(teams[u'dragonKills'])
    
dfMatch3 = pd.DataFrame([firstDragon,bans,firstInhibitor,baronKills,firstRiftHerald,winner,firstBaron,riftHeraldKills,
                  firstBlood,teamId,firstTower,vilemawKills,inhibitorKills,towerKills,dominionVictoryScore,
                  dragonKills]).T

dfMatch3.columns=['firstDragon','bans','firstInhibitor','baronKills','firstRiftHerald','winner','firstBaron','riftheraldKills',
                  'firstBlood','teamId','firstTower','vilemawKills','inhibitorKills','towerKills','dominionVictoryScore',
                  'dragonKills']
dfMatch3.T
# Out:
# [{u'firstDragon': False, u'bans': [{u'pickTurn': 1, u'championId': 164}, {u'pickTurn': 3, u'championId': 7}, {u'pickTurn': 5, u'championId': 90}], u'firstInhibitor': False, u'baronKills': 0, u'firstRiftHerald': False, u'winner': False, u'firstBaron': False, u'riftHeraldKills': 0, u'firstBlood': True, u'teamId': 100, u'firstTower': False, u'vilemawKills': 0, u'inhibitorKills': 0, u'towerKills': 0, u'dominionVictoryScore': 0, u'dragonKills': 0}, {u'firstDragon': True, u'bans': [{u'pickTurn': 2, u'championId': 120}, {u'pickTurn': 4, u'championId': 55}, {u'pickTurn': 6, u'championId': 19}], u'firstInhibitor': True, u'baronKills': 0, u'firstRiftHerald': False, u'winner': True, u'firstBaron': False, u'riftHeraldKills': 0, u'firstBlood': False, u'teamId': 200, u'firstTower': True, u'vilemawKills': 0, u'inhibitorKills': 1, u'towerKills': 7, u'dominionVictoryScore': 0, u'dragonKills': 2}]
#                                                                       0  \
# firstDragon                                                       False
# bans                  [{u'pickTurn': 1, u'championId': 55}, {u'pickT...
# firstInhibitor                                                    False
# baronKills                                                            0
# firstRiftHerald                                                    True
# winner                                                            False
# firstBaron                                                        False
# riftheraldKills                                                       1
# firstBlood                                                        False
# teamId                                                              100
# firstTower                                                        False
# vilemawKills                                                          0
# inhibitorKills                                                        0
# towerKills                                                            4
# dominionVictoryScore                                                  0
# dragonKills                                                           1
#
#                                                                       1
# firstDragon                                                        True
# bans                  [{u'pickTurn': 2, u'championId': 164}, {u'pick...
# firstInhibitor                                                     True
# baronKills                                                            1
# firstRiftHerald                                                   False
# winner                                                             True
# firstBaron                                                         True
# riftheraldKills                                                       0
# firstBlood                                                         True
# teamId                                                              200
# firstTower                                                         True
# vilemawKills                                                          0
# inhibitorKills                                                        4
# towerKills                                                           11
# dominionVictoryScore                                                  0
# dragonKills                                                           2

# %%
matchID[4]
# Out:
# '2410881353'

# %%
matchRequest =Request('https://na.api.pvp.net/api/lol/na/v2.2/match/'+matchID[4]+'?api_key=RGAPI-6b4e9139-2121-4820-8cd9-371891441c4b')
responseMatch = urlopen(matchRequest)
loadMatch = responseMatch.read()
matchData4 = json.loads(loadMatch)
matchData4
#matchID[1]

print matchData1['teams'] #he was on team 100

#{'matchid'},
team_col_header = ['firstDragon','bans','firstInhibitor','baronKills','firstRiftHerald','winner','firstBaron','riftheraldKills',
                  'firstBlood','teamId','firstTower','vilemawKills','inhibitorKills','towerKills','dominionVictoryScore',
                  'dragonKills']

#matchid=['2410881353']
match=[]
firstDragon=[]
bans=[]
firstInhibitor=[]
baronKills=[]
firstRiftHerald=[]
winner=[]
firstBaron=[]
riftHeraldKills=[]
firstBlood=[]
teamId=[]
firstTower=[]
vilemawKills=[]
inhibitorKills=[]
towerKills=[]
dominionVictoryScore=[]
dragonKills=[]

for teams in matchData4['teams']:
    firstDragon.append(teams[u'firstDragon'])
    bans.append(teams[u'bans'])
    firstInhibitor.append(teams[u'firstInhibitor'])
    baronKills.append(teams[u'baronKills'])
    firstRiftHerald.append(teams[u'firstRiftHerald'])
    winner.append(teams[u'winner'])
    firstBaron.append(teams[u'firstBaron'])
    riftHeraldKills.append(teams[u'riftHeraldKills'])
    firstBlood.append(teams[u'firstBlood'])
    teamId.append(teams[u'teamId'])
    firstTower.append(teams[u'firstTower'])
    vilemawKills.append(teams[u'vilemawKills'])
    inhibitorKills.append(teams[u'inhibitorKills'])
    towerKills.append(teams[u'towerKills'])
    dominionVictoryScore.append(teams[u'dominionVictoryScore'])
    dragonKills.append(teams[u'dragonKills'])
    
dfMatch4 = pd.DataFrame([firstDragon,bans,firstInhibitor,baronKills,firstRiftHerald,winner,firstBaron,riftHeraldKills,
                  firstBlood,teamId,firstTower,vilemawKills,inhibitorKills,towerKills,dominionVictoryScore,
                  dragonKills]).T

dfMatch4.columns=['firstDragon','bans','firstInhibitor','baronKills','firstRiftHerald','winner','firstBaron','riftheraldKills',
                  'firstBlood','teamId','firstTower','vilemawKills','inhibitorKills','towerKills','dominionVictoryScore',
                  'dragonKills']
dfMatch4.T
# Out:
# [{u'firstDragon': False, u'bans': [{u'pickTurn': 1, u'championId': 164}, {u'pickTurn': 3, u'championId': 7}, {u'pickTurn': 5, u'championId': 90}], u'firstInhibitor': False, u'baronKills': 0, u'firstRiftHerald': False, u'winner': False, u'firstBaron': False, u'riftHeraldKills': 0, u'firstBlood': True, u'teamId': 100, u'firstTower': False, u'vilemawKills': 0, u'inhibitorKills': 0, u'towerKills': 0, u'dominionVictoryScore': 0, u'dragonKills': 0}, {u'firstDragon': True, u'bans': [{u'pickTurn': 2, u'championId': 120}, {u'pickTurn': 4, u'championId': 55}, {u'pickTurn': 6, u'championId': 19}], u'firstInhibitor': True, u'baronKills': 0, u'firstRiftHerald': False, u'winner': True, u'firstBaron': False, u'riftHeraldKills': 0, u'firstBlood': False, u'teamId': 200, u'firstTower': True, u'vilemawKills': 0, u'inhibitorKills': 1, u'towerKills': 7, u'dominionVictoryScore': 0, u'dragonKills': 2}]
#                                                                       0  \
# firstDragon                                                        True
# bans                  [{u'pickTurn': 1, u'championId': 121}, {u'pick...
# firstInhibitor                                                    False
# baronKills                                                            0
# firstRiftHerald                                                   False
# winner                                                             True
# firstBaron                                                        False
# riftheraldKills                                                       0
# firstBlood                                                         True
# teamId                                                              100
# firstTower                                                         True
# vilemawKills                                                          0
# inhibitorKills                                                        0
# towerKills                                                            5
# dominionVictoryScore                                                  0
# dragonKills                                                           1
#
#                                                                       1
# firstDragon                                                       False
# bans                  [{u'pickTurn': 2, u'championId': 107}, {u'pick...
# firstInhibitor                                                    False
# baronKills                                                            0
# firstRiftHerald                                                   False
# winner                                                            False
# firstBaron                                                        False
# riftheraldKills                                                       0
# firstBlood                                                        False
# teamId                                                              200
# firstTower                                                        False
# vilemawKills                                                          0
# inhibitorKills                                                        0
# towerKills                                                            1
# dominionVictoryScore                                                  0
# dragonKills                                                           1

# %%
matchID[5]
# Out:
# '2410883736'

# %%
matchRequest =Request('https://na.api.pvp.net/api/lol/na/v2.2/match/'+matchID[5]+'?api_key=RGAPI-6b4e9139-2121-4820-8cd9-371891441c4b')
responseMatch = urlopen(matchRequest)
loadMatch = responseMatch.read()
matchData5 = json.loads(loadMatch)
matchData5
#matchID[1]

print matchData1['teams'] #he was on team 100

#{'matchid'},
team_col_header = ['firstDragon','bans','firstInhibitor','baronKills','firstRiftHerald','winner','firstBaron','riftheraldKills',
                  'firstBlood','teamId','firstTower','vilemawKills','inhibitorKills','towerKills','dominionVictoryScore',
                  'dragonKills']

#matchid=['2410883736']
match=[]
firstDragon=[]
bans=[]
firstInhibitor=[]
baronKills=[]
firstRiftHerald=[]
winner=[]
firstBaron=[]
riftHeraldKills=[]
firstBlood=[]
teamId=[]
firstTower=[]
vilemawKills=[]
inhibitorKills=[]
towerKills=[]
dominionVictoryScore=[]
dragonKills=[]

for teams in matchData5['teams']:
    firstDragon.append(teams[u'firstDragon'])
    bans.append(teams[u'bans'])
    firstInhibitor.append(teams[u'firstInhibitor'])
    baronKills.append(teams[u'baronKills'])
    firstRiftHerald.append(teams[u'firstRiftHerald'])
    winner.append(teams[u'winner'])
    firstBaron.append(teams[u'firstBaron'])
    riftHeraldKills.append(teams[u'riftHeraldKills'])
    firstBlood.append(teams[u'firstBlood'])
    teamId.append(teams[u'teamId'])
    firstTower.append(teams[u'firstTower'])
    vilemawKills.append(teams[u'vilemawKills'])
    inhibitorKills.append(teams[u'inhibitorKills'])
    towerKills.append(teams[u'towerKills'])
    dominionVictoryScore.append(teams[u'dominionVictoryScore'])
    dragonKills.append(teams[u'dragonKills'])
    
dfMatch5 = pd.DataFrame([firstDragon,bans,firstInhibitor,baronKills,firstRiftHerald,winner,firstBaron,riftHeraldKills,
                  firstBlood,teamId,firstTower,vilemawKills,inhibitorKills,towerKills,dominionVictoryScore,
                  dragonKills]).T

dfMatch5.columns=['firstDragon','bans','firstInhibitor','baronKills','firstRiftHerald','winner','firstBaron','riftheraldKills',
                  'firstBlood','teamId','firstTower','vilemawKills','inhibitorKills','towerKills','dominionVictoryScore',
                  'dragonKills']
dfMatch5.T
# Out:
# [{u'firstDragon': False, u'bans': [{u'pickTurn': 1, u'championId': 164}, {u'pickTurn': 3, u'championId': 7}, {u'pickTurn': 5, u'championId': 90}], u'firstInhibitor': False, u'baronKills': 0, u'firstRiftHerald': False, u'winner': False, u'firstBaron': False, u'riftHeraldKills': 0, u'firstBlood': True, u'teamId': 100, u'firstTower': False, u'vilemawKills': 0, u'inhibitorKills': 0, u'towerKills': 0, u'dominionVictoryScore': 0, u'dragonKills': 0}, {u'firstDragon': True, u'bans': [{u'pickTurn': 2, u'championId': 120}, {u'pickTurn': 4, u'championId': 55}, {u'pickTurn': 6, u'championId': 19}], u'firstInhibitor': True, u'baronKills': 0, u'firstRiftHerald': False, u'winner': True, u'firstBaron': False, u'riftHeraldKills': 0, u'firstBlood': False, u'teamId': 200, u'firstTower': True, u'vilemawKills': 0, u'inhibitorKills': 1, u'towerKills': 7, u'dominionVictoryScore': 0, u'dragonKills': 2}]
#                                                                       0  \
# firstDragon                                                       False
# bans                  [{u'pickTurn': 1, u'championId': 164}, {u'pick...
# firstInhibitor                                                     True
# baronKills                                                            0
# firstRiftHerald                                                   False
# winner                                                             True
# firstBaron                                                        False
# riftheraldKills                                                       0
# firstBlood                                                        False
# teamId                                                              100
# firstTower                                                         True
# vilemawKills                                                          0
# inhibitorKills                                                        1
# towerKills                                                            8
# dominionVictoryScore                                                  0
# dragonKills                                                           3
#
#                                                                       1
# firstDragon                                                        True
# bans                  [{u'pickTurn': 2, u'championId': 7}, {u'pickTu...
# firstInhibitor                                                    False
# baronKills                                                            0
# firstRiftHerald                                                   False
# winner                                                            False
# firstBaron                                                        False
# riftheraldKills                                                       0
# firstBlood                                                         True
# teamId                                                              200
# firstTower                                                        False
# vilemawKills                                                          0
# inhibitorKills                                                        0
# towerKills                                                            1
# dominionVictoryScore                                                  0
# dragonKills                                                           1

# %%
matchID[6]
# Out:
# '2413197247'

# %%
matchRequest =Request('https://na.api.pvp.net/api/lol/na/v2.2/match/'+matchID[6]+'?api_key=RGAPI-6b4e9139-2121-4820-8cd9-371891441c4b')
responseMatch = urlopen(matchRequest)
loadMatch = responseMatch.read()
matchData6 = json.loads(loadMatch)
matchData6
#matchID[1]

print matchData6['teams'] 

#he was on team 200

#{'matchid'},
team_col_header = ['firstDragon','bans','firstInhibitor','baronKills','firstRiftHerald','winner','firstBaron','riftheraldKills',
                  'firstBlood','teamId','firstTower','vilemawKills','inhibitorKills','towerKills','dominionVictoryScore',
                  'dragonKills']

#matchid=['2413197247']
match=[]
firstDragon=[]
bans=[]
firstInhibitor=[]
baronKills=[]
firstRiftHerald=[]
winner=[]
firstBaron=[]
riftHeraldKills=[]
firstBlood=[]
teamId=[]
firstTower=[]
vilemawKills=[]
inhibitorKills=[]
towerKills=[]
dominionVictoryScore=[]
dragonKills=[]

for teams in matchData6['teams']:
    firstDragon.append(teams[u'firstDragon'])
    bans.append(teams[u'bans'])
    firstInhibitor.append(teams[u'firstInhibitor'])
    baronKills.append(teams[u'baronKills'])
    firstRiftHerald.append(teams[u'firstRiftHerald'])
    winner.append(teams[u'winner'])
    firstBaron.append(teams[u'firstBaron'])
    riftHeraldKills.append(teams[u'riftHeraldKills'])
    firstBlood.append(teams[u'firstBlood'])
    teamId.append(teams[u'teamId'])
    firstTower.append(teams[u'firstTower'])
    vilemawKills.append(teams[u'vilemawKills'])
    inhibitorKills.append(teams[u'inhibitorKills'])
    towerKills.append(teams[u'towerKills'])
    dominionVictoryScore.append(teams[u'dominionVictoryScore'])
    dragonKills.append(teams[u'dragonKills'])
    
dfMatch6 = pd.DataFrame([firstDragon,bans,firstInhibitor,baronKills,firstRiftHerald,winner,firstBaron,riftHeraldKills,
                  firstBlood,teamId,firstTower,vilemawKills,inhibitorKills,towerKills,dominionVictoryScore,
                  dragonKills]).T

dfMatch6.columns=['firstDragon','bans','firstInhibitor','baronKills','firstRiftHerald','winner','firstBaron','riftheraldKills',
                  'firstBlood','teamId','firstTower','vilemawKills','inhibitorKills','towerKills','dominionVictoryScore',
                  'dragonKills']
dfMatch6.T
# Out:
# [{u'firstDragon': False, u'bans': [{u'pickTurn': 1, u'championId': 121}, {u'pickTurn': 3, u'championId': 107}, {u'pickTurn': 5, u'championId': 90}], u'firstInhibitor': False, u'baronKills': 0, u'firstRiftHerald': False, u'winner': False, u'firstBaron': False, u'riftHeraldKills': 0, u'firstBlood': True, u'teamId': 100, u'firstTower': True, u'vilemawKills': 0, u'inhibitorKills': 0, u'towerKills': 4, u'dominionVictoryScore': 0, u'dragonKills': 1}, {u'firstDragon': True, u'bans': [{u'pickTurn': 2, u'championId': 164}, {u'pickTurn': 4, u'championId': 7}, {u'pickTurn': 6, u'championId': 13}], u'firstInhibitor': True, u'baronKills': 1, u'firstRiftHerald': False, u'winner': True, u'firstBaron': True, u'riftHeraldKills': 0, u'firstBlood': False, u'teamId': 200, u'firstTower': False, u'vilemawKills': 0, u'inhibitorKills': 3, u'towerKills': 11, u'dominionVictoryScore': 0, u'dragonKills': 2}]
#                                                                       0  \
# firstDragon                                                       False
# bans                  [{u'pickTurn': 1, u'championId': 121}, {u'pick...
# firstInhibitor                                                    False
# baronKills                                                            0
# firstRiftHerald                                                   False
# winner                                                            False
# firstBaron                                                        False
# riftheraldKills                                                       0
# firstBlood                                                         True
# teamId                                                              100
# firstTower                                                         True
# vilemawKills                                                          0
# inhibitorKills                                                        0
# towerKills                                                            4
# dominionVictoryScore                                                  0
# dragonKills                                                           1
#
#                                                                       1
# firstDragon                                                        True
# bans                  [{u'pickTurn': 2, u'championId': 164}, {u'pick...
# firstInhibitor                                                     True
# baronKills                                                            1
# firstRiftHerald                                                   False
# winner                                                             True
# firstBaron                                                         True
# riftheraldKills                                                       0
# firstBlood                                                        False
# teamId                                                              200
# firstTower                                                        False
# vilemawKills                                                          0
# inhibitorKills                                                        3
# towerKills                                                           11
# dominionVictoryScore                                                  0
# dragonKills                                                           2

# %%
matchID[7]
# Out:
# '2413211846'

# %%
matchRequest =Request('https://na.api.pvp.net/api/lol/na/v2.2/match/'+matchID[7]+'?api_key=RGAPI-6b4e9139-2121-4820-8cd9-371891441c4b')
responseMatch = urlopen(matchRequest)
loadMatch = responseMatch.read()
matchData7 = json.loads(loadMatch)
matchData7
#matchID[1]

print matchData6['teams'] 

#he was on team 200

#{'matchid'},
team_col_header = ['firstDragon','bans','firstInhibitor','baronKills','firstRiftHerald','winner','firstBaron','riftheraldKills',
                  'firstBlood','teamId','firstTower','vilemawKills','inhibitorKills','towerKills','dominionVictoryScore',
                  'dragonKills']

#matchid=['2413211846']
match=[]
firstDragon=[]
bans=[]
firstInhibitor=[]
baronKills=[]
firstRiftHerald=[]
winner=[]
firstBaron=[]
riftHeraldKills=[]
firstBlood=[]
teamId=[]
firstTower=[]
vilemawKills=[]
inhibitorKills=[]
towerKills=[]
dominionVictoryScore=[]
dragonKills=[]

for teams in matchData7['teams']:
    firstDragon.append(teams[u'firstDragon'])
    bans.append(teams[u'bans'])
    firstInhibitor.append(teams[u'firstInhibitor'])
    baronKills.append(teams[u'baronKills'])
    firstRiftHerald.append(teams[u'firstRiftHerald'])
    winner.append(teams[u'winner'])
    firstBaron.append(teams[u'firstBaron'])
    riftHeraldKills.append(teams[u'riftHeraldKills'])
    firstBlood.append(teams[u'firstBlood'])
    teamId.append(teams[u'teamId'])
    firstTower.append(teams[u'firstTower'])
    vilemawKills.append(teams[u'vilemawKills'])
    inhibitorKills.append(teams[u'inhibitorKills'])
    towerKills.append(teams[u'towerKills'])
    dominionVictoryScore.append(teams[u'dominionVictoryScore'])
    dragonKills.append(teams[u'dragonKills'])
    
dfMatch7 = pd.DataFrame([firstDragon,bans,firstInhibitor,baronKills,firstRiftHerald,winner,firstBaron,riftHeraldKills,
                  firstBlood,teamId,firstTower,vilemawKills,inhibitorKills,towerKills,dominionVictoryScore,
                  dragonKills]).T

dfMatch7.columns=['firstDragon','bans','firstInhibitor','baronKills','firstRiftHerald','winner','firstBaron','riftheraldKills',
                  'firstBlood','teamId','firstTower','vilemawKills','inhibitorKills','towerKills','dominionVictoryScore',
                  'dragonKills']
dfMatch7.T
# Out:
# [{u'firstDragon': False, u'bans': [{u'pickTurn': 1, u'championId': 121}, {u'pickTurn': 3, u'championId': 107}, {u'pickTurn': 5, u'championId': 90}], u'firstInhibitor': False, u'baronKills': 0, u'firstRiftHerald': False, u'winner': False, u'firstBaron': False, u'riftHeraldKills': 0, u'firstBlood': True, u'teamId': 100, u'firstTower': True, u'vilemawKills': 0, u'inhibitorKills': 0, u'towerKills': 4, u'dominionVictoryScore': 0, u'dragonKills': 1}, {u'firstDragon': True, u'bans': [{u'pickTurn': 2, u'championId': 164}, {u'pickTurn': 4, u'championId': 7}, {u'pickTurn': 6, u'championId': 13}], u'firstInhibitor': True, u'baronKills': 1, u'firstRiftHerald': False, u'winner': True, u'firstBaron': True, u'riftHeraldKills': 0, u'firstBlood': False, u'teamId': 200, u'firstTower': False, u'vilemawKills': 0, u'inhibitorKills': 3, u'towerKills': 11, u'dominionVictoryScore': 0, u'dragonKills': 2}]
#                                                                       0  \
# firstDragon                                                        True
# bans                  [{u'pickTurn': 1, u'championId': 107}, {u'pick...
# firstInhibitor                                                     True
# baronKills                                                            1
# firstRiftHerald                                                   False
# winner                                                             True
# firstBaron                                                         True
# riftheraldKills                                                       0
# firstBlood                                                        False
# teamId                                                              100
# firstTower                                                        False
# vilemawKills                                                          0
# inhibitorKills                                                        1
# towerKills                                                            9
# dominionVictoryScore                                                  0
# dragonKills                                                           3
#
#                                                                       1
# firstDragon                                                       False
# bans                  [{u'pickTurn': 2, u'championId': 7}, {u'pickTu...
# firstInhibitor                                                    False
# baronKills                                                            0
# firstRiftHerald                                                   False
# winner                                                            False
# firstBaron                                                        False
# riftheraldKills                                                       0
# firstBlood                                                         True
# teamId                                                              200
# firstTower                                                         True
# vilemawKills                                                          0
# inhibitorKills                                                        0
# towerKills                                                            3
# dominionVictoryScore                                                  0
# dragonKills                                                           0

# %%
matchID[8]
# Out:
# '2413213657'

# %%
matchRequest =Request('https://na.api.pvp.net/api/lol/na/v2.2/match/'+matchID[8]+'?api_key=RGAPI-6b4e9139-2121-4820-8cd9-371891441c4b')
responseMatch = urlopen(matchRequest)
loadMatch = responseMatch.read()
matchData8 = json.loads(loadMatch)
matchData8
#matchID[1]

print matchData6['teams'] 

#he was on team 100

#{'matchid'},
team_col_header = ['firstDragon','bans','firstInhibitor','baronKills','firstRiftHerald','winner','firstBaron','riftheraldKills',
                  'firstBlood','teamId','firstTower','vilemawKills','inhibitorKills','towerKills','dominionVictoryScore',
                  'dragonKills']

#matchid=['2413213657']
match=[]
firstDragon=[]
bans=[]
firstInhibitor=[]
baronKills=[]
firstRiftHerald=[]
winner=[]
firstBaron=[]
riftHeraldKills=[]
firstBlood=[]
teamId=[]
firstTower=[]
vilemawKills=[]
inhibitorKills=[]
towerKills=[]
dominionVictoryScore=[]
dragonKills=[]

for teams in matchData8['teams']:
    firstDragon.append(teams[u'firstDragon'])
    bans.append(teams[u'bans'])
    firstInhibitor.append(teams[u'firstInhibitor'])
    baronKills.append(teams[u'baronKills'])
    firstRiftHerald.append(teams[u'firstRiftHerald'])
    winner.append(teams[u'winner'])
    firstBaron.append(teams[u'firstBaron'])
    riftHeraldKills.append(teams[u'riftHeraldKills'])
    firstBlood.append(teams[u'firstBlood'])
    teamId.append(teams[u'teamId'])
    firstTower.append(teams[u'firstTower'])
    vilemawKills.append(teams[u'vilemawKills'])
    inhibitorKills.append(teams[u'inhibitorKills'])
    towerKills.append(teams[u'towerKills'])
    dominionVictoryScore.append(teams[u'dominionVictoryScore'])
    dragonKills.append(teams[u'dragonKills'])
    
dfMatch8 = pd.DataFrame([firstDragon,bans,firstInhibitor,baronKills,firstRiftHerald,winner,firstBaron,riftHeraldKills,
                  firstBlood,teamId,firstTower,vilemawKills,inhibitorKills,towerKills,dominionVictoryScore,
                  dragonKills]).T

dfMatch8.columns=['firstDragon','bans','firstInhibitor','baronKills','firstRiftHerald','winner','firstBaron','riftheraldKills',
                  'firstBlood','teamId','firstTower','vilemawKills','inhibitorKills','towerKills','dominionVictoryScore',
                  'dragonKills']
dfMatch8.T
# Out:
# [{u'firstDragon': False, u'bans': [{u'pickTurn': 1, u'championId': 121}, {u'pickTurn': 3, u'championId': 107}, {u'pickTurn': 5, u'championId': 90}], u'firstInhibitor': False, u'baronKills': 0, u'firstRiftHerald': False, u'winner': False, u'firstBaron': False, u'riftHeraldKills': 0, u'firstBlood': True, u'teamId': 100, u'firstTower': True, u'vilemawKills': 0, u'inhibitorKills': 0, u'towerKills': 4, u'dominionVictoryScore': 0, u'dragonKills': 1}, {u'firstDragon': True, u'bans': [{u'pickTurn': 2, u'championId': 164}, {u'pickTurn': 4, u'championId': 7}, {u'pickTurn': 6, u'championId': 13}], u'firstInhibitor': True, u'baronKills': 1, u'firstRiftHerald': False, u'winner': True, u'firstBaron': True, u'riftHeraldKills': 0, u'firstBlood': False, u'teamId': 200, u'firstTower': False, u'vilemawKills': 0, u'inhibitorKills': 3, u'towerKills': 11, u'dominionVictoryScore': 0, u'dragonKills': 2}]
#                                                                       0  \
# firstDragon                                                        True
# bans                  [{u'pickTurn': 1, u'championId': 126}, {u'pick...
# firstInhibitor                                                    False
# baronKills                                                            0
# firstRiftHerald                                                   False
# winner                                                            False
# firstBaron                                                        False
# riftheraldKills                                                       0
# firstBlood                                                         True
# teamId                                                              100
# firstTower                                                        False
# vilemawKills                                                          0
# inhibitorKills                                                        0
# towerKills                                                            2
# dominionVictoryScore                                                  0
# dragonKills                                                           3
#
#                                                                       1
# firstDragon                                                       False
# bans                  [{u'pickTurn': 2, u'championId': 120}, {u'pick...
# firstInhibitor                                                     True
# baronKills                                                            1
# firstRiftHerald                                                   False
# winner                                                             True
# firstBaron                                                         True
# riftheraldKills                                                       0
# firstBlood                                                        False
# teamId                                                              200
# firstTower                                                         True
# vilemawKills                                                          0
# inhibitorKills                                                        2
# towerKills                                                            8
# dominionVictoryScore                                                  0
# dragonKills                                                           0

# %%
matchID[9]
# Out:
# '2414044482'

# %%
matchRequest =Request('https://na.api.pvp.net/api/lol/na/v2.2/match/'+matchID[9]+'?api_key=RGAPI-6b4e9139-2121-4820-8cd9-371891441c4b')
responseMatch = urlopen(matchRequest)
loadMatch = responseMatch.read()
matchData9 = json.loads(loadMatch)
matchData9
#matchID[1]

print matchData6['teams'] 
#he was on team 200

#{'matchid'},
team_col_header = ['firstDragon','bans','firstInhibitor','baronKills','firstRiftHerald','winner','firstBaron','riftheraldKills',
                  'firstBlood','teamId','firstTower','vilemawKills','inhibitorKills','towerKills','dominionVictoryScore',
                  'dragonKills']

#matchid=['2414044482']
match=[]
firstDragon=[]
bans=[]
firstInhibitor=[]
baronKills=[]
firstRiftHerald=[]
winner=[]
firstBaron=[]
riftHeraldKills=[]
firstBlood=[]
teamId=[]
firstTower=[]
vilemawKills=[]
inhibitorKills=[]
towerKills=[]
dominionVictoryScore=[]
dragonKills=[]

for teams in matchData9['teams']:
    firstDragon.append(teams[u'firstDragon'])
    bans.append(teams[u'bans'])
    firstInhibitor.append(teams[u'firstInhibitor'])
    baronKills.append(teams[u'baronKills'])
    firstRiftHerald.append(teams[u'firstRiftHerald'])
    winner.append(teams[u'winner'])
    firstBaron.append(teams[u'firstBaron'])
    riftHeraldKills.append(teams[u'riftHeraldKills'])
    firstBlood.append(teams[u'firstBlood'])
    teamId.append(teams[u'teamId'])
    firstTower.append(teams[u'firstTower'])
    vilemawKills.append(teams[u'vilemawKills'])
    inhibitorKills.append(teams[u'inhibitorKills'])
    towerKills.append(teams[u'towerKills'])
    dominionVictoryScore.append(teams[u'dominionVictoryScore'])
    dragonKills.append(teams[u'dragonKills'])
    
dfMatch9 = pd.DataFrame([firstDragon,bans,firstInhibitor,baronKills,firstRiftHerald,winner,firstBaron,riftHeraldKills,
                  firstBlood,teamId,firstTower,vilemawKills,inhibitorKills,towerKills,dominionVictoryScore,
                  dragonKills]).T

dfMatch9.columns=['firstDragon','bans','firstInhibitor','baronKills','firstRiftHerald','winner','firstBaron','riftheraldKills',
                  'firstBlood','teamId','firstTower','vilemawKills','inhibitorKills','towerKills','dominionVictoryScore',
                  'dragonKills']
dfMatch9.T
# Out:
# [{u'firstDragon': False, u'bans': [{u'pickTurn': 1, u'championId': 121}, {u'pickTurn': 3, u'championId': 107}, {u'pickTurn': 5, u'championId': 90}], u'firstInhibitor': False, u'baronKills': 0, u'firstRiftHerald': False, u'winner': False, u'firstBaron': False, u'riftHeraldKills': 0, u'firstBlood': True, u'teamId': 100, u'firstTower': True, u'vilemawKills': 0, u'inhibitorKills': 0, u'towerKills': 4, u'dominionVictoryScore': 0, u'dragonKills': 1}, {u'firstDragon': True, u'bans': [{u'pickTurn': 2, u'championId': 164}, {u'pickTurn': 4, u'championId': 7}, {u'pickTurn': 6, u'championId': 13}], u'firstInhibitor': True, u'baronKills': 1, u'firstRiftHerald': False, u'winner': True, u'firstBaron': True, u'riftHeraldKills': 0, u'firstBlood': False, u'teamId': 200, u'firstTower': False, u'vilemawKills': 0, u'inhibitorKills': 3, u'towerKills': 11, u'dominionVictoryScore': 0, u'dragonKills': 2}]
#                                                                       0  \
# firstDragon                                                       False
# bans                  [{u'pickTurn': 1, u'championId': 121}, {u'pick...
# firstInhibitor                                                    False
# baronKills                                                            0
# firstRiftHerald                                                   False
# winner                                                            False
# firstBaron                                                        False
# riftheraldKills                                                       0
# firstBlood                                                        False
# teamId                                                              100
# firstTower                                                         True
# vilemawKills                                                          0
# inhibitorKills                                                        0
# towerKills                                                            2
# dominionVictoryScore                                                  0
# dragonKills                                                           0
#
#                                                                       1
# firstDragon                                                        True
# bans                  [{u'pickTurn': 2, u'championId': 7}, {u'pickTu...
# firstInhibitor                                                    False
# baronKills                                                            0
# firstRiftHerald                                                   False
# winner                                                             True
# firstBaron                                                        False
# riftheraldKills                                                       0
# firstBlood                                                         True
# teamId                                                              200
# firstTower                                                        False
# vilemawKills                                                          0
# inhibitorKills                                                        0
# towerKills                                                            5
# dominionVictoryScore                                                  0
# dragonKills                                                           2

# %%
matchID[10]
# Out:
# '2414052519'

# %%
matchRequest =Request('https://na.api.pvp.net/api/lol/na/v2.2/match/'+matchID[10]+'?api_key=RGAPI-6b4e9139-2121-4820-8cd9-371891441c4b')
responseMatch = urlopen(matchRequest)
loadMatch = responseMatch.read()
matchData10 = json.loads(loadMatch)
matchData10
#matchID[1]

print matchData6['teams'] 
#he was on team 100

#{'matchid'},
team_col_header = ['firstDragon','bans','firstInhibitor','baronKills','firstRiftHerald','winner','firstBaron','riftheraldKills',
                  'firstBlood','teamId','firstTower','vilemawKills','inhibitorKills','towerKills','dominionVictoryScore',
                  'dragonKills']

#matchid=['2414052519']
match=[]
firstDragon=[]
bans=[]
firstInhibitor=[]
baronKills=[]
firstRiftHerald=[]
winner=[]
firstBaron=[]
riftHeraldKills=[]
firstBlood=[]
teamId=[]
firstTower=[]
vilemawKills=[]
inhibitorKills=[]
towerKills=[]
dominionVictoryScore=[]
dragonKills=[]

for teams in matchData10['teams']:
    firstDragon.append(teams[u'firstDragon'])
    bans.append(teams[u'bans'])
    firstInhibitor.append(teams[u'firstInhibitor'])
    baronKills.append(teams[u'baronKills'])
    firstRiftHerald.append(teams[u'firstRiftHerald'])
    winner.append(teams[u'winner'])
    firstBaron.append(teams[u'firstBaron'])
    riftHeraldKills.append(teams[u'riftHeraldKills'])
    firstBlood.append(teams[u'firstBlood'])
    teamId.append(teams[u'teamId'])
    firstTower.append(teams[u'firstTower'])
    vilemawKills.append(teams[u'vilemawKills'])
    inhibitorKills.append(teams[u'inhibitorKills'])
    towerKills.append(teams[u'towerKills'])
    dominionVictoryScore.append(teams[u'dominionVictoryScore'])
    dragonKills.append(teams[u'dragonKills'])
    
dfMatch10 = pd.DataFrame([firstDragon,bans,firstInhibitor,baronKills,firstRiftHerald,winner,firstBaron,riftHeraldKills,
                  firstBlood,teamId,firstTower,vilemawKills,inhibitorKills,towerKills,dominionVictoryScore,
                  dragonKills]).T

dfMatch10.columns=['firstDragon','bans','firstInhibitor','baronKills','firstRiftHerald','winner','firstBaron','riftheraldKills',
                  'firstBlood','teamId','firstTower','vilemawKills','inhibitorKills','towerKills','dominionVictoryScore',
                  'dragonKills']
dfMatch10.T
# Out:
# [{u'firstDragon': False, u'bans': [{u'pickTurn': 1, u'championId': 121}, {u'pickTurn': 3, u'championId': 107}, {u'pickTurn': 5, u'championId': 90}], u'firstInhibitor': False, u'baronKills': 0, u'firstRiftHerald': False, u'winner': False, u'firstBaron': False, u'riftHeraldKills': 0, u'firstBlood': True, u'teamId': 100, u'firstTower': True, u'vilemawKills': 0, u'inhibitorKills': 0, u'towerKills': 4, u'dominionVictoryScore': 0, u'dragonKills': 1}, {u'firstDragon': True, u'bans': [{u'pickTurn': 2, u'championId': 164}, {u'pickTurn': 4, u'championId': 7}, {u'pickTurn': 6, u'championId': 13}], u'firstInhibitor': True, u'baronKills': 1, u'firstRiftHerald': False, u'winner': True, u'firstBaron': True, u'riftHeraldKills': 0, u'firstBlood': False, u'teamId': 200, u'firstTower': False, u'vilemawKills': 0, u'inhibitorKills': 3, u'towerKills': 11, u'dominionVictoryScore': 0, u'dragonKills': 2}]
#                                                                       0  \
# firstDragon                                                       False
# bans                  [{u'pickTurn': 1, u'championId': 121}, {u'pick...
# firstInhibitor                                                    False
# baronKills                                                            0
# firstRiftHerald                                                   False
# winner                                                            False
# firstBaron                                                        False
# riftheraldKills                                                       0
# firstBlood                                                        False
# teamId                                                              100
# firstTower                                                        False
# vilemawKills                                                          0
# inhibitorKills                                                        0
# towerKills                                                            3
# dominionVictoryScore                                                  0
# dragonKills                                                           0
#
#                                                                       1
# firstDragon                                                        True
# bans                  [{u'pickTurn': 2, u'championId': 164}, {u'pick...
# firstInhibitor                                                     True
# baronKills                                                            1
# firstRiftHerald                                                    True
# winner                                                             True
# firstBaron                                                         True
# riftheraldKills                                                       1
# firstBlood                                                         True
# teamId                                                              200
# firstTower                                                         True
# vilemawKills                                                          0
# inhibitorKills                                                        1
# towerKills                                                            9
# dominionVictoryScore                                                  0
# dragonKills                                                           3
