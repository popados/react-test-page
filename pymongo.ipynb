# %%
import pymongo
import csv
import json

# Connection to Mongo DB
try:
    conn=pymongo.MongoClient()
    print "Connected successfully!!!"
except pymongo.errors.ConnectionFailure, e:
   print "Could not connect to MongoDB: %s" % e
conn
# Out:
# Connected successfully!!!
# MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True)

# %%
db = conn.leagueDB
print db
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), u'leagueDB')

# %%
db = conn['sandpit-test']
db
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), u'sandpit-test')

# %%
conn.database_names()
# Out:
# [u'admin', u'local']

# %%
collection = db.my_collection
collection
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), u'sandpit-test'), u'my_collection')

# %%
db.collection_names()
# Out:
# []

# %%
# Out:
# {u'data': {u'Aatrox': {u'id': 266,
#    u'key': u'Aatrox',
#    u'name': u'Aatrox',
#    u'title': u'the Darkin Blade'},
#   u'Ahri': {u'id': 103,
#    u'key': u'Ahri',
#    u'name': u'Ahri',
#    u'title': u'the Nine-Tailed Fox'},
#   u'Akali': {u'id': 84,
#    u'key': u'Akali',
#    u'name': u'Akali',
#    u'title': u'the Fist of Shadow'},
#   u'Alistar': {u'id': 12,
#    u'key': u'Alistar',
#    u'name': u'Alistar',
#    u'title': u'the Minotaur'},
#   u'Amumu': {u'id': 32,
#    u'key': u'Amumu',
#    u'name': u'Amumu',
#    u'title': u'the Sad Mummy'},
#   u'Anivia': {u'id': 34,
#    u'key': u'Anivia',
#    u'name': u'Anivia',
#    u'title': u'the Cryophoenix'},
#   u'Annie': {u'id': 1,
#    u'key': u'Annie',
#    u'name': u'Annie',
#    u'title': u'the Dark Child'},
#   u'Ashe': {u'id': 22,
#    u'key': u'Ashe',
#    u'name': u'Ashe',
#    u'title': u'the Frost Archer'},
#   u'AurelionSol': {u'id': 136,
#    u'key': u'AurelionSol',
#    u'name': u'Aurelion Sol',
#    u'title': u'The Star Forger'},
#   u'Azir': {u'id': 268,
#    u'key': u'Azir',
#    u'name': u'Azir',
#    u'title': u'the Emperor of the Sands'},
#   u'Bard': {u'id': 432,
#    u'key': u'Bard',
#    u'name': u'Bard',
#    u'title': u'the Wandering Caretaker'},
#   u'Blitzcrank': {u'id': 53,
#    u'key': u'Blitzcrank',
#    u'name': u'Blitzcrank',
#    u'title': u'the Great Steam Golem'},
#   u'Brand': {u'id': 63,
#    u'key': u'Brand',
#    u'name': u'Brand',
#    u'title': u'the Burning Vengeance'},
#   u'Braum': {u'id': 201,
#    u'key': u'Braum',
#    u'name': u'Braum',
#    u'title': u'the Heart of the Freljord'},
#   u'Caitlyn': {u'id': 51,
#    u'key': u'Caitlyn',
#    u'name': u'Caitlyn',
#    u'title': u'the Sheriff of Piltover'},
#   u'Camille': {u'id': 164,
#    u'key': u'Camille',
#    u'name': u'Camille',
#    u'title': u'the Steel Shadow'},
#   u'Cassiopeia': {u'id': 69,
#    u'key': u'Cassiopeia',
#    u'name': u'Cassiopeia',
#    u'title': u"the Serpent's Embrace"},
#   u'Chogath': {u'id': 31,
#    u'key': u'Chogath',
#    u'name': u"Cho'Gath",
#    u'title': u'the Terror of the Void'},
#   u'Corki': {u'id': 42,
#    u'key': u'Corki',
#    u'name': u'Corki',
#    u'title': u'the Daring Bombardier'},
#   u'Darius': {u'id': 122,
#    u'key': u'Darius',
#    u'name': u'Darius',
#    u'title': u'the Hand of Noxus'},
#   u'Diana': {u'id': 131,
#    u'key': u'Diana',
#    u'name': u'Diana',
#    u'title': u'Scorn of the Moon'},
#   u'DrMundo': {u'id': 36,
#    u'key': u'DrMundo',
#    u'name': u'Dr. Mundo',
#    u'title': u'the Madman of Zaun'},
#   u'Draven': {u'id': 119,
#    u'key': u'Draven',
#    u'name': u'Draven',
#    u'title': u'the Glorious Executioner'},
#   u'Ekko': {u'id': 245,
#    u'key': u'Ekko',
#    u'name': u'Ekko',
#    u'title': u'the Boy Who Shattered Time'},
#   u'Elise': {u'id': 60,
#    u'key': u'Elise',
#    u'name': u'Elise',
#    u'title': u'the Spider Queen'},
#   u'Evelynn': {u'id': 28,
#    u'key': u'Evelynn',
#    u'name': u'Evelynn',
#    u'title': u'the Widowmaker'},
#   u'Ezreal': {u'id': 81,
#    u'key': u'Ezreal',
#    u'name': u'Ezreal',
#    u'title': u'the Prodigal Explorer'},
#   u'FiddleSticks': {u'id': 9,
#    u'key': u'FiddleSticks',
#    u'name': u'Fiddlesticks',
#    u'title': u'the Harbinger of Doom'},
#   u'Fiora': {u'id': 114,
#    u'key': u'Fiora',
#    u'name': u'Fiora',
#    u'title': u'the Grand Duelist'},
#   u'Fizz': {u'id': 105,
#    u'key': u'Fizz',
#    u'name': u'Fizz',
#    u'title': u'the Tidal Trickster'},
#   u'Galio': {u'id': 3,
#    u'key': u'Galio',
#    u'name': u'Galio',
#    u'title': u"the Sentinel's Sorrow"},
#   u'Gangplank': {u'id': 41,
#    u'key': u'Gangplank',
#    u'name': u'Gangplank',
#    u'title': u'the Saltwater Scourge'},
#   u'Garen': {u'id': 86,
#    u'key': u'Garen',
#    u'name': u'Garen',
#    u'title': u'The Might of Demacia'},
#   u'Gnar': {u'id': 150,
#    u'key': u'Gnar',
#    u'name': u'Gnar',
#    u'title': u'the Missing Link'},
#   u'Gragas': {u'id': 79,
#    u'key': u'Gragas',
#    u'name': u'Gragas',
#    u'title': u'the Rabble Rouser'},
#   u'Graves': {u'id': 104,
#    u'key': u'Graves',
#    u'name': u'Graves',
#    u'title': u'the Outlaw'},
#   u'Hecarim': {u'id': 120,
#    u'key': u'Hecarim',
#    u'name': u'Hecarim',
#    u'title': u'the Shadow of War'},
#   u'Heimerdinger': {u'id': 74,
#    u'key': u'Heimerdinger',
#    u'name': u'Heimerdinger',
#    u'title': u'the Revered Inventor'},
#   u'Illaoi': {u'id': 420,
#    u'key': u'Illaoi',
#    u'name': u'Illaoi',
#    u'title': u'the Kraken Priestess'},
#   u'Irelia': {u'id': 39,
#    u'key': u'Irelia',
#    u'name': u'Irelia',
#    u'title': u'the Will of the Blades'},
#   u'Ivern': {u'id': 427,
#    u'key': u'Ivern',
#    u'name': u'Ivern',
#    u'title': u'the Green Father'},
#   u'Janna': {u'id': 40,
#    u'key': u'Janna',
#    u'name': u'Janna',
#    u'title': u"the Storm's Fury"},
#   u'JarvanIV': {u'id': 59,
#    u'key': u'JarvanIV',
#    u'name': u'Jarvan IV',
#    u'title': u'the Exemplar of Demacia'},
#   u'Jax': {u'id': 24,
#    u'key': u'Jax',
#    u'name': u'Jax',
#    u'title': u'Grandmaster at Arms'},
#   u'Jayce': {u'id': 126,
#    u'key': u'Jayce',
#    u'name': u'Jayce',
#    u'title': u'the Defender of Tomorrow'},
#   u'Jhin': {u'id': 202,
#    u'key': u'Jhin',
#    u'name': u'Jhin',
#    u'title': u'the Virtuoso'},
#   u'Jinx': {u'id': 222,
#    u'key': u'Jinx',
#    u'name': u'Jinx',
#    u'title': u'the Loose Cannon'},
#   u'Kalista': {u'id': 429,
#    u'key': u'Kalista',
#    u'name': u'Kalista',
#    u'title': u'the Spear of Vengeance'},
#   u'Karma': {u'id': 43,
#    u'key': u'Karma',
#    u'name': u'Karma',
#    u'title': u'the Enlightened One'},
#   u'Karthus': {u'id': 30,
#    u'key': u'Karthus',
#    u'name': u'Karthus',
#    u'title': u'the Deathsinger'},
#   u'Kassadin': {u'id': 38,
#    u'key': u'Kassadin',
#    u'name': u'Kassadin',
#    u'title': u'the Void Walker'},
#   u'Katarina': {u'id': 55,
#    u'key': u'Katarina',
#    u'name': u'Katarina',
#    u'title': u'the Sinister Blade'},
#   u'Kayle': {u'id': 10,
#    u'key': u'Kayle',
#    u'name': u'Kayle',
#    u'title': u'The Judicator'},
#   u'Kennen': {u'id': 85,
#    u'key': u'Kennen',
#    u'name': u'Kennen',
#    u'title': u'the Heart of the Tempest'},
#   u'Khazix': {u'id': 121,
#    u'key': u'Khazix',
#    u'name': u"Kha'Zix",
#    u'title': u'the Voidreaver'},
#   u'Kindred': {u'id': 203,
#    u'key': u'Kindred',
#    u'name': u'Kindred',
#    u'title': u'The Eternal Hunters'},
#   u'Kled': {u'id': 240,
#    u'key': u'Kled',
#    u'name': u'Kled',
#    u'title': u'the Cantankerous Cavalier'},
#   u'KogMaw': {u'id': 96,
#    u'key': u'KogMaw',
#    u'name': u"Kog'Maw",
#    u'title': u'the Mouth of the Abyss'},
#   u'Leblanc': {u'id': 7,
#    u'key': u'Leblanc',
#    u'name': u'LeBlanc',
#    u'title': u'the Deceiver'},
#   u'LeeSin': {u'id': 64,
#    u'key': u'LeeSin',
#    u'name': u'Lee Sin',
#    u'title': u'the Blind Monk'},
#   u'Leona': {u'id': 89,
#    u'key': u'Leona',
#    u'name': u'Leona',
#    u'title': u'the Radiant Dawn'},
#   u'Lissandra': {u'id': 127,
#    u'key': u'Lissandra',
#    u'name': u'Lissandra',
#    u'title': u'the Ice Witch'},
#   u'Lucian': {u'id': 236,
#    u'key': u'Lucian',
#    u'name': u'Lucian',
#    u'title': u'the Purifier'},
#   u'Lulu': {u'id': 117,
#    u'key': u'Lulu',
#    u'name': u'Lulu',
#    u'title': u'the Fae Sorceress'},
#   u'Lux': {u'id': 99,
#    u'key': u'Lux',
#    u'name': u'Lux',
#    u'title': u'the Lady of Luminosity'},
#   u'Malphite': {u'id': 54,
#    u'key': u'Malphite',
#    u'name': u'Malphite',
#    u'title': u'Shard of the Monolith'},
#   u'Malzahar': {u'id': 90,
#    u'key': u'Malzahar',
#    u'name': u'Malzahar',
#    u'title': u'the Prophet of the Void'},
#   u'Maokai': {u'id': 57,
#    u'key': u'Maokai',
#    u'name': u'Maokai',
#    u'title': u'the Twisted Treant'},
#   u'MasterYi': {u'id': 11,
#    u'key': u'MasterYi',
#    u'name': u'Master Yi',
#    u'title': u'the Wuju Bladesman'},
#   u'MissFortune': {u'id': 21,
#    u'key': u'MissFortune',
#    u'name': u'Miss Fortune',
#    u'title': u'the Bounty Hunter'},
#   u'MonkeyKing': {u'id': 62,
#    u'key': u'MonkeyKing',
#    u'name': u'Wukong',
#    u'title': u'the Monkey King'},
#   u'Mordekaiser': {u'id': 82,
#    u'key': u'Mordekaiser',
#    u'name': u'Mordekaiser',
#    u'title': u'the Iron Revenant'},
#   u'Morgana': {u'id': 25,
#    u'key': u'Morgana',
#    u'name': u'Morgana',
#    u'title': u'Fallen Angel'},
#   u'Nami': {u'id': 267,
#    u'key': u'Nami',
#    u'name': u'Nami',
#    u'title': u'the Tidecaller'},
#   u'Nasus': {u'id': 75,
#    u'key': u'Nasus',
#    u'name': u'Nasus',
#    u'title': u'the Curator of the Sands'},
#   u'Nautilus': {u'id': 111,
#    u'key': u'Nautilus',
#    u'name': u'Nautilus',
#    u'title': u'the Titan of the Depths'},
#   u'Nidalee': {u'id': 76,
#    u'key': u'Nidalee',
#    u'name': u'Nidalee',
#    u'title': u'the Bestial Huntress'},
#   u'Nocturne': {u'id': 56,
#    u'key': u'Nocturne',
#    u'name': u'Nocturne',
#    u'title': u'the Eternal Nightmare'},
#   u'Nunu': {u'id': 20,
#    u'key': u'Nunu',
#    u'name': u'Nunu',
#    u'title': u'the Yeti Rider'},
#   u'Olaf': {u'id': 2,
#    u'key': u'Olaf',
#    u'name': u'Olaf',
#    u'title': u'the Berserker'},
#   u'Orianna': {u'id': 61,
#    u'key': u'Orianna',
#    u'name': u'Orianna',
#    u'title': u'the Lady of Clockwork'},
#   u'Pantheon': {u'id': 80,
#    u'key': u'Pantheon',
#    u'name': u'Pantheon',
#    u'title': u'the Artisan of War'},
#   u'Poppy': {u'id': 78,
#    u'key': u'Poppy',
#    u'name': u'Poppy',
#    u'title': u'Keeper of the Hammer'},
#   u'Quinn': {u'id': 133,
#    u'key': u'Quinn',
#    u'name': u'Quinn',
#    u'title': u"Demacia's Wings"},
#   u'Rammus': {u'id': 33,
#    u'key': u'Rammus',
#    u'name': u'Rammus',
#    u'title': u'the Armordillo'},
#   u'RekSai': {u'id': 421,
#    u'key': u'RekSai',
#    u'name': u"Rek'Sai",
#    u'title': u'the Void Burrower'},
#   u'Renekton': {u'id': 58,
#    u'key': u'Renekton',
#    u'name': u'Renekton',
#    u'title': u'the Butcher of the Sands'},
#   u'Rengar': {u'id': 107,
#    u'key': u'Rengar',
#    u'name': u'Rengar',
#    u'title': u'the Pridestalker'},
#   u'Riven': {u'id': 92,
#    u'key': u'Riven',
#    u'name': u'Riven',
#    u'title': u'the Exile'},
#   u'Rumble': {u'id': 68,
#    u'key': u'Rumble',
#    u'name': u'Rumble',
#    u'title': u'the Mechanized Menace'},
#   u'Ryze': {u'id': 13,
#    u'key': u'Ryze',
#    u'name': u'Ryze',
#    u'title': u'the Rune Mage'},
#   u'Sejuani': {u'id': 113,
#    u'key': u'Sejuani',
#    u'name': u'Sejuani',
#    u'title': u"the Winter's Wrath"},
#   u'Shaco': {u'id': 35,
#    u'key': u'Shaco',
#    u'name': u'Shaco',
#    u'title': u'the Demon Jester'},
#   u'Shen': {u'id': 98,
#    u'key': u'Shen',
#    u'name': u'Shen',
#    u'title': u'the Eye of Twilight'},
#   u'Shyvana': {u'id': 102,
#    u'key': u'Shyvana',
#    u'name': u'Shyvana',
#    u'title': u'the Half-Dragon'},
#   u'Singed': {u'id': 27,
#    u'key': u'Singed',
#    u'name': u'Singed',
#    u'title': u'the Mad Chemist'},
#   u'Sion': {u'id': 14,
#    u'key': u'Sion',
#    u'name': u'Sion',
#    u'title': u'The Undead Juggernaut'},
#   u'Sivir': {u'id': 15,
#    u'key': u'Sivir',
#    u'name': u'Sivir',
#    u'title': u'the Battle Mistress'},
#   u'Skarner': {u'id': 72,
#    u'key': u'Skarner',
#    u'name': u'Skarner',
#    u'title': u'the Crystal Vanguard'},
#   u'Sona': {u'id': 37,
#    u'key': u'Sona',
#    u'name': u'Sona',
#    u'title': u'Maven of the Strings'},
#   u'Soraka': {u'id': 16,
#    u'key': u'Soraka',
#    u'name': u'Soraka',
#    u'title': u'the Starchild'},
#   u'Swain': {u'id': 50,
#    u'key': u'Swain',
#    u'name': u'Swain',
#    u'title': u'the Master Tactician'},
#   u'Syndra': {u'id': 134,
#    u'key': u'Syndra',
#    u'name': u'Syndra',
#    u'title': u'the Dark Sovereign'},
#   u'TahmKench': {u'id': 223,
#    u'key': u'TahmKench',
#    u'name': u'Tahm Kench',
#    u'title': u'the River King'},
#   u'Taliyah': {u'id': 163,
#    u'key': u'Taliyah',
#    u'name': u'Taliyah',
#    u'title': u'the Stoneweaver'},
#   u'Talon': {u'id': 91,
#    u'key': u'Talon',
#    u'name': u'Talon',
#    u'title': u"the Blade's Shadow"},
#   u'Taric': {u'id': 44,
#    u'key': u'Taric',
#    u'name': u'Taric',
#    u'title': u'the Shield of Valoran'},
#   u'Teemo': {u'id': 17,
#    u'key': u'Teemo',
#    u'name': u'Teemo',
#    u'title': u'the Swift Scout'},
#   u'Thresh': {u'id': 412,
#    u'key': u'Thresh',
#    u'name': u'Thresh',
#    u'title': u'the Chain Warden'},
#   u'Tristana': {u'id': 18,
#    u'key': u'Tristana',
#    u'name': u'Tristana',
#    u'title': u'the Yordle Gunner'},
#   u'Trundle': {u'id': 48,
#    u'key': u'Trundle',
#    u'name': u'Trundle',
#    u'title': u'the Troll King'},
#   u'Tryndamere': {u'id': 23,
#    u'key': u'Tryndamere',
#    u'name': u'Tryndamere',
#    u'title': u'the Barbarian King'},
#   u'TwistedFate': {u'id': 4,
#    u'key': u'TwistedFate',
#    u'name': u'Twisted Fate',
#    u'title': u'the Card Master'},
#   u'Twitch': {u'id': 29,
#    u'key': u'Twitch',
#    u'name': u'Twitch',
#    u'title': u'the Plague Rat'},
#   u'Udyr': {u'id': 77,
#    u'key': u'Udyr',
#    u'name': u'Udyr',
#    u'title': u'the Spirit Walker'},
#   u'Urgot': {u'id': 6,
#    u'key': u'Urgot',
#    u'name': u'Urgot',
#    u'title': u"the Headsman's Pride"},
#   u'Varus': {u'id': 110,
#    u'key': u'Varus',
#    u'name': u'Varus',
#    u'title': u'the Arrow of Retribution'},
#   u'Vayne': {u'id': 67,
#    u'key': u'Vayne',
#    u'name': u'Vayne',
#    u'title': u'the Night Hunter'},
#   u'Veigar': {u'id': 45,
#    u'key': u'Veigar',
#    u'name': u'Veigar',
#    u'title': u'the Tiny Master of Evil'},
#   u'Velkoz': {u'id': 161,
#    u'key': u'Velkoz',
#    u'name': u"Vel'Koz",
#    u'title': u'the Eye of the Void'},
#   u'Vi': {u'id': 254,
#    u'key': u'Vi',
#    u'name': u'Vi',
#    u'title': u'the Piltover Enforcer'},
#   u'Viktor': {u'id': 112,
#    u'key': u'Viktor',
#    u'name': u'Viktor',
#    u'title': u'the Machine Herald'},
#   u'Vladimir': {u'id': 8,
#    u'key': u'Vladimir',
#    u'name': u'Vladimir',
#    u'title': u'the Crimson Reaper'},
#   u'Volibear': {u'id': 106,
#    u'key': u'Volibear',
#    u'name': u'Volibear',
#    u'title': u"the Thunder's Roar"},
#   u'Warwick': {u'id': 19,
#    u'key': u'Warwick',
#    u'name': u'Warwick',
#    u'title': u'the Blood Hunter'},
#   u'Xerath': {u'id': 101,
#    u'key': u'Xerath',
#    u'name': u'Xerath',
#    u'title': u'the Magus Ascendant'},
#   u'XinZhao': {u'id': 5,
#    u'key': u'XinZhao',
#    u'name': u'Xin Zhao',
#    u'title': u'the Seneschal of Demacia'},
#   u'Yasuo': {u'id': 157,
#    u'key': u'Yasuo',
#    u'name': u'Yasuo',
#    u'title': u'the Unforgiven'},
#   u'Yorick': {u'id': 83,
#    u'key': u'Yorick',
#    u'name': u'Yorick',
#    u'title': u'Shepherd of Souls'},
#   u'Zac': {u'id': 154,
#    u'key': u'Zac',
#    u'name': u'Zac',
#    u'title': u'the Secret Weapon'},
#   u'Zed': {u'id': 238,
#    u'key': u'Zed',
#    u'name': u'Zed',
#    u'title': u'the Master of Shadows'},
#   u'Ziggs': {u'id': 115,
#    u'key': u'Ziggs',
#    u'name': u'Ziggs',
#    u'title': u'the Hexplosives Expert'},
#   u'Zilean': {u'id': 26,
#    u'key': u'Zilean',
#    u'name': u'Zilean',
#    u'title': u'the Chronokeeper'},
#   u'Zyra': {u'id': 143,
#    u'key': u'Zyra',
#    u'name': u'Zyra',
#    u'title': u'Rise of the Thorns'}},
#  u'type': u'champion',
#  u'version': u'7.1.1'}

# %%
collection.insert_many(champData)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-2591b165bc62> in <module>()
# ----> 1 collection.insert_many(champData)
#
# C:\Users\NIk Khandwala\Anaconda2\lib\site-packages\pymongo\collection.pyc in insert_many(self, documents, ordered, bypass_document_validation)
#     708
#     709         blk = _Bulk(self, ordered, bypass_document_validation)
# --> 710         blk.ops = [doc for doc in gen()]
#     711         blk.execute(self.write_concern.document)
#     712         return InsertManyResult(inserted_ids, self.write_concern.acknowledged)
#
# C:\Users\NIk Khandwala\Anaconda2\lib\site-packages\pymongo\collection.pyc in gen()
#     700             """A generator that validates documents and handles _ids."""
#     701             for document in documents:
# --> 702                 common.validate_is_document_type("document", document)
#     703                 if not isinstance(document, RawBSONDocument):
#     704                     if "_id" not in document:
#
# C:\Users\NIk Khandwala\Anaconda2\lib\site-packages\pymongo\common.pyc in validate_is_document_type(option, value)
#     405                         "bson.raw_bson.RawBSONDocument, or "
#     406                         "a type that inherits from "
# --> 407                         "collections.MutableMapping" % (option,))
#     408
#     409
#
# TypeError: document must be an instance of dict, bson.son.SON, bson.raw_bson.RawBSONDocument, or a type that inherits from collections.MutableMapping

# %%
conn.database_names()
# Out:
# [u'admin', u'local', u'sandpit-test']

# %%
db.collection_names()
# Out:
# [u'my_collection']
