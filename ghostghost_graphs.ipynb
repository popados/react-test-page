# %%
import json
import csv
import pandas as pd
import numpy as np
import urllib2

# %%
# %matplotlib inline

# %%
# %magic

# %%
ghostghost=pd.read_csv('ghostghost.csv' )
ghostghost.dtypes
del ghostghost['Unnamed: 0']
ghostghost.keys()
ghostghost
# Out:
#        matchID firstDragon                                               bans  \
# 0   2407787433        True  [{u'pickTurn': 2, u'championId': 164}, {u'pick...
# 1   2410767351        True  [{u'pickTurn': 2, u'championId': 164}, {u'pick...
# 2   2410749501       False  [{u'pickTurn': 2, u'championId': 164}, {u'pick...
# 3   2410774976       False  [{u'pickTurn': 1, u'championId': 55}, {u'pickT...
# 4   2410881353        True  [{u'pickTurn': 1, u'championId': 121}, {u'pick...
# 5   2410883736       False  [{u'pickTurn': 1, u'championId': 164}, {u'pick...
# 6   2413197247        True  [{u'pickTurn': 2, u'championId': 164}, {u'pick...
# 7   2413211846       False  [{u'pickTurn': 2, u'championId': 7}, {u'pickTu...
# 8   2413213657        True  [{u'pickTurn': 1, u'championId': 126}, {u'pick...
# 9   2414044482        True  [{u'pickTurn': 2, u'championId': 7}, {u'pickTu...
# 10  2414052519       False  [{u'pickTurn': 1, u'championId': 121}, {u'pick...
#
# ...

# %%
ghostghost.plot(kind='hist', x='teamId', y='winner')
