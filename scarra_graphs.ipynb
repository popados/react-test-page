# %%
import json
import csv
import pandas as pd
import numpy as np
import urllib2

# %%
# %matplotlib inline

# %%
# %magic

# %%
scarra=pd.read_csv('scarra.csv' ) #numeric for modeling and use mapping technique
scarra.dtypes
del scarra['Unnamed: 0']
scarra.keys()
scarra
# Out:
#       matchID firstDragon                                               bans  \
# 0  2408679535       False  [{u'pickTurn': 2, u'championId': 64}, {u'pickT...
# 1  2409069673       False  [{u'pickTurn': 1, u'championId': 164}, {u'pick...
# 2  2409098015        True  [{u'pickTurn': 2, u'championId': 13}, {u'pickT...
# 3  2409104031        True  [{u'pickTurn': 2, u'championId': 120}, {u'pick...
# 4  2409473580        True  [{u'pickTurn': 1, u'championId': 107}, {u'pick...
# 5  2409546141       False  [{u'pickTurn': 2, u'championId': 120}, {u'pick...
# 6  2409549765        True  [{u'pickTurn': 1, u'championId': 107}, {u'pick...
# 7  2409609168        True  [{u'pickTurn': 2, u'championId': 164}, {u'pick...
# 8  2409674662       False  [{u'pickTurn': 1, u'championId': 107}, {u'pick...
# 9  2413317998        True  [{u'pickTurn': 1, u'championId': 7}, {u'pickTu...
#
#   firstInhibitor  baronKills firstRiftHerald winner firstBaron  \
# ...

# %%
scarra.dtypes
# Out:
# matchID                  int64
# firstDragon               bool
# bans                    object
# firstInhibitor            bool
# baronKills               int64
# firstRiftHerald           bool
# winner                    bool
# firstBaron                bool
# riftheraldKills          int64
# firstBlood                bool
# teamId                   int64
# firstTower                bool
# vilemawKills             int64
# inhibitorKills           int64
# towerKills               int64
# dominionVictoryScore     int64
# dragonKills              int64
# dtype: object

# %%
scarra.firstDragon.map(encodefalse=)
