# %%
import json
import csv
import urllib2
import pandas as pd
from urllib2 import Request, urlopen
import numpy as np

# %% [raw]
# matchList1 = pd.read_csv('matchList.csv')#ghostghost PlayerID:621
# matchList1

# %%
matchID=[]

for n in list(np.unique(matchList1.matchID.values)):
    matchID.append(str(n))
    print str(n)
# Out:
# 2407787433
# 2410749501
# 2410767351
# 2410774976
# 2410881353
# 2410883736
# 2413197247
# 2413211846
# 2413213657
# 2414044482
# 2414052519

# %%
matchRequest =Request('https://na.api.pvp.net/api/lol/na/v2.2/match/'+matchID[0]+'?api_key=RGAPI-6b4e9139-2121-4820-8cd9-371891441c4b')
responseMatch = urlopen(matchRequest)
loadMatch = responseMatch.read()
matchData = json.loads(loadMatch)
matchData
# Out:
# {u'mapId': 11,
#  u'matchCreation': 1485305776502L,
#  u'matchDuration': 2056,
#  u'matchId': 2407787433L,
#  u'matchMode': u'CLASSIC',
#  u'matchType': u'MATCHED_GAME',
#  u'matchVersion': u'7.1.172.6393',
#  u'participantIdentities': [{u'participantId': 1,
#    u'player': {u'matchHistoryUri': u'/v1/stats/player_history/NA1/200626893',
#     u'profileIcon': 1441,
#     u'summonerId': 37558151,
#     u'summonerName': u'lnvalid Name'}},
#   {u'participantId': 2,
#    u'player': {u'matchHistoryUri': u'/v1/stats/player_history/NA1/200499050',
#     u'profileIcon': 1381,
#     u'summonerId': 37532228,
#     u'summonerName': u'rhubarbs'}},
#   {u'participantId': 3,
#    u'player': {u'matchHistoryUri': u'/v1/stats/player_history/NA1/48093906',
#     u'profileIcon': 936,
#     u'summonerId': 33359979,
#     u'summonerName': u'21 10'}},
#   {u'participantId': 4,
#    u'player': {u'matchHistoryUri': u'/v1/stats/player_history/NA1/201596793',
#     u'profileIcon': 1460,
# ...

# %%
matchIndex =[]
for key in matchData:
    matchIndex.append(str(key))
matchIndex
# Out:
# ['queueType',
#  'matchVersion',
#  'platformId',
#  'season',
#  'region',
#  'matchId',
#  'mapId',
#  'matchCreation',
#  'teams',
#  'participants',
#  'matchMode',
#  'matchDuration',
#  'participantIdentities',
#  'matchType']

# %%
for key in matchData['participantIdentities']:
    print str(key)
# Out:
# {u'player': {u'profileIcon': 1441, u'summonerId': 37558151, u'matchHistoryUri': u'/v1/stats/player_history/NA1/200626893', u'summonerName': u'lnvalid Name'}, u'participantId': 1}
# {u'player': {u'profileIcon': 1381, u'summonerId': 37532228, u'matchHistoryUri': u'/v1/stats/player_history/NA1/200499050', u'summonerName': u'rhubarbs'}, u'participantId': 2}
# {u'player': {u'profileIcon': 936, u'summonerId': 33359979, u'matchHistoryUri': u'/v1/stats/player_history/NA1/48093906', u'summonerName': u'21 10'}, u'participantId': 3}
# {u'player': {u'profileIcon': 1460, u'summonerId': 38869932, u'matchHistoryUri': u'/v1/stats/player_history/NA1/201596793', u'summonerName': u'really big meme'}, u'participantId': 4}
# {u'player': {u'profileIcon': 603, u'summonerId': 46239231, u'matchHistoryUri': u'/v1/stats/player_history/NA1/209287319', u'summonerName': u'Hyorimaru'}, u'participantId': 5}
# ...

# %%
for key in matchData['participants'][7]:
    print str(key)
# Out:
# stats
# championId
# participantId
# runes
# highestAchievedSeasonTier
# masteries
# spell2Id
# teamId
# timeline
# spell1Id

# %%
for key in matchData['participants'][7]['stats']:
    print str(key)
# Out:
# item1
# totalPlayerScore
# unrealKills
# objectivePlayerScore
# largestCriticalStrike
# totalDamageDealt
# magicDamageDealtToChampions
# largestMultiKill
# largestKillingSpree
# quadraKills
# magicDamageTaken
# towerKills
# totalTimeCrowdControlDealt
# neutralMinionsKilledEnemyJungle
# firstTowerAssist
# neutralMinionsKilledTeamJungle
# physicalDamageDealt
# item2
# item3
# item0
# winner
# item6
# wardsPlaced
# item4
# item5
# minionsKilled
# tripleKills
# champLevel
# magicDamageDealt
# kills
# doubleKills
# firstInhibitorKill
# trueDamageTaken
# firstBloodAssist
# firstBloodKill
# assists
# deaths
# neutralMinionsKilled
# combatPlayerScore
# visionWardsBoughtInGame
# physicalDamageDealtToChampions
# goldSpent
# trueDamageDealt
# trueDamageDealtToChampions
# pentaKills
# firstInhibitorAssist
# firstTowerKill
# totalHeal
# wardsKilled
# goldEarned
# sightWardsBoughtInGame
# totalDamageDealtToChampions
# totalUnitsHealed
# inhibitorKills
# totalScoreRank
# totalDamageTaken
# ...

# %%
# Out:
# [u'queueType',
#  u'matchVersion',
#  u'platformId',
#  u'season',
#  u'region',
#  u'matchId',
#  u'mapId',
#  u'matchCreation',
#  u'teams',
#  u'participants',
#  u'matchMode',
#  u'matchDuration',
#  u'participantIdentities',
#  u'matchType']

# %%
for keys in matchData:
    print keys
# Out:
# queueType
# matchVersion
# platformId
# season
# region
# matchId
# mapId
# matchCreation
# teams
# participants
# matchMode
# matchDuration
# participantIdentities
# matchType

# %%
totalPlayerScore=[]
unrealKills=[]
objectivePlayerScore=[]

for keys in matchData['participants'][7]['stats']:
    totalPlayerScore.append('participants'[u'totalPlayerScore'])
    unrealKills.append('participants'[u'unrealKills'])
    objectivePlayerScore.append('participants'[u'objectivePlayerScore'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-0599716b29c1> in <module>()
#       4
#       5 for keys in matchData['participants'][7]['stats']:
# ----> 6     totalPlayerScore.append('participants'[u'totalPlayerScore'])
#       7     unrealKills.append('participants'[u'unrealKills'])
#       8     objectivePlayerScore.append('participants'[u'objectivePlayerScore'])
#
# TypeError: string indices must be integers, not unicode

# %%
totalPlayerScore=[]
unrealKills=[]
objectivePlayerScore=[]
largestCriticalStrike=[]
totalDamageDealt=[]
magicDamageDealtToChampions=[]
largestMultiKill=[]
largestKillingSpree=[]
quadraKills=[]
magicDamageTaken=[]
towerKills=[]
totalTimeCrowdControlDealt=[]
neutralMinionsKilledEnemyJungle=[]
firstTowerAssist=[]
neutralMinionsKilledTeamJungle=[]
physicalDamageDealt=[]
winner=[]
wardsPlaced=[]
minionsKilled=[]
tripleKills=[]
champLevel=[]
magicDamageDealt=[]
kills=[]
doubleKills=[]
firstInhibitorKill=[]
trueDamageTaken=[]
firstBloodAssist=[]
firstBloodKill=[]
assists=[]
deaths=[]
neutralMinionsKilled=[]
combatPlayerScore=[]
visionWardsBoughtInGame=[]
physicalDamageDealtToChampions=[]
goldSpent=[]
trueDamageDealt=[]
trueDamageDealtToChampions=[]
pentaKills=[]
firstInhibitorAssist=[]
firstTowerKill=[]
totalHeal=[]
wardsKilled=[]
goldEarned=[]
sightWardsBoughtInGame=[]
totalUnitsHealed=[]
inhibitorKills=[]
totalScoreRank=[]
totalDamageTaken=[]
killingSprees=[]
physicalDamageTaken=[]
totalDamageDealtToChampions=[]

for keys in matchData['participants'][7]['stats']:
    totalPlayerScore.append(participants[u'totalPlayerScore'])
    unrealKills.append(participants[u'unrealKills'])
    objectivePlayerScore.append(participants[u'objectivePlayerScore'])
    largestCriticalStrike.append(participants[u'largestCriticalStrike'])
    totalDamageDealt.append(participants[u'totalDamageDealt'])
    magicDamageDealtToChampions.append(participants[u'magicDamageDealtToChampions'])
    largestMultiKill.append(participants[u'largestMultiKill'])
    largestKillingSpree.append(participants[u'largestKillingSpree'])
    quadraKills.append(participants[u'quadraKills'])
    magicDamageTaken.append(participants[u'magicDamageTaken'])
    towerKills.append(participants[u'towerKills'])
    totalTimeCrowdControlDealt.append(participants[u'totalTimeCrowdControlDealt'])
    neutralMinionsKilledEnemyJungle.append(participants[u'neutralMinionsKilledEnemyJungle'])
    firstTowerAssist.append(participants[u'firstTowerAssist'])
    neutralMinionsKilledTeamJungle.append(participants[u'neutralMinionsKilledTeamJungle'])
    physicalDamageDealt.append(participants[u'physicalDamageDealt'])
    winner.append(participants[u'winner'])
    wardsPlaced.append(participants[u'wardsPlaced'])
    minionsKilled.append(participants[u'minionsKilled'])
    tripleKills.append(participants[u'tripleKills'])
    champLevel.append(participants[u'champLevel'])
    magicDamageDealt.append(participants[u'magicDamageDealt'])
    kills.append(participants[u'kills'])
    doubleKills.append(participants[u'doubleKills'])
    firstInhibitorKill.append(participants[u'firstInhibitorKill'])
    trueDamageTaken.append(participants[u'trueDamageTaken'])
    firstBloodAssist.append(participants[u'firstBloodAssist'])
    firstBloodKill.append(participants[u'firstBloodKill'])
    assists.append(participants[u'assists'])
    deaths.append(participants[u'deaths'])
    neutralMinionsKilled.append(participants[u'neutralMinionsKilled'])
    combatPlayerScore.append(participants[u'combatPlayerScore'])
    visionWardsBoughtInGame.append(participants[u'visionWardsBoughtInGame'])
    physicalDamageDealtToChampions.append(participants[u'physicalDamageDealtToChampions'])
    goldSpent.append(participants[u'goldSpent'])
    trueDamageDealt.append(participants[u'trueDamageDealt'])
    trueDamageDealtToChampions.append(participants[u'trueDamageDealtToChampions'])
    pentaKills.append(participants[u'pentaKills'])
    firstInhibitorAssist.append(participants[u'firstInhibitorAssist'])
    firstTowerKill.append(participants[u'firstTowerKill'])
    totalHeal.append(participants[u'totalHeal'])
    wardsKilled.append(participants[u'wardsKilled'])
    goldEarned.append(participants[u'goldEarned'])
    sightWardsBoughtInGame.append(participants[u'sightWardsBoughtInGame'])
    totalDamageDealtToChampions.append(participants[u'totalDamageDealtToChampions'])
    totalUnitsHealed.append(participants[u'totalUnitsHealed'])
    inhibitorKills.append(participants[u'inhibitorKills'])
    totalScoreRank.append(participants[u'totalScoreRank'])
    totalDamageTaken.append(participants[u'totalDamageTaken'])
    killingSprees.append(participants[u'killingSprees'])
    physicalDamageTaken.append(participants[u'physicalDamageTaken'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-48-0c0aeff43a6b> in <module>()
#      15
#      16 for keys in matchData:
# ---> 17     queueType.append(keys[u'queueType'])
#      18     matchVersion.append(keys[u'matchVersion'])
#      19     platformId.append(keys[u'playformId'])
#
# TypeError: string indices must be integers

# %%
my_family = dict()

my_family["dad"] = "Homer"

# %%
my_family
# Out:
# {'1': 'Family Member 1',
#  '2': 'Family Member 2',
#  '3': 'Family Member 3',
#  '4': 'Family Member 4',
#  '5': 'Family Member 5',
#  '6': 'Family Member 6',
#  '7': 'Family Member 7',
#  '8': 'Family Member 8',
#  '9': 'Family Member 9',
#  'Neighbor-1': {},
#  'dad': 'New Homer',
#  'kids': ['Kid-1']}

# %%
for x in range(1, 10):
    my_family[str(x)] = "Family Member " + str(x)

# %%
my_family["1"]
# Out:
# 'Family Member 1'

# %%
my_family["dad"] = "New Homer"

# %%
my_family["kids"] = list()

# %%
my_family["kids"].append("Kid-1")

# %%
my_family["Neighbor-1"] = dict()
