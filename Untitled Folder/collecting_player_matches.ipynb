# %%
import json
import urllib2
import csv
import pandas as pd
import numpy as np
from urllib2 import Request, urlopen

# %%
matchList1 = pd.read_csv('C:\Users\Nik\Desktop\player_match_list\matchlist.csv')#ghostghost PlayerID:621
matchList1
# Out:
#      champion    lane     matchID platformID                     queue  \
# 0         421  JUNGLE  2438661899        NA1  TEAM_BUILDER_RANKED_SOLO
# 1          39     TOP  2438581166        NA1  TEAM_BUILDER_RANKED_SOLO
# 2          58     TOP  2438506691        NA1  TEAM_BUILDER_RANKED_SOLO
# 3         133     TOP  2438484705        NA1  TEAM_BUILDER_RANKED_SOLO
# 4          85  BOTTOM  2437022468        NA1  TEAM_BUILDER_RANKED_SOLO
# 5         133     TOP  2437011135        NA1  TEAM_BUILDER_RANKED_SOLO
# 6         133     TOP  2434996388        NA1  TEAM_BUILDER_RANKED_SOLO
# 7         133     TOP  2434122488        NA1  TEAM_BUILDER_RANKED_SOLO
# 8         133     TOP  2434107483        NA1  TEAM_BUILDER_RANKED_SOLO
# 9         133     TOP  2433489353        NA1  TEAM_BUILDER_RANKED_SOLO
# 10        133  BOTTOM  2433495235        NA1  TEAM_BUILDER_RANKED_SOLO
# 11        202  BOTTOM  2434997859        NA1  TEAM_BUILDER_RANKED_SOLO
# ...
