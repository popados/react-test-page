# %%
import json
import urllib2
import csv
import pandas as pd
import numpy as np
from urllib2 import Request, urlopen

# %%
matchRequest =Request('https://na.api.pvp.net/api/lol/na/v2.2/match/2410883736?api_key=RGAPI-6b4e9139-2121-4820-8cd9-371891441c4b')
responseMatch = urlopen(matchRequest)
loadMatch = responseMatch.read()
matchData = json.loads(loadMatch)
matchData
# Out:
# {u'mapId': 11,
#  u'matchCreation': 1485624082554L,
#  u'matchDuration': 1826,
#  u'matchId': 2410883736L,
#  u'matchMode': u'CLASSIC',
#  u'matchType': u'MATCHED_GAME',
#  u'matchVersion': u'7.2.174.829',
#  u'participantIdentities': [{u'participantId': 1,
#    u'player': {u'matchHistoryUri': u'/v1/stats/player_history/NA/34398919',
#     u'profileIcon': 915,
#     u'summonerId': 21131448,
#     u'summonerName': u'FreSHKiCKs'}},
#   {u'participantId': 2,
#    u'player': {u'matchHistoryUri': u'/v1/stats/player_history/NA/32921958',
#     u'profileIcon': 900,
#     u'summonerId': 20142680,
#     u'summonerName': u'freelancer'}},
#   {u'participantId': 3,
#    u'player': {u'matchHistoryUri': u'/v1/stats/player_history/NA/32886695',
#     u'profileIcon': 1407,
#     u'summonerId': 20156051,
#     u'summonerName': u'Jako5000'}},
#   {u'participantId': 4,
#    u'player': {u'matchHistoryUri': u'/v1/stats/player_history/NA/5766',
#     u'profileIcon': 20,
#     u'summonerId': 621,
# ...

# %%
with open('testStats.csv', 'wb') as createcsv:
    create = csv.writer(createcsv)
    create.writerow(matchData.keys())
    create.writerow(matchData.values())

# %%
stats = pd.read_csv('testStats.csv')

# %%
stats
# Out:
#                   queueType matchVersion platformId         season  region  \
# 0  TEAM_BUILDER_RANKED_SOLO  7.2.174.829        NA1  PRESEASON2017     NaN
#
#       matchId  mapId  matchCreation  \
# 0  2410883736     11  1485624082554
#
#                                                teams  \
# 0  [{u'firstDragon': False, u'bans': [{u'pickTurn...
#
#                                         participants matchMode  matchDuration  \
# 0  [{u'stats': {u'item1': 3068, u'totalPlayerScor...   CLASSIC           1826
#
#                                participantIdentities     matchType
# 0  [{u'player': {u'profileIcon': 915, u'summonerI...  MATCHED_GAME

# %%
for keys in stats['teams']:
    print str(keys)
# Out:
# [{u'firstDragon': False, u'bans': [{u'pickTurn': 1, u'championId': 164}, {u'pickTurn': 3, u'championId': 121}, {u'pickTurn': 5, u'championId': 51}], u'firstInhibitor': True, u'baronKills': 0, u'firstRiftHerald': False, u'winner': True, u'firstBaron': False, u'riftHeraldKills': 0, u'firstBlood': False, u'teamId': 100, u'firstTower': True, u'vilemawKills': 0, u'inhibitorKills': 1, u'towerKills': 8, u'dominionVictoryScore': 0, u'dragonKills': 3}, {u'firstDragon': True, u'bans': [{u'pickTurn': 2, u'championId': 7}, {u'pickTurn': 4, u'championId': 154}, {u'pickTurn': 6, u'championId': 107}], u'firstInhibitor': False, u'baronKills': 0, u'firstRiftHerald': False, u'winner': False, u'firstBaron': False, u'riftHeraldKills': 0, u'firstBlood': True, u'teamId': 200, u'firstTower': False, u'vilemawKills': 0, u'inhibitorKills': 0, u'towerKills': 1, u'dominionVictoryScore': 0, u'dragonKills': 1}]

# %%
for keys in stats['participants']:
    print str(keys)
# Out:
# [{u'stats': {u'item1': 3068, u'totalPlayerScore': 0, u'unrealKills': 0, u'objectivePlayerScore': 0, u'largestCriticalStrike': 0, u'totalDamageDealt': 140440, u'magicDamageDealtToChampions': 16827, u'largestMultiKill': 2, u'largestKillingSpree': 4, u'quadraKills': 0, u'magicDamageTaken': 6682, u'towerKills': 1, u'totalTimeCrowdControlDealt': 797, u'neutralMinionsKilledEnemyJungle': 2, u'firstTowerAssist': False, u'neutralMinionsKilledTeamJungle': 0, u'physicalDamageDealt': 26022, u'item2': 3047, u'item3': 3065, u'item0': 2033, u'winner': True, u'item6': 3340, u'wardsPlaced': 15, u'item4': 3025, u'item5': 1011, u'minionsKilled': 200, u'tripleKills': 0, u'champLevel': 15, u'magicDamageDealt': 112472, u'kills': 8, u'doubleKills': 1, u'firstInhibitorKill': False, u'trueDamageTaken': 368, u'firstBloodAssist': False, u'firstBloodKill': False, u'assists': 10, u'deaths': 2, u'neutralMinionsKilled': 2, u'combatPlayerScore': 0, u'visionWardsBoughtInGame': 1, u'physicalDamageDealtToChampions': 3
# ...

# %%
with open('testStats1.csv', 'wb') as createcsv:
    create = csv.writer(createcsv)
    create.writerow(stats.keys())
    create.writerow(stats.values())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-db39b4bfa4d4> in <module>()
#       2     create = csv.writer(createcsv)
#       3     create.writerow(stats.keys())
# ----> 4     create.writerow(stats.values())
#
# TypeError: 'numpy.ndarray' object is not callable
