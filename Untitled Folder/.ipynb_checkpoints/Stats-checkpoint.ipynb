# %%
import csv
import json
import urllib2
from urllib2 import Request, urlopen
import pandas as pd

# %%
request = Request("https://na.api.pvp.net/api/lol/na/v1.3/stats/by-summoner/30366254/ranked?season=SEASON2017&api_key=RGAPI-6b4e9139-2121-4820-8cd9-371891441c4b")
response = urlopen(request)
data = response.read() #Acoldblazeolive
stats = json.loads(data)
pd.read_csv(stats)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-7-9320efa09c6c> in <module>()
#       3 data = response.read() #Acoldblazeolive
#       4 stats = json.loads(data)
# ----> 5 pd.read_csv(stats)
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     644                     skip_blank_lines=skip_blank_lines)
#     645
# --> 646         return _read(filepath_or_buffer, kwds)
#     647
#     648     parser_f.__name__ = name
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     387
#     388     # Create the parser.
# --> 389     parser = TextFileReader(filepath_or_buffer, **kwds)
#     390
#     391     if (nrows is not None) and (chunksize is not None):
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\io\parsers.py in __init__(self, f, engine, **kwds)
#     728             self.options['has_index_names'] = kwds['has_index_names']
#     729
# --> 730         self._make_engine(self.engine)
#     731
#     732     def close(self):
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\io\parsers.py in _make_engine(self, engine)
#     921     def _make_engine(self, engine='c'):
#     922         if engine == 'c':
# --> 923             self._engine = CParserWrapper(self.f, **self.options)
#     924         else:
#     925             if engine == 'python':
#
# C:\ProgramData\Anaconda2\lib\site-packages\pandas\io\parsers.py in __init__(self, src, **kwds)
#    1388         kwds['allow_leading_cols'] = self.index_col is not False
#    1389
# -> 1390         self._reader = _parser.TextReader(src, **kwds)
#    1391
#    1392         # XXX
#
# pandas\parser.pyx in pandas.parser.TextReader.__cinit__ (pandas\parser.c:4184)()
#
# pandas\parser.pyx in pandas.parser.TextReader._setup_parser_source (pandas\parser.c:8626)()
#
# IOError: Expected file path name or file-like object, got <type 'dict'> type

# %%
df_cols = ['freshblood', 'divison', 'veteran', 'wins', 'losses', 'playerID','playerName',
           'inactive','hotstreak','leaguePoints']

leader = pd.read_csv('leaguedata2.csv',names=df_cols, skiprows=1, na_filter=False, header=0)
leader
# Out:
#     freshblood divison veteran  wins  losses  playerID        playerName  \
# 0        False       I   False    54      45  30366254   Acoldblazeolive
# 1        False       I   False   173     159  32723343            Budded
# 2        False       I   False   112      81  82779239       FOX Damonte
# 3        False       I   False    71      45  41216586          Finkypop
# 4         True       I   False   194     161  43644170          East Tao
# 5         True       I   False    78      54  28943509            Kokiri
# 6         True       I   False   115      90  35463974              Luda
# 7        False       I   False   126      86  71350203     TSB Ethiridis
# 8         True       I   False    79      52  21703151           boo sky
# 9        False       I   False    77      53  20123146       AND 1 AIDAN
# 10       False       I   False   117      92  29168137        Reconsider
# 11       False       I   False   137     117  73169691    Barclay snoopy
# 12       False       I   False    61      39  26600205             M ckg
# 13        True       I   False   180     167  20037104      Chody Walrus
# 14       False       I    True   290     274  38067655    Challenger Pig
# 15        True       I   False   119     110  32705024        Falcon God
# 16       False       I   False    57      28  68240838        EnVy Ninja
# 17       False       I   False    64      47  31209421      Captain Nuke
# 18        True       I   False   114      98  21726097      IIIll63IIlll
# 19       False       I   False   102      80  46113000             Øctav
# 20       False       I   False    79      35  20973757               Z40
# 21       False       I   False   185     171    262255        Aerodactyl
# 22       False       I   False   107      82  53801673         Dziarmaga
# 23       False       I   False   156     139  19243208      chuck normis
# 24        True       I   False   166     134  19208458       nukeforlots
# 25        True       I   False    66      41  20959855  I feed for nudez
# 26       False       I   False   122     102  20962399            Teesum
# 27       False       I   False   105      77  52041228              Yiza
# 28        True       I   False    64      37  29491995     nightmare mom
# 29        True       I   False    55      30  34268448  Forgotten Legend
# ..         ...     ...     ...   ...     ...       ...               ...
# 555      False       I   False   204     183  22701102         EleJiggle
# 556      False       I   False   167     102  28961355  AlphaKennyBodyGG
# 557      False       I   False   140     115  38869932   really big meme
# 558      False       I   False   204     180  68871212       BatBoyMelee
# 559      False       I   False    80      49  48664738            Pennie
# 560       True       I   False   139     118  40278872            Arrowe
# 561      False       I   False   128     102  71641026   TwtchTv imaokai
# 562      False       I   False   135     116  36631236            Sasuni
# 563      False       I   False   138     115  38384295       1 Mìn 1 Sec
# 564      False       I   False    63      46  79390303           keithly
# 565      False       I   False    74      36  21533287      CriCriCriCri
# 566      False       I   False   149     125  25145157          Credenda
# 567       True       I   False   107      95  36119978          Kazahana
# 568       True       I   False   178     168  28903785      YummiBananas
# 569      False       I   False   223     213  46531569          IKingVex
# 570      False       I   False   139     128  19577112           gatsuno
# 571       True       I   False    42      23  73459347               LKN
# 572       True       I   False    95      73  34018967     Artan 1000 LP
# 573      False       I   False   293     273  23994633      I Am Leegend
# 574       True       I   False   217     201  27794083          Gillette
# 575       True       I   False   305     293  38841069        Ikzencriel
# 576      False       I   False   120      93  30970977       LilPistacho
# 577      False       I   False   110      84  38886417          DuskDust
# 578       True       I   False    57      36  39987054       CloudNguyén
# 579      False       I   False   149     100  80060982            spear1
# 580      False       I   False   263     245  28388863         HonyakuEn
# 581      False       I    True   145     130  45678930         MattyMooo
# 582      False       I   False   241     214  29710909         On my own
# 583      False       I   False   116      68  77560481            adc ty
# 584      False       I   False   228     196  28690500             KaNKl
#
#     inactive hotstreak  leaguePoints
# 0      False     False             9
# 1      False      True           141
# 2      False     False            70
# 3      False     False           165
# 4      False     False            18
# 5      False     False             0
# 6      False      True            72
# 7      False     False           185
# 8      False     False            23
# 9      False     False           143
# 10     False     False            29
# 11     False      True            58
# 12     False     False           171
# 13     False     False           163
# 14     False     False            18
# 15     False     False            47
# 16     False     False           306
# 17     False     False            46
# 18     False     False             0
# 19     False     False            20
# 20     False      True            81
# 21     False     False           102
# 22     False     False           191
# 23     False     False            36
# 24     False     False            52
# 25     False     False            55
# 26     False     False           210
# 27     False     False           157
# 28     False      True             0
# 29     False     False            65
# ..       ...       ...           ...
# 555    False     False             2
# 556    False     False           225
# 557    False      True            74
# 558    False     False           124
# 559    False     False           155
# 560    False     False            17
# 561    False     False           245
# 562    False     False            42
# 563    False      True           182
# 564    False     False            36
# 565    False     False           150
# 566    False     False            33
# 567    False     False           146
# 568    False     False             0
# 569    False     False            40
# 570    False     False           100
# 571    False     False            24
# 572    False     False            73
# 573    False     False           142
# 574    False      True           136
# 575    False     False            92
# 576    False     False           187
# 577    False     False           129
# 578    False     False            80
# 579    False     False           167
# 580    False     False           151
# 581    False     False           213
# 582    False     False             0
# 583    False     False           137
# 584    False      True           163
#
# [585 rows x 10 columns]
