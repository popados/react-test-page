# %%
import csv
import json
import urllib2
from urllib2 import Request, urlopen
import pandas as pd

# %%
request = Request("https://na.api.pvp.net/api/lol/na/v1.3/stats/by-summoner/30366254/ranked?season=SEASON2017&api_key=RGAPI-6b4e9139-2121-4820-8cd9-371891441c4b")
response = urlopen(request)
data = response.read() #Acoldblazeolive
stats = json.loads(data)
stats
# Out:
# {u'champions': [{u'id': 110,
#    u'stats': {u'maxChampionsKilled': 18,
#     u'maxNumDeaths': 9,
#     u'mostChampionKillsPerSession': 18,
#     u'mostSpellsCast': 0,
#     u'totalAssists': 53,
#     u'totalChampionKills': 48,
#     u'totalDamageDealt': 1010372,
#     u'totalDamageTaken': 115863,
#     u'totalDeathsPerSession': 33,
#     u'totalDoubleKills': 7,
#     u'totalFirstBlood': 0,
#     u'totalGoldEarned': 78913,
#     u'totalMagicDamageDealt': 69279,
#     u'totalMinionKills': 1282,
#     u'totalPentaKills': 0,
#     u'totalPhysicalDamageDealt': 932927,
#     u'totalQuadraKills': 0,
#     u'totalSessionsLost': 2,
#     u'totalSessionsPlayed': 5,
#     u'totalSessionsWon': 3,
#     u'totalTripleKills': 1,
#     u'totalTurretsKilled': 8,
#     u'totalUnrealKills': 0}},
#   {u'id': 41,
#    u'stats': {u'maxChampionsKilled': 7,
#     u'maxNumDeaths': 6,
#     u'mostChampionKillsPerSession': 7,
#     u'mostSpellsCast': 0,
#     u'totalAssists': 23,
# ...

# %%
for key in stats:
    print stats['champions']
# Out:
# [{u'stats': {u'totalPhysicalDamageDealt': 932927, u'totalTurretsKilled': 8, u'totalSessionsPlayed': 5, u'totalAssists': 53, u'totalDamageDealt': 1010372, u'mostChampionKillsPerSession': 18, u'totalPentaKills': 0, u'mostSpellsCast': 0, u'totalDoubleKills': 7, u'maxChampionsKilled': 18, u'totalDeathsPerSession': 33, u'totalSessionsWon': 3, u'totalGoldEarned': 78913, u'totalTripleKills': 1, u'totalChampionKills': 48, u'maxNumDeaths': 9, u'totalMinionKills': 1282, u'totalMagicDamageDealt': 69279, u'totalQuadraKills': 0, u'totalUnrealKills': 0, u'totalDamageTaken': 115863, u'totalSessionsLost': 2, u'totalFirstBlood': 0}, u'id': 110}, {u'stats': {u'totalPhysicalDamageDealt': 482516, u'totalTurretsKilled': 3, u'totalSessionsPlayed': 3, u'totalAssists': 23, u'totalDamageDealt': 524578, u'mostChampionKillsPerSession': 7, u'totalPentaKills': 0, u'mostSpellsCast': 0, u'totalDoubleKills': 2, u'maxChampionsKilled': 7, u'totalDeathsPerSession': 12, u'totalSessionsWon': 2, u'totalGoldEarned': 39312
# ...

# %%
for key in stats['champions']:
    print key
# Out:
# {u'stats': {u'totalPhysicalDamageDealt': 932927, u'totalTurretsKilled': 8, u'totalSessionsPlayed': 5, u'totalAssists': 53, u'totalDamageDealt': 1010372, u'mostChampionKillsPerSession': 18, u'totalPentaKills': 0, u'mostSpellsCast': 0, u'totalDoubleKills': 7, u'maxChampionsKilled': 18, u'totalDeathsPerSession': 33, u'totalSessionsWon': 3, u'totalGoldEarned': 78913, u'totalTripleKills': 1, u'totalChampionKills': 48, u'maxNumDeaths': 9, u'totalMinionKills': 1282, u'totalMagicDamageDealt': 69279, u'totalQuadraKills': 0, u'totalUnrealKills': 0, u'totalDamageTaken': 115863, u'totalSessionsLost': 2, u'totalFirstBlood': 0}, u'id': 110}
# ...

# %%
maxChampionsKilled=[]
maxNumDeaths=[]
mostChampionKillsPerSession=[]
mostSpellsCast=[]
totalAssists=[]
totalChampionKills=[]
totalDamageDealt=[]
totalDamageTaken=[]
totalDeathsPerSession=[]
totalDoubleKills=[]
totalFirstBlood=[]
totalGoldEarned=[]
totalMagicDamageDealt=[]
totalMinionKills=[]
totalPentaKills=[]
totalPhysicalDamageDealt=[]
totalQuadraKills=[]
totalSessionsLost=[]
totalSessionsPlayed=[]
totalSessionsWon=[]
totalTripleKills=[]
totalTurretsKilled=[]
totalUnrealKills=[]

for stat in stats['champions']:
    maxChampionsKilled=[]
    maxNumDeaths=[]
    mostChampionKillsPerSession=[]
    mostSpellsCast=[]
    totalAssists=[]
    totalChampionKills=[]
    totalDamageDealt=[]
    totalDamageTaken=[]
    totalDeathsPerSession=[]
    totalDoubleKills=[]
    totalFirstBlood=[]
    totalGoldEarned=[]
    totalMagicDamageDealt=[]
    totalMinionKills=[]
    totalPentaKills=[]
    totalPhysicalDamageDealt=[]
    totalQuadraKills=[]
    totalSessionsLost=[]
    totalSessionsPlayed=[]
    totalSessionsWon=[]
    totalTripleKills=[]
    totalTurretsKilled=[]
    totalUnrealKills=[]
