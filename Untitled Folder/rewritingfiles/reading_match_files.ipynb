# %%
import pandas as pd

# %%
df = pd.read_csv('C:\Users\Nik\Desktop\Ldata\participant_data_per_match\matchData2393387314.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 58 columns):
# item1                              10 non-null int64
# totalPlayerScore                   10 non-null int64
# unrealKills                        10 non-null int64
# objectivePlayerScore               10 non-null int64
# largestCriticalStrike              10 non-null int64
# totalDamageDealt                   10 non-null int64
# magicDamageDealtToChampions        10 non-null int64
# largestMultiKill                   10 non-null int64
# largestKillingSpree                10 non-null int64
# quadraKills                        10 non-null int64
# magicDamageTaken                   10 non-null int64
# towerKills                         10 non-null int64
# totalTimeCrowdControlDealt         10 non-null int64
# neutralMinionsKilledEnemyJungle    10 non-null int64
# firstTowerAssist                   10 non-null bool
# neutralMinionsKilledTeamJungle     10 non-null int64
# ...

# %%
import pandas as pd
import glob
interesting_files = glob.glob("C:\Users\Nik\Desktop\Ldata\participant_data_per_match\*.csv")
df_list = []
for filename in sorted(interesting_files):
    df_list.append(pd.read_csv(filename))
full_df = pd.concat(df_list)

full_df.to_csv('C:\Users\Nik\Desktop\Ldata\participant_data_per_match\end_of_game_players.csv')

# %%
full_df
# Out:
#     assists  champLevel  combatPlayerScore  deaths  doubleKills  \
# 0         8          18                  0       2            0
# 1         7          16                  0       5            0
# 2        12          18                  0       9            1
# 3        11          17                  0      10            0
# 4         8          18                  0       4            0
# 5        11          18                  0       6            1
# 6         8          18                  0       8            0
# 7        14          18                  0       6            0
# 8        18          17                  0       2            0
# 9         7          18                  0       4            2
# 0         7          18                  0       7            2
# 1        14          17                  0      12            0
# 2        13          16                  0       6            0
# 3        16          18                  0       6            0
# ...

# %%
full_df.winner.value_counts()
# Out:
# True     12545
# False    12545
# Name: winner, dtype: int64
