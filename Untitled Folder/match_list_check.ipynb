# %%
import json
import csv
import urllib2
import pandas as pd
from urllib2 import Request, urlopen
import numpy as np

matchList = pd.read_csv('C:\Users\Nik\Desktop\Ldata\player_match\match.csv')#ghostghost PlayerID:621
matchList

for n in list(np.unique(matchList.matchID.values)):
    print str(n)
# Out:
#       playerID  champion    lane     matchID platformID  \
# 0     81619136       421  JUNGLE  2438661899        NA1
# 1     81619136        39     TOP  2438581166        NA1
# 2     81619136        58     TOP  2438506691        NA1
# 3     81619136       133     TOP  2438484705        NA1
# 4     81619136        85  BOTTOM  2437022468        NA1
# 5     81619136       133     TOP  2437011135        NA1
# 6     81619136       133     TOP  2434996388        NA1
# 7     81619136       133     TOP  2434122488        NA1
# 8     81619136       133     TOP  2434107483        NA1
# 9     81619136       133     TOP  2433489353        NA1
# 10    81619136       133  BOTTOM  2433495235        NA1
# 11    23632567       202  BOTTOM  2434997859        NA1
# 12    23632567       412  BOTTOM  2409111096        NA1
# 13    23632567        81  BOTTOM  2408458051        NA1
# 14    23632567       202  BOTTOM  2407783213        NA1
# 15    23632567        81  BOTTOM  2406134058        NA1
# ...

# %%
for n in list(np.unique(matchList.matchID.values)):
    print str(n)
#make a list with each unique matchID and start gathering participant info?
# Out:
# 2375109373
# 2375160703
# 2388663395
# 2388767398
# 2388789645
# 2388836940
# 2392604962
# 2392638598
# 2392645029
# 2392683284
# 2392683733
# 2392779047
# 2393106347
# 2393387314
# 2393428892
# 2394459481
# 2394582239
# 2394664038
# 2394750498
# 2394917687
# 2394933162
# 2394964668
# 2395052120
# 2395181060
# 2395236061
# 2395244001
# 2395533152
# 2395636158
# 2395682753
# 2395708403
# 2395715810
# 2395771600
# 2395773019
# 2395775488
# 2395778720
# 2395792782
# 2395796645
# 2396310697
# 2396681786
# 2397175993
# 2397231751
# 2397236250
# 2397268803
# 2397304852
# 2397337064
# 2397351606
# 2397431791
# 2397444950
# 2397504749
# 2397562130
# 2397563194
# 2397667616
# 2397679277
# 2397684575
# 2397685699
# 2397714419
# 2397716802
# 2397717801
# 2397734313
# 2397776522
# 2397791209
# 2397824558
# 2397828757
# 2397828839
# 2397840287
# 2397845101
# 2397874055
# 2397875193
# 2397895341
# 2397933060
# 2397937465
# 2397938026
# 2397944379
# 2397997989
# 2398042933
# 2398045031
# ...

# %%
matchRequest =Request('https://na.api.pvp.net/api/lol/na/v2.2/match/2375109373?api_key=RGAPI-6b4e9139-2121-4820-8cd9-371891441c4b')
responseMatch = urlopen(matchRequest)
loadMatch = responseMatch.read()
matchData = json.loads(loadMatch)
matchData
# Out:
# {u'mapId': 11,
#  u'matchCreation': 1481975940640L,
#  u'matchDuration': 1696,
#  u'matchId': 2375109373L,
#  u'matchMode': u'CLASSIC',
#  u'matchType': u'MATCHED_GAME',
#  u'matchVersion': u'6.24.169.4424',
#  u'participantIdentities': [{u'participantId': 1,
#    u'player': {u'matchHistoryUri': u'/v1/stats/player_history/NA1/216701563',
#     u'profileIcon': 691,
#     u'summonerId': 54329134,
#     u'summonerName': u'swaggreed'}},
#   {u'participantId': 2,
#    u'player': {u'matchHistoryUri': u'/v1/stats/player_history/NA/36786840',
#     u'profileIcon': 1229,
#     u'summonerId': 22891040,
#     u'summonerName': u'EmperorOng'}},
#   {u'participantId': 3,
#    u'player': {u'matchHistoryUri': u'/v1/stats/player_history/NA1/212222226',
#     u'profileIcon': 1301,
#     u'summonerId': 49194182,
#     u'summonerName': u'silvermidget fan'}},
#   {u'participantId': 4,
#    u'player': {u'matchHistoryUri': u'/v1/stats/player_history/NA1/201403328',
#     u'profileIcon': 23,
# ...

# %%
matchData['participants'][1]['stats'] #2410767351

with open('teststats.csv', 'wb') as createcsv:
    create = csv.writer(createcsv)
    create.writerow(matchData['participants'][1]['stats'].keys())
    create.writerow(matchData['participants'][1]['stats'].values())

# %%
stats=pd.read_csv('teststats.csv')
stats
# Out:
#    item1  totalPlayerScore  unrealKills  objectivePlayerScore  \
# 0   1400                 0            0                     0
#
#    largestCriticalStrike  totalDamageDealt  magicDamageDealtToChampions  \
# 0                    300            156959                          870
#
#    largestMultiKill  largestKillingSpree  quadraKills         ...           \
# 0                 2                    3            0         ...
#
#    wardsKilled  goldEarned  sightWardsBoughtInGame  \
# 0            4       11771                       0
#
#    totalDamageDealtToChampions totalUnitsHealed  inhibitorKills  \
# 0                         9520                1               0
#
#    totalScoreRank  totalDamageTaken  killingSprees  physicalDamageTaken
# 0               0             19342              2                15086
#
# [1 rows x 58 columns]

# %%
for key in matchData:
    print str(key)
# Out:
# queueType
# matchVersion
# platformId
# season
# region
# matchId
# mapId
# matchCreation
# teams
# participants
# matchMode
# matchDuration
# participantIdentities
# matchType

# %%
for participantId in matchData['participants']:
    print str(key)
# Out:
# {u'stats': {u'item1': 3022, u'totalPlayerScore': 0, u'unrealKills': 0, u'objectivePlayerScore': 0, u'largestCriticalStrike': 300, u'totalDamageDealt': 104257, u'magicDamageDealtToChampions': 9704, u'largestMultiKill': 1, u'largestKillingSpree': 0, u'quadraKills': 0, u'magicDamageTaken': 3576, u'towerKills': 1, u'totalTimeCrowdControlDealt': 662, u'neutralMinionsKilledEnemyJungle': 8, u'firstTowerAssist': False, u'neutralMinionsKilledTeamJungle': 2, u'physicalDamageDealt': 54251, u'item2': 1053, u'item3': 3047, u'item0': 1056, u'winner': True, u'item6': 3363, u'wardsPlaced': 8, u'item4': 3085, u'item5': 1043, u'minionsKilled': 160, u'tripleKills': 0, u'champLevel': 15, u'magicDamageDealt': 49086, u'kills': 1, u'doubleKills': 0, u'firstInhibitorKill': False, u'trueDamageTaken': 2680, u'firstBloodAssist': False, u'firstBloodKill': False, u'assists': 5, u'deaths': 6, u'neutralMinionsKilled': 10, u'combatPlayerScore': 0, u'visionWardsBoughtInGame': 3, u'physicalDamageDealtToChampions': 40
# ...

# %%
queueType=[]
matchVersion=[]
platformId=[]
season=[]
region=[]
matchId=[]
mapId=[]
matchCreation=[]
teams=[]
participants=[]
matchMode=[]
matchDuration=[]
participantIdentities=[]
matchType=[]

col_header = ['queueType','matchVersion','platformId','season','region','matchId','matchCreation','teams',
                  'participants','matchMode','matchDuration','participantIdentities','matchType']

for data in matchData:
    queueType.append('queueType')
    matchVersion.append('matchVersion')
    platformId.append('platformId')
    season.append('season')
    region.append('region')
    matchId.append('matchId')
    mapId.append('mapId')
    matchCreation.append('matchCreation')
    teams.append('teams')
    participants.append('participants')
    matchMode.append('matchMode')
    matchDuration.append('matchDuration')
    participantIdentities.append('participantIdentities')
    matchType.append('matchType')
    
df = pd.DataFrame([queueType,matchVersion,platformId,season,region,matchId,matchCreation,teams, participants,matchMode,matchDuration,participantIdentities,matchType])

df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-29-c9a8f2bd7508> in <module>()
#      18
#      19 for data in matchData:
# ---> 20     queueType.values().append('queueType')
#      21     matchVersion.append('matchVersion')
#      22     platformId.append('platformId')
#
# AttributeError: 'list' object has no attribute 'values'

# %%
player = pd.read_csv('C:\Users\Nik\Desktop\Ldata\participant_data_per_match\match1.csv')
player.T
# Out:
#                                      0       1       2      3      4       5  \
# item1                             2301    1400    3009   1042   3165    3046
# totalPlayerScore                     0       0       0      0      0       0
# unrealKills                          0       0       0      0      0       0
# objectivePlayerScore                 0       0       0      0      0       0
# largestCriticalStrike                0     300       0    666      0     773
# totalDamageDealt                 36466  156959  109165  99851  95970  215030
# magicDamageDealtToChampions      12260     870    1500    871   8530    5115
# largestMultiKill                     1       2       1      2      1       2
# largestKillingSpree                  0       3       5      2      0      11
# quadraKills                          0       0       0      0      0       0
# magicDamageTaken                  5187    3849    9682   6390   3327    5080
# ...

# %%
player.dtypes
# Out:
# item1                              int64
# totalPlayerScore                   int64
# unrealKills                        int64
# objectivePlayerScore               int64
# largestCriticalStrike              int64
# totalDamageDealt                   int64
# magicDamageDealtToChampions        int64
# largestMultiKill                   int64
# largestKillingSpree                int64
# quadraKills                        int64
# magicDamageTaken                   int64
# towerKills                         int64
# totalTimeCrowdControlDealt         int64
# neutralMinionsKilledEnemyJungle    int64
# firstTowerAssist                    bool
# neutralMinionsKilledTeamJungle     int64
# physicalDamageDealt                int64
# item2                              int64
# item3                              int64
# item0                              int64
# winner                              bool
# item6                              int64
# wardsPlaced                        int64
# ...
